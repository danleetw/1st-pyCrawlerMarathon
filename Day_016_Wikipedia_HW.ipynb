# %% [markdown]
# # Wikipedia爬蟲練習
# ## 範例：練習是從Wikipedia中爬取文章。先定義一個搜尋的關鍵字，擷取該關鍵字詞的文章。

# %%
import requests
import re
from bs4 import BeautifulSoup

# %% [markdown]
# ### 先定義一個我們想搜尋的字詞，並將它轉換成UTF-8編碼後的URL

# %%
input_keyword = "網路爬蟲"  # 這裡可以自己定義有興趣的關鍵字
input_keyword = "全球資訊網"  # 這裡可以自己定義有興趣的關鍵字


utf8_url = repr(input_keyword.encode('UTF-8')).upper()  # 編碼成UTF-8並轉成大寫字元
utf8_url = utf8_url.replace("\\X", "%")                 # 用 '%' 取代 '\X' 
print("%s: %s" % (input_keyword, utf8_url[2:-1:1]))     # 擷取中間的編碼結果

# 組成Wiki關鍵字搜尋的網址格式
root_keyword_link = '/wiki/' + utf8_url[2:-1:1]
print(root_keyword_link)
# Out:
# 全球資訊網: %E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2
# /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2

# %% [markdown]
# ### 範例1：送出關鍵字請求後，爬取該關鍵字的文章內容

# %%
# 模擬封包的標頭
headers = {
    'authority': 'zh.wikipedia.org',
    'method': 'GET',
    'path': '/wiki/' + root_keyword_link,
    'scheme': 'https',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'GeoIP=TW:TPE:Taipei:25.05:121.53:v4; TBLkisOn=0; mwPhp7Seed=8b8; WMF-Last-Access-Global=04-Jun-2019; WMF-Last-Access=04-Jun-2019',
    'dnt': '1',
    #'if-modified-since': 'Tue, 04 Jun 2019 12:03:22 GMT',
    'referer': 'https://zh.wikipedia.org/wiki/Wikipedia:%E9%A6%96%E9%A1%B5',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
}    

url = 'https://zh.wikipedia.org' + root_keyword_link  # 組合關鍵字查詢URL
resp = requests.get(url, headers=headers)
resp.encoding = 'utf-8'

html = BeautifulSoup(resp.text, "lxml")
content = html.find(name='div', attrs={'id':'mw-content-text'}).find_all(name='p')

#
# 解析回傳資料，並萃取文章內容
#
for paragraph in content:
    print(paragraph.get_text())
# Out:
# 全球資訊網（英語：World Wide Web）亦作WWW、Web，是一個透過網際網路存取的，由許多互相連結的超文字組成的系統[1]。英國科學家提姆·柏內茲-李於1989年發明了全球資訊網。1990年他在瑞士CERN的工作期間編寫了第一個網頁瀏覽器[2][3]。網頁瀏覽器於1991年在CERN以外發行，1991年1月最先向其他研究機構發行，並於1991年8月在網際網路上向公眾開放。
#
# 全球資訊網是資訊時代發展的核心，也是數十億人在網際網路上進行互動的主要工具[4][5][6]。網頁主要是文字檔案格式化和超文件標示語言（HTML）。除了格式化文字之外，網頁還可能包含圖片、影片、聲音和軟體元件，這些元件會在使用者的網頁瀏覽器中呈現為多媒體內容的連貫頁面。
#
# 全球資訊網並不等同網際網路，全球資訊網只是網際網路所能提供的服務其中之一，是靠著網際網路運行的一項服務。
#
# 最早的構想可以追溯到遙遠的1980年提姆·柏內茲-李構建的ENQUIRE專案。這是一個類似維基百科的超文字線上編輯資料庫。儘管這與我們現在使用的全球資訊網大不相同，但是它們有許多相同的核心思想，甚至還包括一些柏內茲-李的全球資訊網之後的下一個專案語意網中的構想。
#
# 1989年3月，柏內茲.李撰寫了《關於資訊化管理的建議》一文，文中提及ENQUIRE並且描述了一個更加精巧的管理模型[7]。1990年11月12日他和羅伯特·卡里奧合作提出了一個更加正式的關於全球資訊網的建議[8]。在1990年11月13日他在一台NeXT工作站上寫了第一個網頁以實現他文中的想法[9]。
#
# 在那年的聖誕節，柏內茲-李製作了要讓網路工作的所有必要工具[10]：第一個網頁瀏覽器WorldWideWeb（同時也是網頁編輯器）和第一個網頁伺服器。
#
# 1991年8月6日，他在alt.hypertext新聞群組上貼了全球資訊網專案簡介的文章[11]。這一天也標誌著網際網路上全球資訊網公共服務的首次亮相。
#
# 全球資訊網中至關重要的概念─超文字，起源於1960年代的幾個從前的專案。譬如泰德·尼爾森的仙那度計劃（英語：Project Xanadu）和道格拉斯·英格巴特的NLS（英語：NLS (computer system)）。而這兩個專案的靈感都是來源於萬尼瓦爾·布希在其1945年的論文《和我們想得一樣》中為微縮膠片設計的Memex（英語：Memex）系統。
#
# 提姆·柏內茲-李的另一個才華橫溢的突破是將超文字嫁接到網際網路上。在他的《一千零一網》一書中解釋，他曾多次向技術社群的成員暗示這兩種技術結合是可行的，但是卻沒有任何人接受他的建議，他最後只好自己解決了這個計劃。他發明了三項關鍵技術：
#
# 全球資訊網和其他超文字系統有很多不同之處。全球資訊網上需要單項連接而不是雙向連接，這使得任何人可以在資源擁有者不作任何行動情況下連結該資源。和早期的網路系統相比，這一點對於減少實現網路伺服器和網路瀏覽器的困難至關重要，但它的副作用是產生了連結失效（英語：Link rot）的慢性問題。全球資訊網不像某些應用軟體如HyperCard，它不是私有的，這使得伺服器和客戶端能夠獨立地發展和擴充，而不受許可限制。
#
# 1993年4月30日，歐洲核子研究組織宣布全球資訊網對任何人免費開放，並不收取任何費用[13]。兩個月之後Gopher協定宣布不再是免費使用，造成大量用戶從Gopher轉向全球資訊網。早期流行的網頁瀏覽器是用於Unix和X Windows系統的ViolaWWW。
#
# 學者普遍認為，全球資訊網的一個轉折點始於1993年推出的Mosaic網頁瀏覽器[14][15]，這是由伊利諾大學厄巴納-香檳分校（NCSA-UIUC）的國家超級電腦應用中心團隊所開發的圖形介面瀏覽器，由馬克·安德森領導。Mosaic的資金來自美國高速運算及通訊計劃（High-Performance Computing and Communications Initiative）和高速運算及通訊法案（High Performance Computing and Communication Act of 1991），這是美國參議員艾爾·高爾所發起的幾項運算發展計劃（英語：Al Gore and information technology）之一[16]。在Mosaic發布之前，網頁中的圖片和文字混合並不常見，全球資訊網的受歡迎程度遠低於網際網路上使用的舊協定，例如Gopher和WAIS。Mosaic的圖形使用介面讓全球資訊網成為迄今為止最受歡迎的網際網路協定。
#
# 1994年10月，全球資訊網協會（W3C）在麻省理工學院電腦科學實驗室成立，建立者是全球資訊網的發明者提姆·柏內茲-李。到了1994年底，全球網站數量仍然相對稀少，但是很多著名網站（英語：List of websites founded before 1995）已經相當活躍，這些網站已經預示或者啟發了當今最流行的服務。
#
# 透過網際網路，世界各地都建立了其他網站。這促進了協定和格式化的國際標準發展。柏內茲-李繼續參與指導全球資訊網標準的開發，例如編寫網頁的標記式語言和他提倡的語義網願景。全球資訊網透過一種易於使用和靈活的格式，使資訊在網際網路上傳播。因此，全球資訊網對於網際網路的普及發揮了重要的作用[17]。雖然這兩個詞語有時被混在一起使用，但全球資訊網並不是網際網路的同義詞[18]。全球資訊網是一個資訊空間（英語：Information space），包含超連結文件和其他資源，由其URIs標識[19]。它使用網際網路協定如TCP/IP和HTTP實作為客戶端和伺服器端軟體。
#
# 網際網路和全球資訊網這兩個詞語經常沒有太大的區別被使用。然而，這兩個詞語的意思並不相同。網際網路是一個全球互相連接的電腦網路系統。相較之下，全球資訊網是由超連結和統一資源標誌符連接的檔案和其他資源的全球集合。全球資訊網資源通常使用HTTP或HTTPS存取，是網際網路通訊協定的其中之一[20]。
#
# 若要進入全球資訊網上一個網頁，或者其他網路資源的時候，通常需瀏覽器上鍵入你想存取網頁的統一資源定位符（URL），或者通過超連結方式連結到那個網頁或網路資源。這之後的工作首先是URL的伺服器名部分，被名為域名系統的分布於全球的網際網路資料庫解析，並根據解析結果決定進入哪一個IP位址（IP Address）。
#
# 接下來的步驟是為所要存取的網頁，向在那個IP位址工作的伺服器傳送一個HTTP請求。在通常情況下，HTML文字、圖片和構成該網頁的一切其他檔案很快會被逐一請求並行送回用戶。
#
# 網路瀏覽器接下來的工作是把HTML、CSS和其他接受到的檔案所描述的內容，加上圖像、連結和其他必須的資源，顯示給用戶。這些就構成了你所看到的「網頁」。
#
# 大多數的網頁自身包含有超連結指向其他相關網頁，可能還有下載、源文獻、定義和其他網路資源。像這樣通過超連結，把有用的相關資源組織在一起的集合，就形成了一個所謂的資訊的「網」。這個網在網際網路上被方便使用，就構成了最早在1990年代初提姆·柏內茲-李所說的全球資訊網[21][22]。
#
# 網路獨立於大眾傳媒而被大家使用。如果你要發布一個網頁，你不需要去拜訪出版商或者任何其他傳媒機構，而且你潛在的讀者可能遍布於世界各地。
#
# 與傳統書籍文獻不同，超文字沒有一個線性的順序從頭到尾。它不能分解成章，節，段等層次。
#
# 現在在全球資訊網上可以尋找到不同種類的資訊，你想了解其他的國家以及那裡的風土人情變得十分容易。當你在外國或者一個偏僻的小鎮旅遊的時候，你可以通過網路找到關於這個地方的資訊，尤其是如果是在一個已開發國家的話。當地的報紙，官方出版物和其他資料都可以非常容易找到，因此你可以通過網路找到更多種類的相關資訊。
#
# 儘管有些站點有多種語言的版本，但是大部分站點只有當地語言版本。而且，不是所有的軟體都能很好地支援所有的特殊字元和那些從右向左寫的語言（如阿拉伯語或希伯來語）。這些因素使得關於全球資訊網讓地球融為地球村的觀點受到挑戰。
#
# 隨著大量的免費網路首頁伺服器的出現，湧現出了無數的個人首頁以及家庭首頁，小商店的首頁等等，在網路上發布資料顯而易見地越來越容易。
#
# JavaScript是一種處理網頁的手稿語言。其標準版本是ECMAScript[23]，由網景通訊公司提交給歐洲標準協會制訂。儘管它的名字和Java類似，但是它是由網景公司開發的而不是由昇陽電腦公司開發的，除了兩者的語法都是從C語言發展而來這一點外，它們之間幾乎沒有什麼關係。之所以叫JavaScript，只是當時網景公司希望能藉助Java的名氣推廣它。和Java一樣，JavaScript類似C++是一種支援物件導向的程式設計的語言，和C++相同的是它允許混合代碼，即物件導向的和基於過程的代碼可以同時存在。由於網頁瀏覽器中，JavaScript與文件物件模型（Document Object Model）緊密結合，能夠很好地處理網頁，使得它比它的作者原本預期的要有用得多。它的用途可以用術語DHTML（動態HTML）表達，以強調它和靜態HTML網頁的區別。
#
# 儘管英文單詞「worldwide」通常被寫為一個詞（沒有空格或者連字元），全稱「World Wide Web」和其簡稱「WWW」現在在一些正規的英文中也被廣泛使用。最早的文獻談到全球資訊網稱其為「WorldWideWeb」（為一駝峰式大小寫）或者「World-Wide Web」（加了連字元，這樣這個版本的名字最接近正式的英語用法）。有趣的是，「WWW」成為了英文中少數的簡稱的音節比本來名字的音節更長的簡稱。在英語裡，「World Wide Web」共三個音節，而單單一個W字母就有三個音節。
#
# 1994年6月，在北美留學的李小文（後來成為中國科學院院士）於中國新聞電腦網路（CND）的電子出版物《華夏文摘》上首次將「World Wide Web」稱為「萬維天羅地網」，簡稱「萬維網」[24]，這樣其中文名稱漢語拼音也是以WWW開始，自此「萬維網」這一名稱開始被廣泛採用。
#
# 全球資訊網的核心部分是由三個標準構成的：
#
# 提姆·柏內茲-李現在是全球資訊網協會（W3C）的領導人，這個組織的作用是使電腦能夠在全球資訊網上不同形式的資訊間更有效的儲存和通信。
#
# 據2001年一份研究表明，全球資訊網上有超過5500億份文件，大多數檔案在不可見的「深網」[25]。2002年一份通過20億2千4百萬網頁調查[26] 表明至今大多數的網頁內容是用英語寫成的，為56.4%；之後是德語（7.7%），法語（5.6%）和日語（4.9%）。但是中文站點的增長也很快。一份最近的研究通過在75種語言的網路調查取樣表明，到2005年1月為止，有超過115億個網頁在公共索引頁面中[27]。
#
# 由於網際網路的基礎結構的缺陷，造成的網路堵塞（英語：Network_congestion#Congestive_collapse）問題和顯現為瀏覽速度的減慢的延遲，經常讓人很煩。知名網站techweb甚至因此戲稱全球資訊網應改成World Wide Wait（全球等）[28]。利用點對點技術和服務品質來提高網際網路的速度的討論一直在進行。其他解決方案也可以在W3C的網站上找到。
#
# 和WWW有關的主要學術會議為IW3C2。發起的全球資訊網系列會議。這是有關這一系列會議的連結
#
# 2019年3月12日，Google更改Google doodle，以紀念全球資訊網發明30周年。[29]

# %% [markdown]
# ### 範例2：從爬取的文章內容中，擷取出有外部連結的關鍵字。這些關鍵字在文章中是以藍色字體顯示，會連到外部的網頁，並解釋其內容。

# %%
for ext_link in content:
    a_tag = ext_link.find_all('a', href=re.compile("^(/wiki/)((?!;)\S)*$"))
    if len(a_tag) > 0:
        for link_string in a_tag:
            a_link = link_string["href"]       # 外部連結的網址
            a_keyword = link_string.get_text()  # 外部連結的中文名稱
            print("外部連結: [%s] %s" % (a_keyword, a_link))
# Out:
# 外部連結: [網際網路] /wiki/%E4%BA%92%E8%81%94%E7%BD%91
# 外部連結: [超文字] /wiki/%E8%B6%85%E6%96%87%E6%9C%AC
# 外部連結: [提姆·柏內茲-李] /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E
# 外部連結: [CERN] /wiki/CERN
# 外部連結: [網頁瀏覽器] /wiki/%E7%B6%B2%E9%A0%81%E7%80%8F%E8%A6%BD%E5%99%A8
# 外部連結: [資訊時代] /wiki/%E8%B3%87%E8%A8%8A%E6%99%82%E4%BB%A3
# 外部連結: [網頁] /wiki/%E7%B6%B2%E9%A0%81
# 外部連結: [格式化] /wiki/%E6%A0%BC%E5%BC%8F%E5%8C%96%E6%96%87%E6%9C%AC
# 外部連結: [超文件標示語言] /wiki/%E8%B6%85%E6%96%87%E4%BB%B6%E6%A8%99%E7%A4%BA%E8%AA%9E%E8%A8%80
# 外部連結: [圖片] /wiki/%E5%9C%96%E7%89%87
# 外部連結: [影片] /wiki/%E5%BD%B1%E7%89%87
# 外部連結: [聲音] /wiki/%E8%81%B2%E9%9F%B3
# 外部連結: [多媒體] /wiki/%E5%A4%9A%E5%AA%92%E9%AB%94
# 外部連結: [網際網路] /wiki/%E7%B6%B2%E9%9A%9B%E7%B6%B2%E8%B7%AF
# 外部連結: [提姆·柏內茲-李] /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E
# 外部連結: [ENQUIRE] /wiki/ENQUIRE
# 外部連結: [資料庫] /wiki/%E6%95%B0%E6%8D%AE%E5%BA%93
# 外部連結: [語意網] /wiki/%E8%AF%AD%E4%B9%89%E7%BD%91
# 外部連結: [羅伯特·卡里奧] /wiki/%E7%BD%97%E4%BC%AF%E7%89%B9%C2%B7%E5%8D%A1%E9%87%8C%E5%A5%A5
# 外部連結: [NeXT] /wiki/NeXT
# 外部連結: [聖誕節] /wiki/%E8%81%96%E8%AA%95%E7%AF%80
# 外部連結: [網頁瀏覽器] /wiki/%E7%B6%B2%E9%A0%81%E7%80%8F%E8%A6%BD%E5%99%A8
# 外部連結: [WorldWideWeb] /wiki/WorldWideWeb
# 外部連結: [網頁伺服器] /wiki/%E7%B6%B2%E9%A0%81%E4%BC%BA%E6%9C%8D%E5%99%A8
# 外部連結: [新聞群組] /wiki/%E6%96%B0%E9%97%BB%E7%BB%84
# 外部連結: [超文字] /wiki/%E8%B6%85%E6%96%87%E6%9C%AC
# 外部連結: [泰德·尼爾森] /wiki/%E6%B3%B0%E5%BE%B7%C2%B7%E5%B0%BC%E7%88%BE%E6%A3%AE
# 外部連結: [道格拉斯·英格巴特] /wiki/%E9%81%93%E6%A0%BC%E6%8B%89%E6%96%AF%C2%B7%E8%8B%B1%E6%A0%BC%E5%B7%B4%E7%89%B9
# 外部連結: [萬尼瓦爾·布希] /wiki/%E4%B8%87%E5%B0%BC%E7%93%A6%E5%B0%94%C2%B7%E5%B8%83%E4%BB%80
# 外部連結: [微縮膠片] /wiki/%E5%BE%AE%E7%BC%A9%E8%83%B6%E7%89%87
# 外部連結: [一千零一網] /wiki/%E4%B8%80%E5%8D%83%E9%9B%B6%E4%B8%80%E7%B6%B2%EF%BC%9A%E7%B6%B2%E9%9A%9B%E7%B6%B2%E8%B7%AFWWW%E7%99%BC%E6%98%8E%E4%BA%BA%E7%9A%84%E6%80%9D%E6%83%B3%E6%A7%8B%E5%9C%96
# 外部連結: [HyperCard] /wiki/HyperCard
# 外部連結: [歐洲核子研究組織] /wiki/%E6%AD%90%E6%B4%B2%E6%A0%B8%E5%AD%90%E7%A0%94%E7%A9%B6%E7%B5%84%E7%B9%94
# 外部連結: [Gopher] /wiki/Gopher_(%E7%BD%91%E7%BB%9C%E5%8D%8F%E8%AE%AE)
# 外部連結: [Unix] /wiki/Unix
# 外部連結: [X Windows] /wiki/X_Windows
# 外部連結: [ViolaWWW] /wiki/ViolaWWW
# 外部連結: [Mosaic] /wiki/Mosaic
# 外部連結: [伊利諾大學厄巴納-香檳分校] /wiki/%E4%BC%8A%E5%88%A9%E8%AB%BE%E5%A4%A7%E5%AD%B8%E5%8E%84%E5%B7%B4%E7%B4%8D-%E9%A6%99%E6%AA%B3%E5%88%86%E6%A0%A1
# 外部連結: [國家超級電腦應用中心] /wiki/%E5%9B%BD%E5%AE%B6%E8%B6%85%E7%BA%A7%E7%94%B5%E8%84%91%E5%BA%94%E7%94%A8%E4%B8%AD%E5%BF%83
# 外部連結: [馬克·安德森] /wiki/%E9%A9%AC%E5%85%8B%C2%B7%E5%AE%89%E5%BE%B7%E6%A3%AE
# 外部連結: [艾爾·高爾] /wiki/%E8%89%BE%E7%88%BE%C2%B7%E9%AB%98%E7%88%BE
# 外部連結: [Gopher] /wiki/Gopher_(%E7%BD%91%E7%BB%9C%E5%8D%8F%E8%AE%AE)
# 外部連結: [全球資訊網協會] /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91%E8%81%94%E7%9B%9F
# 外部連結: [麻省理工學院] /wiki/%E9%BA%BB%E7%9C%81%E7%90%86%E5%B7%A5%E5%AD%A6%E9%99%A2
# 外部連結: [提姆·柏內茲-李] /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E
# 外部連結: [標記式語言] /wiki/%E6%A8%99%E8%A8%98%E5%BC%8F%E8%AA%9E%E8%A8%80
# 外部連結: [語義網] /wiki/%E8%AA%9E%E7%BE%A9%E7%B6%B2
# 外部連結: [同義詞] /wiki/%E5%90%8C%E4%B9%89%E8%AF%8D
# 外部連結: [TCP/IP] /wiki/TCP/IP
# 外部連結: [HTTP] /wiki/HTTP
# 外部連結: [電腦網路] /wiki/%E7%94%B5%E8%84%91%E7%BD%91%E7%BB%9C
# 外部連結: [HTTP] /wiki/HTTP
# 外部連結: [HTTPS] /wiki/HTTPS
# 外部連結: [統一資源定位符] /wiki/%E7%BB%9F%E4%B8%80%E8%B5%84%E6%BA%90%E5%AE%9A%E4%BD%8D%E7%AC%A6
# 外部連結: [域名系統] /wiki/%E5%9F%9F%E5%90%8D%E7%B3%BB%E7%BB%9F
# 外部連結: [IP位址] /wiki/IP%E5%9C%B0%E5%9D%80
# 外部連結: [大眾傳媒] /wiki/%E5%A4%A7%E7%9C%BE%E5%82%B3%E5%AA%92
# 外部連結: [出版商] /wiki/%E5%87%BA%E7%89%88%E5%95%86
# 外部連結: [已開發國家] /wiki/%E5%8F%91%E8%BE%BE%E5%9B%BD%E5%AE%B6
# 外部連結: [阿拉伯語] /wiki/%E9%98%BF%E6%8B%89%E4%BC%AF%E8%AF%AD
# 外部連結: [希伯來語] /wiki/%E5%B8%8C%E4%BC%AF%E6%9D%A5%E8%AF%AD
# 外部連結: [伺服器] /wiki/%E6%9C%8D%E5%8A%A1%E5%99%A8
# 外部連結: [個人首頁] /wiki/%E4%B8%AA%E4%BA%BA%E4%B8%BB%E9%A1%B5
# 外部連結: [JavaScript] /wiki/JavaScript
# 外部連結: [ECMAScript] /wiki/ECMAScript
# 外部連結: [網景通訊公司] /wiki/Netscape
# 外部連結: [Java] /wiki/Java
# 外部連結: [昇陽電腦公司] /wiki/%E6%98%87%E9%99%BD%E9%9B%BB%E8%85%A6
# 外部連結: [C語言] /wiki/C%E8%AF%AD%E8%A8%80
# 外部連結: [C++] /wiki/C%2B%2B
# 外部連結: [物件導向的程式設計] /wiki/%E9%9D%A2%E5%90%91%E5%AF%B9%E8%B1%A1%E7%9A%84%E7%A8%8B%E5%BA%8F%E8%AE%BE%E8%AE%A1
# 外部連結: [C++] /wiki/C%2B%2B
# 外部連結: [文件物件模型] /wiki/%E6%96%87%E6%A1%A3%E5%AF%B9%E8%B1%A1%E6%A8%A1%E5%9E%8B
# 外部連結: [DHTML] /wiki/DHTML
# 外部連結: [駝峰式大小寫] /wiki/%E9%A7%9D%E5%B3%B0%E5%BC%8F%E5%A4%A7%E5%B0%8F%E5%AF%AB
# 外部連結: [北美] /wiki/%E5%8C%97%E7%BE%8E
# 外部連結: [李小文] /wiki/%E6%9D%8E%E5%B0%8F%E6%96%87
# 外部連結: [中國科學院院士] /wiki/%E4%B8%AD%E5%9B%BD%E7%A7%91%E5%AD%A6%E9%99%A2%E9%99%A2%E5%A3%AB
# 外部連結: [中國新聞電腦網路] /wiki/%E4%B8%AD%E5%9C%8B%E6%96%B0%E8%81%9E%E9%9B%BB%E8%85%A6%E7%B6%B2%E7%B5%A1
# 外部連結: [華夏文摘] /wiki/%E8%8F%AF%E5%A4%8F%E6%96%87%E6%91%98
# 外部連結: [漢語拼音] /wiki/%E6%BC%A2%E8%AA%9E%E6%8B%BC%E9%9F%B3
# 外部連結: [標準] /wiki/%E6%A0%87%E5%87%86
# 外部連結: [全球資訊網協會] /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91%E8%81%94%E7%9B%9F
# 外部連結: [深網] /wiki/%E6%B7%B1%E7%BD%91
# 外部連結: [網頁] /wiki/%E7%BD%91%E9%A1%B5
# 外部連結: [英語] /wiki/%E8%8B%B1%E8%AF%AD
# 外部連結: [德語] /wiki/%E5%BE%B7%E8%AF%AD
# 外部連結: [法語] /wiki/%E6%B3%95%E8%AF%AD
# 外部連結: [日語] /wiki/%E6%97%A5%E8%AF%AD
# 外部連結: [中文] /wiki/%E4%B8%AD%E6%96%87
# 外部連結: [語言] /wiki/%E8%AF%AD%E8%A8%80
# 外部連結: [網際網路] /wiki/%E5%9B%A0%E7%89%B9%E7%BD%91
# 外部連結: [點對點技術] /wiki/%E9%BB%9E%E5%B0%8D%E9%BB%9E%E6%8A%80%E8%A1%93
# 外部連結: [服務品質] /wiki/QoS
# 外部連結: [Google] /wiki/Google
# 外部連結: [Google doodle] /wiki/Google_doodle

# %% [markdown]
# ## 作業：接下來定義一個爬蟲函數，這個函數的主要工作為：
# ### (1) 爬取當前關鍵字的解釋，並存入檔案(因為文章內容太多會佔滿整個頁面，所以存程檔案，方便後續檢視)
# ### (2) 萃取出當前關鍵字所引用的外部連結，當作新的查詢關鍵字
# ### (3) 把第(2)擷取到的關鍵字當作新的關鍵字，回到第(1)步，爬取新的關鍵字解釋。

# %%
import os

def WikiArticle(key_word_link, key_word, recursive):
    
    if (recursive <= max_recursive_depth):
        print("遞迴層[%d] - %s (%s)" % (recursive, key_word_link, key_word))
        
        # 模擬封包的標頭
        headers = {
            'authority': 'zh.wikipedia.org',
            'method': 'GET',
            'path': '/wiki/' + key_word_link,
            'scheme': 'https',
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
            'accept-encoding': 'gzip, deflate, br',
            'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
            'cookie': 'GeoIP=TW:TPE:Taipei:25.05:121.53:v4; TBLkisOn=0; mwPhp7Seed=8b8; WMF-Last-Access-Global=04-Jun-2019; WMF-Last-Access=04-Jun-2019',
            'dnt': '1',
            #'if-modified-since': 'Tue, 04 Jun 2019 12:03:22 GMT',
            'referer': 'https://zh.wikipedia.org/wiki/Wikipedia:%E9%A6%96%E9%A1%B5',
            'upgrade-insecure-requests': '1',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
        }    

        url = 'https://zh.wikipedia.org' + key_word_link  # 組合關鍵字查詢URL
        resp = requests.get(url, headers=headers)
        resp.encoding = 'utf-8'

        html = BeautifulSoup(resp.text, "lxml")
        content = html.find(name='div', attrs={'id':'mw-content-text'}).find_all(name='p')
        
        #
        # Part 1: 請參考範例1，爬取當前關鍵字的文章內容。
        #         因為內容太多，我們把它寫入檔案，並以關鍵字作為檔案名稱，以便稍後查閱內容。
        #         請先建立一個名為"WikiArticle"的資料夾，爬取到的文章內容會放在這個資料夾底下。
        #
        '''
        
        Your code here
        
        '''
        try:
          os.mkdir("WikiArticl")
        except:
          pass  

        #
        # 解析回傳資料，並萃取文章內容
        #
        
        out_filename=os.path.join("WikiArticl",key_word+".html")
        out_filename=out_filename.replace("/","_")
        with open(out_filename,"w", encoding="utf-8") as out_file:
             for paragraph in content:
                 out_file.write(paragraph.get_text())
                 #print(paragraph.get_text())
    
        

        
        #
        # Part 2: 請參考範例2，萃取出本篇文章中所延伸引用的外部連結，並儲存在external_link_dict
        #
        external_link_dict = dict({})
        '''
        
        Your code here
        
        '''
        for ext_link in content:
            a_tag = ext_link.find_all('a', href=re.compile("^(/wiki/)((?!;)\S)*$"))
            if len(a_tag) > 0:
               for link_string in a_tag:
                   a_link = link_string["href"]       # 外部連結的網址
                   a_keyword = link_string.get_text()  # 外部連結的中文名稱
                   external_link_dict[a_link]=a_keyword
                   #print("外部連結: [%s] %s" % (a_keyword, a_link))

                    
        #
        # Part 3: 將Part 2所收集的外部連結，當作新的關鍵字，繼續迭代深入爬蟲
        #
        if (len(external_link_dict) > 0):
            
            recursive = recursive + 1  # 遞迴深度加1
            
            for k, v in external_link_dict.items():
                WikiArticle(k, v, recursive)  # 再次呼叫同樣的函數，執行同樣的流程

# %% [markdown]
# ### 執行前個步驟定義好的爬蟲主程式

# %%
# 定義爬取的遞迴深度。深度不要訂太深，否則會爬很久。
max_recursive_depth = 2

WikiArticle(root_keyword_link, input_keyword, 0)
# Out:
# 遞迴層[0] - /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 (全球資訊網)
# 遞迴層[1] - /wiki/%E4%BA%92%E8%81%94%E7%BD%91 (網際網路)
# 遞迴層[2] - /wiki/20%E4%B8%96%E7%B4%80 (20世紀)
# 遞迴層[2] - /wiki/%E7%94%B5%E8%84%91%E7%BD%91%E7%BB%9C (電腦網路)
# 遞迴層[2] - /wiki/%E7%B6%B2%E8%B7%AF (網路)
# 遞迴層[2] - /wiki/%E7%BD%91%E7%BB%9C%E5%8D%8F%E8%AE%AE (網路協定)
# 遞迴層[2] - /wiki/%E5%AD%B8%E8%A1%93%E7%95%8C (學術界)
# 遞迴層[2] - /wiki/%E7%94%B5%E5%AD%90%E6%8A%80%E6%9C%AF (電子)
# 遞迴層[2] - /wiki/%E7%84%A1%E7%B7%9A (無線)
# 遞迴層[2] - /wiki/%E5%85%89%E7%BA%96%E7%B6%B2%E8%B7%AF (光纖網路技術)
# 遞迴層[2] - /wiki/%E8%B6%85%E6%96%87%E6%9C%AC (超文字)
# 遞迴層[2] - /wiki/%E8%90%AC%E7%B6%AD%E7%B6%B2 (全球資訊網)
# 遞迴層[2] - /wiki/%E9%9B%BB%E5%AD%90%E9%83%B5%E4%BB%B6 (電子郵件)
# 遞迴層[2] - /wiki/%E7%B6%B2%E9%9A%9B%E5%8D%94%E8%AD%B0%E9%80%9A%E8%A9%B1%E6%8A%80%E8%A1%93 (通話)
# 遞迴層[2] - /wiki/%E6%AA%94%E6%A1%88%E5%88%86%E4%BA%AB (檔案分享)
# 遞迴層[2] - /wiki/TCP/IP (TCP/IP)
# 遞迴層[2] - /wiki/%E5%88%86%E6%95%A3%E7%BD%91%E7%BB%9C (分散網路)
# 遞迴層[2] - /wiki/%E6%8E%92%E9%98%9F%E8%AE%BA (排隊論)
# 遞迴層[2] - /wiki/%E5%B0%81%E5%8C%85%E4%BA%A4%E6%8F%9B (封包交換)
# 遞迴層[2] - /wiki/%E7%BE%8E%E5%9B%BD%E5%9B%BD%E9%98%B2%E9%83%A8 (美國國防部)
# 遞迴層[2] - /wiki/%E5%9C%8B%E9%98%B2%E9%AB%98%E7%AD%89%E7%A0%94%E7%A9%B6%E8%A8%88%E5%8A%83%E7%BD%B2 (高等研究計劃署)
# 遞迴層[2] - /wiki/%E5%86%B7%E6%88%98 (冷戰)
# 遞迴層[2] - /wiki/ARPA%E7%BD%91 (ARPA網)
# 遞迴層[2] - /wiki/%E8%8B%B1%E5%9B%BD (英國)
# 遞迴層[2] - /wiki/%E6%8C%AA%E5%A8%81 (挪威)
# 遞迴層[2] - /wiki/%E8%AE%A1%E7%AE%97%E6%9C%BA (電腦)
# 遞迴層[2] - /wiki/%E7%BD%97%E4%BC%AF%E7%89%B9%C2%B7%E5%8D%A1%E6%81%A9 (羅伯特·卡恩)
# 遞迴層[2] - /wiki/%E6%96%87%E9%A0%93%C2%B7%E7%91%9F%E5%A4%AB (文頓·瑟夫)
# 遞迴層[2] - /wiki/TCP/IP%E5%8D%8F%E8%AE%AE (TCP/IP協定)
# 遞迴層[2] - /wiki/%E5%9B%BE%E7%81%B5%E5%A5%96 (圖靈獎)
# 遞迴層[2] - /wiki/%E7%BD%91%E7%BB%9C%E6%8E%A7%E5%88%B6%E5%8D%8F%E8%AE%AE (NCP)
# 遞迴層[2] - /wiki/%E7%BE%8E%E5%9B%BD%E5%9B%BD%E5%AE%B6%E7%A7%91%E5%AD%A6%E5%9F%BA%E9%87%91%E4%BC%9A (美國國家科學基金會)
# 遞迴層[2] - /wiki/Usenet (Usenet)
# 遞迴層[2] - /wiki/Bitnet (Bitnet)
# 遞迴層[2] - /wiki/X.25 (X.25)
# 遞迴層[2] - /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E (提姆·柏內茲-李)
# 遞迴層[2] - /wiki/%E7%91%9E%E5%A3%AB (瑞士)
# 遞迴層[2] - /wiki/%E6%AD%90%E6%B4%B2%E6%A0%B8%E5%AD%90%E7%A0%94%E7%A9%B6%E7%B5%84%E7%B9%94 (歐洲核子研究組織)
# 遞迴層[2] - /wiki/HTML (HTML)
# 遞迴層[2] - /wiki/HTTP (HTTP)
# 遞迴層[2] - /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 (web)
# 遞迴層[2] - /wiki/FidoNet (FidoNet)
# 遞迴層[2] - /wiki/ARPANET (ARPA網)
# 遞迴層[2] - /wiki/%E7%BE%8E%E8%81%94%E7%A4%BE (美聯社)
# 遞迴層[2] - /wiki/%E7%BA%BD%E7%BA%A6%E6%97%B6%E6%8A%A5 (紐約時報)
# 遞迴層[2] - /wiki/%E7%B6%B2%E9%9A%9B%E7%B6%B2%E8%B7%AF%E5%8D%94%E5%AE%9A (網際網路協定)
# 遞迴層[2] - /wiki/IPv4 (IPv4)
# 遞迴層[2] - /wiki/IP%E5%9C%B0%E5%9D%80 (IP位址)
# 遞迴層[2] - /wiki/IPv6 (IPv6)
# 遞迴層[2] - /wiki/%E7%94%A8%E6%88%B7%E6%95%B0%E6%8D%AE%E6%8A%A5%E5%8D%8F%E8%AE%AE (UDP)
# 遞迴層[2] - /wiki/%E4%BC%A0%E8%BE%93%E6%8E%A7%E5%88%B6%E5%8D%8F%E8%AE%AE (TCP協定)
# 遞迴層[2] - /wiki/UDP (UDP)
# 遞迴層[2] - /wiki/%E6%96%87%E4%BB%B6%E4%BC%A0%E8%BE%93%E5%8D%8F%E8%AE%AE (FTP)
# 遞迴層[2] - /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E4%BC%A0%E8%BE%93%E5%8D%8F%E8%AE%AE (HTTP)
# 遞迴層[2] - /wiki/%E5%9E%83%E5%9C%BE%E9%82%AE%E4%BB%B6 (垃圾郵件)
# 遞迴層[2] - /wiki/%E8%A0%95%E8%99%AB%E7%97%85%E6%AF%92 (蠕蟲病毒)
# 遞迴層[2] - /wiki/%E6%83%A1%E6%84%8F%E8%BB%9F%E9%AB%94 (惡意軟體)
# 遞迴層[2] - /wiki/%E9%9B%BB%E8%85%A6%E7%97%85%E6%AF%92 (電腦病毒)
# 遞迴層[2] - /wiki/%E9%9B%BB%E8%85%A6%E8%A0%95%E8%9F%B2 (電腦蠕蟲)
# 遞迴層[2] - /wiki/%E9%98%BB%E6%96%B7%E6%9C%8D%E5%8B%99%E6%94%BB%E6%93%8A (阻斷服務攻擊)
# 遞迴層[2] - /wiki/%E5%8B%92%E7%B4%A2%E8%BB%9F%E9%AB%94 (勒索軟體)
# 遞迴層[2] - /wiki/%E6%AE%AD%E5%B1%8D%E7%B6%B2%E7%B5%A1 (殭屍網路)
# 遞迴層[2] - /wiki/%E9%96%93%E8%AB%9C%E8%BB%9F%E4%BB%B6 (間諜軟體)
# 遞迴層[2] - /wiki/%E7%94%B5%E8%84%91%E7%8A%AF%E7%BD%AA (網路犯罪)
# 遞迴層[2] - /wiki/%E8%85%BE%E8%AE%AFQQ (騰訊QQ)
# 遞迴層[2] - /wiki/Skype (Skype)
# 遞迴層[2] - /wiki/%E7%A1%AC%E4%BB%B6 (硬體)
# 遞迴層[2] - /wiki/%E9%98%B2%E7%81%AB%E5%A2%99 (防火牆)
# 遞迴層[2] - /wiki/%E4%B8%AD%E5%8D%8E%E4%BA%BA%E6%B0%91%E5%85%B1%E5%92%8C%E5%9B%BD (中華人民共和國)
# 遞迴層[2] - /wiki/%E6%B2%99%E7%89%B9%E9%98%BF%E6%8B%89%E4%BC%AF (沙烏地阿拉伯)
# 遞迴層[2] - /wiki/%E6%94%BF%E6%B2%BB (政治)
# 遞迴層[2] - /wiki/%E5%AE%97%E6%95%99 (宗教)
# 遞迴層[2] - /wiki/%E4%BF%A1%E6%81%AF%E6%8A%80%E6%9C%AF (資訊科技)
# 遞迴層[2] - /wiki/%E6%9C%9D%E9%B2%9C (朝鮮)
# 遞迴層[2] - /wiki/%E9%98%B2%E7%81%AB%E9%95%BF%E5%9F%8E (防火長城)
# 遞迴層[2] - /wiki/%E7%BE%8E%E5%9C%8B%E5%9C%8B%E5%AE%B6%E5%AE%89%E5%85%A8%E5%B1%80 (美國國家安全域)
# 遞迴層[2] - /wiki/%E4%B8%AD%E6%83%85%E5%B1%80 (中情局)
# 遞迴層[2] - /wiki/%E7%88%B1%E5%BE%B7%E5%8D%8E%C2%B7%E6%96%AF%E8%AF%BA%E7%99%BB (史諾登)
# 遞迴層[2] - /wiki/%E8%A1%9B%E5%A0%B1 (衛報)
# 遞迴層[2] - /wiki/%E8%8F%AF%E7%9B%9B%E9%A0%93%E9%83%B5%E5%A0%B1 (華盛頓郵報)
# 遞迴層[2] - /wiki/%E7%B6%93%E6%BF%9F%E5%90%88%E4%BD%9C%E7%99%BC%E5%B1%95%E7%B5%84%E7%B9%94 (經濟合作發展組織)
# 遞迴層[2] - /wiki/%E5%86%B0%E5%B3%B6 (冰島)
# 遞迴層[2] - /wiki/%E9%9F%A9%E5%9B%BD (韓國)
# 遞迴層[2] - /wiki/%E8%8D%B7%E8%98%AD (荷蘭)
# 遞迴層[2] - /wiki/%E4%B8%B9%E9%BA%A5 (丹麥)
# 遞迴層[2] - /wiki/%E7%BE%8E%E5%9C%8B (美國)
# 遞迴層[2] - /wiki/%E4%B8%AD%E5%9B%BD%E4%BA%92%E8%81%94%E7%BD%91%E7%BB%9C%E4%BF%A1%E6%81%AF%E4%B8%AD%E5%BF%83 (中國互聯網絡信息中心)
# 遞迴層[2] - /wiki/%E7%BD%91%E6%B0%91 (網友)
# 遞迴層[1] - /wiki/%E8%B6%85%E6%96%87%E6%9C%AC (超文字)
# 遞迴層[2] - /wiki/%E9%9B%BB%E8%85%A6%E9%A1%AF%E7%A4%BA%E5%99%A8 (電腦顯示器)
# 遞迴層[2] - /wiki/%E9%9B%BB%E5%AD%90%E8%A8%AD%E5%82%99 (電子裝置)
# 遞迴層[2] - /wiki/%E8%B6%85%E9%80%A3%E7%B5%90 (超連結)
# 遞迴層[2] - /wiki/%E8%B1%AA%E5%B0%94%E8%B5%AB%C2%B7%E8%B7%AF%E6%98%93%E6%96%AF%C2%B7%E5%8D%9A%E5%B0%94%E8%B5%AB%E6%96%AF (豪爾赫·路易斯·博爾赫斯)
# 遞迴層[2] - /wiki/%E7%9F%AD%E7%AF%87%E5%B0%8F%E8%AA%AA (短篇小說)
# 遞迴層[2] - /wiki/%E4%B8%87%E5%B0%BC%E7%93%A6%E5%B0%94%C2%B7%E5%B8%83%E4%BB%80 (萬尼瓦爾·布希)
# 遞迴層[2] - /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 (全球資訊網)
# 遞迴層[1] - /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E (提姆·柏內茲-李)
# 遞迴層[2] - /wiki/%E5%8A%9F%E7%B8%BE%E5%8B%B3%E7%AB%A0_(%E8%8B%B1%E5%9C%8B) (OM)
# 遞迴層[2] - /wiki/%E5%B7%B4%E6%96%AF%E5%8B%8B%E7%AB%A0 (KBE)
# 遞迴層[2] - /wiki/%E7%9A%87%E5%AE%B6%E5%AD%B8%E6%9C%83%E9%99%A2%E5%A3%AB (FRS)
# 遞迴層[2] - /wiki/%E7%9A%87%E5%AE%B6%E5%B7%A5%E7%A8%8B%E9%99%A2 (FREng)
# 遞迴層[2] - /wiki/%E7%9A%87%E5%AE%B6%E6%96%87%E8%89%BA%E5%AD%A6%E4%BC%9A (FRSA)
# 遞迴層[2] - /wiki/%E8%8B%B1%E5%9C%8B%E9%9B%BB%E8%85%A6%E5%AD%B8%E6%9C%83 (FBCS)
# 遞迴層[2] - /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 (全球資訊網)
# 遞迴層[2] - /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E4%BC%A0%E8%BE%93%E5%8D%8F%E8%AE%AE (超文字傳輸協定)
# 遞迴層[2] - /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91%E8%81%94%E7%9B%9F (全球資訊網協會)
# 遞迴層[2] - /wiki/%E9%BA%BB%E7%9C%81%E7%90%86%E5%B7%A5%E5%AD%A6%E9%99%A2%E8%AE%A1%E7%AE%97%E6%9C%BA%E7%A7%91%E5%AD%A6%E5%8F%8A%E4%BA%BA%E5%B7%A5%E6%99%BA%E8%83%BD%E5%AE%9E%E9%AA%8C%E5%AE%A4 (麻省理工學院電腦科學及人工智慧實驗室)
# 遞迴層[2] - /wiki/%E7%A6%8F%E7%89%B9%E5%9F%BA%E9%87%91%E6%9C%83 (福特基金會)
# 遞迴層[2] - /wiki/%E4%BC%8A%E4%B8%BD%E8%8E%8E%E7%99%BD%E4%BA%8C%E4%B8%96 (伊麗莎白二世)
# 遞迴層[2] - /wiki/%E5%A4%A7%E8%8B%B1%E5%B8%9D%E5%9B%BD%E5%8B%8B%E7%AB%A0 (大英帝國爵級司令勳章)
# 遞迴層[2] - /wiki/%E7%BE%8E%E5%9B%BD%E5%9B%BD%E5%AE%B6%E7%A7%91%E5%AD%A6%E9%99%A2 (美國國家科學院)
# 遞迴層[2] - /wiki/%E6%99%82%E4%BB%A3_(%E9%9B%9C%E8%AA%8C) (時代)
# 遞迴層[2] - /wiki/%E6%97%B6%E4%BB%A3100%E4%BA%BA%EF%BC%9A%E6%9C%AC%E4%B8%96%E7%BA%AA%E6%9C%80%E9%87%8D%E8%A6%81%E7%9A%84%E4%BA%BA%E7%89%A9 (時代100人：本世紀最重要的人物)
# 遞迴層[2] - /wiki/2012%E5%B9%B4%E5%A4%8F%E5%AD%A3%E5%A5%A7%E6%9E%97%E5%8C%B9%E5%85%8B%E9%81%8B%E5%8B%95%E6%9C%83%E9%96%8B%E5%B9%95%E5%85%B8%E7%A6%AE (2012年夏季奧林匹克運動會開幕典禮)
# 遞迴層[2] - /wiki/NeXT (NeXT)
# 遞迴層[2] - /wiki/Twitter (Twitter)
# 遞迴層[2] - /wiki/%E6%B6%B2%E6%99%B6%E6%98%BE%E7%A4%BA%E5%99%A8 (液晶顯示器)
# 遞迴層[2] - /wiki/%E5%9B%BE%E7%81%B5%E5%A5%96 (圖靈獎)
# 遞迴層[2] - /wiki/%E6%9B%BC%E5%88%87%E6%96%AF%E7%89%B91%E5%9E%8B (曼切斯特1型)
# 遞迴層[2] - /wiki/%E9%90%B5%E9%81%93%E8%BF%B7 (鐵道迷)
# 遞迴層[2] - /wiki/%E7%89%9B%E6%B4%A5%E5%A4%A7%E5%AD%A6%E7%8E%8B%E5%90%8E%E5%AD%A6%E9%99%A2 (牛津大學王后學院)
# 遞迴層[2] - /wiki/%E6%99%AE%E7%88%BE (普爾)
# 遞迴層[2] - /wiki/%E6%97%A5%E5%85%A7%E7%93%A6 (日內瓦)
# 遞迴層[2] - /wiki/%E6%AD%90%E6%B4%B2%E6%A0%B8%E5%AD%90%E7%A0%94%E7%A9%B6%E7%B5%84%E7%B9%94 (歐洲核子研究組織)
# 遞迴層[2] - /wiki/%E7%8D%A8%E7%AB%8B%E5%90%88%E5%90%8C%E4%BA%BA (獨立承包人)
# 遞迴層[2] - /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E7%B3%BB%E7%BB%9F (超文字系統)
# 遞迴層[2] - /wiki/ENQUIRE (ENQUIRE)
# 遞迴層[2] - /wiki/%E4%BC%AF%E6%81%A9%E8%8C%85%E6%96%AF (伯恩茅斯)
# 遞迴層[2] - /wiki/%E8%BF%9C%E7%A8%8B%E8%BF%87%E7%A8%8B%E8%B0%83%E7%94%A8 (遠端程序呼叫)
# 遞迴層[2] - /wiki/%E8%AE%A1%E7%AE%97%E6%9C%BA%E7%BD%91%E7%BB%9C (電腦網路)
# 遞迴層[2] - /wiki/%E7%BD%91%E9%A1%B5%E6%B5%8F%E8%A7%88%E5%99%A8 (網頁瀏覽器)
# 遞迴層[2] - /wiki/WorldWideWeb (WorldWideWeb)
# 遞迴層[2] - /wiki/NeXTSTEP (NeXTSTEP)
# 遞迴層[2] - /wiki/CERN_httpd (CERN httpd)
# 遞迴層[2] - /wiki/%E5%AE%88%E6%8A%A4%E8%BF%9B%E7%A8%8B (守護行程)
# 遞迴層[2] - /wiki/%E7%BD%91%E7%AB%99 (網站)
# 遞迴層[2] - /wiki/%E5%8D%97%E5%AE%89%E6%99%AE%E6%95%A6%E5%A4%A7%E5%AD%A6 (南安普敦大學)
# 遞迴層[2] - /wiki/%E8%AF%AD%E4%B9%89%E7%BD%91 (語意網)
# 遞迴層[2] - /wiki/%E6%B3%B0%E6%99%A4%E5%A3%AB%E6%8A%A5 (泰晤士報)
# 遞迴層[2] - /wiki/%E6%88%88%E7%99%BB%C2%B7%E5%B8%83%E6%9C%97 (戈登·布朗)
# 遞迴層[2] - /wiki/%E8%8B%B1%E5%9C%8B%E5%9C%B0%E5%BD%A2%E6%B8%AC%E9%87%8F%E5%B1%80 (英國地形測量局)
# 遞迴層[2] - /wiki/%E7%BD%91%E7%BB%9C%E4%B8%AD%E7%AB%8B%E6%80%A7 (網路中立性)
# 遞迴層[2] - /wiki/%E4%BA%92%E8%81%94%E7%BD%91%E6%9C%8D%E5%8A%A1%E4%BE%9B%E5%BA%94%E5%95%86 (網際網路服務供應商)
# 遞迴層[1] - /wiki/CERN (CERN)
# 遞迴層[2] - /wiki/%E6%B3%95%E8%AF%AD (法語)
# 遞迴層[2] - /wiki/%E8%8B%B1%E6%96%87 (英文)
# 遞迴層[2] - /wiki/%E7%B2%92%E5%AD%90%E7%89%A9%E7%90%86%E5%AD%B8 (粒子物理學)
# 遞迴層[2] - /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 (全球資訊網)
# 遞迴層[2] - /wiki/%E7%91%9E%E5%A3%AB (瑞士)
# 遞迴層[2] - /wiki/%E6%97%A5%E5%85%A7%E7%93%A6 (日內瓦)
# 遞迴層[2] - /wiki/%E6%B2%BB%E5%A4%96%E6%B3%95%E6%AC%8A (治外法權)
# 遞迴層[2] - /wiki/%E4%BB%A5%E8%89%B2%E5%88%97 (以色列)
# 遞迴層[2] - /wiki/%E6%AD%90%E6%B4%B2 (歐洲)
# 遞迴層[2] - /wiki/%E7%89%A9%E7%90%86%E5%AD%B8 (物理學)
# 遞迴層[2] - /wiki/%E7%B2%92%E5%AD%90%E5%8A%A0%E9%80%9F%E5%99%A8 (粒子加速器)
# 遞迴層[2] - /wiki/%E7%A7%91%E7%93%A6%E7%88%BE%E6%96%AF%E5%9F%BA (科瓦爾斯基)
# 遞迴層[2] - /wiki/%E6%B2%83%E7%B4%8D%C2%B7%E6%B5%B7%E6%A3%AE%E5%A0%A1 (沃納·海森堡)
# 遞迴層[2] - /wiki/ENQUIRE (詢問計劃)
# 遞迴層[2] - /wiki/%E6%8F%90%E5%A7%86%C2%B7%E6%9F%8F%E5%85%A7%E8%8C%B2-%E6%9D%8E (提姆·柏內茲-李)
# 遞迴層[2] - /wiki/%E7%BD%97%E4%BC%AF%E7%89%B9%C2%B7%E5%8D%A1%E9%87%8C%E5%A5%A5 (羅伯特·卡里奧)
# 遞迴層[2] - /wiki/%E8%B6%85%E6%96%87%E6%9C%AC (超文字)
# 遞迴層[2] - /wiki/%E7%B6%B2%E6%A0%BC%E8%A8%88%E7%AE%97 (網格計算)
# 遞迴層[2] - /wiki/%E5%A4%A7%E5%9E%8B%E5%BC%B7%E5%AD%90%E5%B0%8D%E6%92%9E%E6%A9%9F (大型強子對撞機)
# 遞迴層[2] - /wiki/%E5%A4%A7%E5%9E%8B%E9%9B%BB%E5%AD%90%E6%AD%A3%E5%AD%90%E5%B0%8D%E6%92%9E%E6%A9%9F (大型電子正子對撞機)
# 遞迴層[2] - /wiki/%E6%97%A5%E5%86%85%E7%93%A6%E5%9B%BD%E9%99%85%E6%9C%BA%E5%9C%BA (日內瓦國際機場)
# 遞迴層[2] - /wiki/%E4%BE%8F%E7%BD%97%E5%B1%B1 (侏羅山)
# 遞迴層[2] - /wiki/%E7%B7%8A%E6%B9%8A%E7%B7%B2%E5%AD%90%E7%B7%9A%E5%9C%88 (緊湊緲子線圈)
# 遞迴層[2] - /wiki/%E8%B6%85%E7%92%B0%E9%9D%A2%E5%84%80%E5%99%A8 (超環面儀器)
# 遞迴層[2] - /wiki/LHCb (LHCb)
# 遞迴層[2] - /wiki/%E6%AF%94%E5%88%A9%E6%99%82 (比利時)
# 遞迴層[2] - /wiki/%E9%9B%BB%E8%85%A6 (電腦)
# 遞迴層[2] - /wiki/%E4%B8%B2%E6%B5%81 (串流)
# 遞迴層[2] - /wiki/%E5%AE%89%E7%9C%81 (安省)
# 遞迴層[2] - /wiki/%E5%A4%B8%E5%85%8B (魅夸克)
# 遞迴層[2] - /wiki/%E5%9C%B0%E7%90%86%E5%9D%90%E6%A0%87 (座標)
# 遞迴層[1] - /wiki/%E7%B6%B2%E9%A0%81%E7%80%8F%E8%A6%BD%E5%99%A8 (網頁瀏覽器)
# 遞迴層[2] - /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 (全球資訊網)
# 遞迴層[2] - /wiki/%E6%87%89%E7%94%A8%E7%A8%8B%E5%BC%8F (應用程式)
# 遞迴層[2] - /wiki/%E7%B5%B1%E4%B8%80%E8%B3%87%E6%BA%90%E6%A8%99%E8%AA%8C%E7%AC%A6 (統一資源標誌符)
# 遞迴層[2] - /wiki/%E8%B6%85%E9%80%A3%E7%B5%90 (超連結)
# 遞迴層[2] - /wiki/%E4%B8%93%E7%94%A8%E7%BD%91%E7%BB%9C (專用網路)
# 遞迴層[2] - /wiki/%E7%B6%B2%E9%A0%81%E4%BC%BA%E6%9C%8D%E5%99%A8 (網頁伺服器)
# 遞迴層[2] - /wiki/%E6%AA%94%E6%A1%88%E7%B3%BB%E7%B5%B1 (檔案系統)
# 遞迴層[2] - /wiki/Mozilla_Firefox (Phoenix)
# 遞迴層[2] - /wiki/Internet_Explorer (Internet Explorer)
# 遞迴層[2] - /wiki/Microsoft_Edge (Microsoft Edge)
# 遞迴層[2] - /wiki/Google_Chrome (Google Chrome)
# 遞迴層[2] - /wiki/Opera%E9%9B%BB%E8%85%A6%E7%80%8F%E8%A6%BD%E5%99%A8 (Opera)
# 遞迴層[2] - /wiki/Safari (Safari)
# 遞迴層[2] - /wiki/%E6%8F%90%E5%A7%86%C2%B7%E6%9F%8F%E5%85%A7%E8%8C%B2-%E6%9D%8E (提姆·柏內茲-李)
# 遞迴層[2] - /wiki/WorldWideWeb (WorldWideWeb)
# 遞迴層[2] - /wiki/%E5%A6%AE%E5%8F%AF%E6%8B%89%C2%B7%E4%BD%A9%E6%B4%9B (妮可拉·佩洛)
# 遞迴層[2] - /wiki/Line_Mode_Browser (LMB)
# 遞迴層[2] - /wiki/%E5%93%91%E7%BB%88%E7%AB%AF (啞終端)
# 遞迴層[2] - /wiki/%E9%A9%AC%E5%85%8B%C2%B7%E5%AE%89%E5%BE%B7%E6%A3%AE (馬克·安德森)
# 遞迴層[2] - /wiki/Mosaic (Mosaic)
# 遞迴層[2] - /wiki/NCSA (NCSA)
# 遞迴層[2] - /wiki/Netscape (Netscape)
# 遞迴層[2] - /wiki/Netscape_Navigator (Netscape Navigator)
# 遞迴層[2] - /wiki/%E5%BE%AE%E8%BB%9F (微軟)
# 遞迴層[2] - /wiki/Spyglass%E5%85%AC%E5%8F%B8 (Spyglass公司)
# 遞迴層[2] - /wiki/%E6%B5%8F%E8%A7%88%E5%99%A8%E5%A4%A7%E6%88%98 (瀏覽器大戰)
# 遞迴層[2] - /wiki/Windows (Windows)
# 遞迴層[2] - /wiki/%E9%96%8B%E6%94%BE%E5%8E%9F%E5%A7%8B%E7%A2%BC (開放原始碼)
# 遞迴層[2] - /wiki/Mozilla_Application_Suite (Mozilla Application Suite)
# 遞迴層[2] - /wiki/%E7%BE%8E%E5%9C%8B%E7%B7%9A%E4%B8%8A (美國線上)
# 遞迴層[2] - /wiki/Macintosh (Macintosh)
# 遞迴層[2] - /wiki/Internet_Explorer_for_Mac (Internet Explorer)
# 遞迴層[2] - /wiki/Firefox (Firefox)
# 遞迴層[2] - /wiki/IPad (iPad)
# 遞迴層[2] - /wiki/IPhone (iPhone)
# 遞迴層[2] - /wiki/Konqueror (Konqueror)
# 遞迴層[2] - /wiki/KHTML (KHTML)
# 遞迴層[2] - /wiki/%E6%8E%92%E7%89%88%E5%BC%95%E6%93%8E (排版引擎)
# 遞迴層[2] - /wiki/OS_X (OS X)
# 遞迴層[2] - /wiki/%E6%90%9C%E5%B0%8B%E5%BC%95%E6%93%8E (搜尋引擎)
# 遞迴層[2] - /wiki/Google (Google)
# 遞迴層[2] - /wiki/StatCounter (StatCounter)
# 遞迴層[2] - /wiki/%E7%B6%B2%E7%B5%A1%E5%A5%97%E4%BB%B6 (網路套件)
# 遞迴層[2] - /wiki/%E5%BC%B9%E5%87%BA%E5%BC%8F%E5%B9%BF%E5%91%8A (彈出式廣告)
# 遞迴層[2] - /wiki/HTTPS (HTTPS)
# 遞迴層[2] - /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E4%BC%A0%E8%BE%93%E5%8D%8F%E8%AE%AE (HTTP)
# 遞迴層[2] - /wiki/Cookie (Cookie)
# 遞迴層[2] - /wiki/%E7%80%8F%E8%A6%BD%E5%99%A8%E6%93%B4%E5%85%85%E5%8A%9F%E8%83%BD (瀏覽器擴充功能)
# 遞迴層[2] - /wiki/%E9%9A%90%E7%A7%81%E7%8D%BE (防止廣告聯盟)
# 遞迴層[1] - /wiki/%E8%B3%87%E8%A8%8A%E6%99%82%E4%BB%A3 (資訊時代)
# 遞迴層[2] - /wiki/%E4%BF%A1%E6%81%AF%E4%BA%A7%E4%B8%9A (資訊工業)
# 遞迴層[2] - /wiki/%E9%A9%AC%E5%85%8B%C2%B7%E6%89%8E%E5%85%8B%E4%BC%AF%E6%A0%BC (馬克·祖克柏)
# 遞迴層[2] - /wiki/Facebook (Facebook)
# 遞迴層[1] - /wiki/%E7%B6%B2%E9%A0%81 (網頁)
# 遞迴層[2] - /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 (全球資訊網)
# 遞迴層[2] - /wiki/%E7%B6%B2%E9%A0%81%E7%80%8F%E8%A6%BD%E5%99%A8 (網頁瀏覽器)
# 遞迴層[2] - /wiki/%E8%AE%A1%E7%AE%97%E6%9C%BA (電腦)
# 遞迴層[2] - /wiki/%E4%BA%92%E8%81%94%E7%BD%91 (網際網路)
# 遞迴層[2] - /wiki/%E7%B6%B2%E5%9D%80 (網址)
# 遞迴層[2] - /wiki/URL (URL)
# 遞迴層[2] - /wiki/%E7%BD%91%E9%A1%B5%E6%B5%8F%E8%A7%88%E5%99%A8 (網頁瀏覽器)
# 遞迴層[2] - /wiki/HTML (HTML)
# 遞迴層[2] - /wiki/%E5%9C%96%E5%83%8F (圖像)
# 遞迴層[2] - /wiki/%E7%B6%B2%E7%AB%99 (網站)
# 遞迴層[2] - /wiki/%E9%A6%96%E9%A0%81 (首頁)
# 遞迴層[2] - /wiki/%E6%96%87%E5%AD%97%E7%B7%A8%E8%BC%AF%E5%99%A8 (文字編輯器)
# 遞迴層[2] - /wiki/HTML%E7%B7%A8%E8%BC%AF%E5%99%A8 (HTML編輯器)
# 遞迴層[2] - /wiki/FTP (FTP)
# 遞迴層[2] - /wiki/%E4%B8%8A%E8%BC%89 (上傳)
# 遞迴層[1] - /wiki/%E6%A0%BC%E5%BC%8F%E5%8C%96%E6%96%87%E6%9C%AC (格式化)
# 遞迴層[2] - /wiki/%E8%8B%B1%E6%96%87 (英文)
# 遞迴層[2] - /wiki/%E7%BA%AF%E6%96%87%E6%9C%AC (純文本)
# 遞迴層[2] - /wiki/%E8%B6%85%E9%93%BE%E6%8E%A5 (超連結)
# 遞迴層[2] - /wiki/HTML (HTML)
# 遞迴層[2] - /wiki/Rich_Text_Format (RTF)
# 遞迴層[2] - /wiki/UTF-8 (UTF-8)
# 遞迴層[2] - /wiki/%E6%A0%87%E8%AE%B0%E8%AF%AD%E8%A8%80 (標記語言)
# 遞迴層[2] - /wiki/Microsoft_Word (Microsoft Word)
# 遞迴層[1] - /wiki/%E8%B6%85%E6%96%87%E4%BB%B6%E6%A8%99%E7%A4%BA%E8%AA%9E%E8%A8%80 (超文件標示語言)
# 遞迴層[2] - /wiki/%E7%BD%91%E9%A1%B5 (網頁)
# 遞迴層[2] - /wiki/%E6%A0%87%E8%AE%B0%E8%AF%AD%E8%A8%80 (標記語言)
# 遞迴層[2] - /wiki/CSS (CSS)
# 遞迴層[2] - /wiki/JavaScript (JavaScript)
# 遞迴層[2] - /wiki/%E7%BD%91%E9%A1%B5%E6%B5%8F%E8%A7%88%E5%99%A8 (網頁瀏覽器)
# 遞迴層[2] - /wiki/%E7%BC%96%E7%A8%8B%E8%AF%AD%E8%A8%80 (程式語言)
# 遞迴層[2] - /wiki/HTML%E5%85%83%E7%B4%A0 (HTML元素)
# 遞迴層[2] - /wiki/%E8%AF%AD%E4%B9%89 (語意)
# 遞迴層[2] - /wiki/%E6%8B%AC%E5%8F%B7 (尖括號)
# 遞迴層[2] - /wiki/%E8%84%9A%E6%9C%AC%E8%AF%AD%E8%A8%80 (手稿語言)
# 遞迴層[2] - /wiki/%E5%B1%82%E5%8F%A0%E6%A0%B7%E5%BC%8F%E8%A1%A8 (CSS)
# 遞迴層[2] - /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91%E8%81%94%E7%9B%9F (全球資訊網協會)
# 遞迴層[2] - /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E (提姆·柏內茲-李)
# 遞迴層[2] - /wiki/%E6%AD%90%E6%B4%B2%E6%A0%B8%E5%AD%90%E7%A0%94%E7%A9%B6%E7%B5%84%E7%B9%94 (歐洲核子研究中心)
# 遞迴層[2] - /wiki/ENQUIRE (ENQUIRE)
# 遞迴層[2] - /wiki/%E4%BA%92%E8%81%94%E7%BD%91 (網際網路)
# 遞迴層[2] - /wiki/%E8%B6%85%E6%96%87%E6%9C%AC (超文字)
# 遞迴層[2] - /wiki/%E7%BD%97%E4%BC%AF%E7%89%B9%C2%B7%E5%8D%A1%E9%87%8C%E5%A5%A5 (羅伯特·卡里奧)
# 遞迴層[2] - /wiki/SGML (標準通用標記語言)
# 遞迴層[2] - /wiki/%E4%BA%92%E8%81%94%E7%BD%91%E5%B7%A5%E7%A8%8B%E4%BB%BB%E5%8A%A1%E7%BB%84 (網際網路工程任務組)
# 遞迴層[2] - /wiki/%E6%96%87%E4%BB%B6%E7%B1%BB%E5%9E%8B%E6%8F%8F%E8%BF%B0 (文件類型定義)
# 遞迴層[2] - /wiki/NCSA_Mosaic (NCSA Mosaic)
# 遞迴層[2] - /wiki/%E5%9C%8B%E9%9A%9B%E6%A8%99%E6%BA%96%E5%8C%96%E7%B5%84%E7%B9%94 (ISO)
# 遞迴層[2] - /wiki/IEC (IEC)
# 遞迴層[2] - /wiki/%E7%B6%B2%E9%A0%81%E8%B6%85%E6%96%87%E6%9C%AC%E6%8A%80%E8%A1%93%E5%B7%A5%E4%BD%9C%E5%B0%8F%E7%B5%84 (網頁超文字應用技術工作小組)
# 遞迴層[2] - /wiki/XML (XML)
# 遞迴層[2] - /wiki/%E6%80%AA%E5%BC%82%E6%A8%A1%E5%BC%8F (怪異模式)
# 遞迴層[2] - /wiki/Hello_World (Hello World)
# 遞迴層[2] - /wiki/%E6%8F%9B%E8%A1%8C (換行)
# 遞迴層[2] - /wiki/%E9%98%BF%E6%8B%89%E4%BC%AF%E8%AF%AD (阿拉伯語)
# 遞迴層[2] - /wiki/%E6%B3%A2%E6%96%AF%E8%AF%AD (波斯語)
# 遞迴層[2] - /wiki/%E5%B8%8C%E4%BC%AF%E6%9D%A5%E8%AF%AD (希伯來語)
# 遞迴層[2] - /wiki/%E5%AD%97%E5%85%83%E5%80%BC%E5%8F%83%E8%80%83 (字元值參考)
# 遞迴層[2] - /wiki/%E7%94%A8%E6%88%B7%E4%BB%A3%E7%90%86 (用戶代理)
# 遞迴層[2] - /wiki/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB (搜尋和索引)
# 遞迴層[2] - /wiki/%E5%AD%97%E7%AC%A6%E7%BC%96%E7%A0%81 (字元編碼)
# 遞迴層[2] - /wiki/UTF-8 (UTF-8)
# 遞迴層[2] - /wiki/Unicode (Unicode)
# 遞迴層[2] - /wiki/%E6%95%B8%E6%93%9A%E9%A1%9E%E5%9E%8B (資料類型)
# 遞迴層[2] - /wiki/%E6%96%87%E6%A1%A3%E7%B1%BB%E5%9E%8B%E5%AE%9A%E4%B9%89 (文件類型定義)
# 遞迴層[2] - /wiki/HTML5 (HTML5)
# 遞迴層[2] - /wiki/Span_and_div (span與div)
# 遞迴層[2] - /wiki/%E5%91%88%E7%8E%B0%E4%B8%8E%E5%86%85%E5%AE%B9%E5%88%86%E7%A6%BB (呈現與內容分離)
# 遞迴層[2] - /wiki/%E8%AF%AD%E4%B9%89%E7%BD%91 (語意)
# 遞迴層[2] - /wiki/Web_2.0 (Web 2.0)
# 遞迴層[2] - /wiki/%E6%B7%B7%E6%90%AD_(%E4%BA%92%E8%81%AF%E7%B6%B2) (混搭)
# 遞迴層[2] - /wiki/%E6%A0%BC%E5%83%B9 (價格比較網站)
# 遞迴層[2] - /wiki/%E8%81%9A%E5%90%88%E5%99%A8 (聚合)
# 遞迴層[2] - /wiki/%E7%B6%B2%E9%A0%81%E9%96%8B%E7%99%BC%E8%80%85 (網頁開發者)
# 遞迴層[2] - /wiki/API (API)
# 遞迴層[2] - /wiki/%E7%B6%B2%E8%B7%AF%E8%9C%98%E8%9B%9B (網路爬蟲)
# 遞迴層[2] - /wiki/%E7%AE%97%E6%B3%95 (演算法)
# 遞迴層[2] - /wiki/%E7%BD%91%E7%BB%9C%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E (搜尋工具)
# 遞迴層[2] - /wiki/%E7%B6%B2%E9%A0%81%E4%BC%BA%E6%9C%8D%E5%99%A8 (網頁伺服器)
# 遞迴層[2] - /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E4%BC%A0%E8%BE%93%E5%8D%8F%E8%AE%AE (超文字傳輸協定)
# 遞迴層[2] - /wiki/%E7%94%B5%E5%AD%90%E9%82%AE%E4%BB%B6 (電子郵件)
# 遞迴層[2] - /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 (全球資訊網)
# 遞迴層[2] - /wiki/HTTP (HTTP)
# 遞迴層[2] - /wiki/%E6%96%87%E4%BB%B6%E9%A1%9E%E5%9E%8B (檔案類型)
# 遞迴層[2] - /wiki/%E5%85%83%E6%95%B0%E6%8D%AE (元資料)
# 遞迴層[2] - /wiki/MIME (MIME)
# 遞迴層[2] - /wiki/HTML%E5%AD%97%E7%AC%A6%E7%BC%96%E7%A0%81 (HTML字元編碼)
# 遞迴層[2] - /wiki/%E8%AF%AD%E6%B3%95%E9%94%99%E8%AF%AF (語法錯誤)
# 遞迴層[2] - /wiki/%E7%BA%AF%E6%96%87%E6%9C%AC (純文字)
# 遞迴層[2] - /wiki/%E5%9B%BE%E5%BD%A2%E7%94%A8%E6%88%B7%E7%95%8C%E9%9D%A2 (圖形化使用者介面)
# 遞迴層[2] - /wiki/%E9%92%93%E9%B1%BC%E5%BC%8F%E6%94%BB%E5%87%BB (釣魚攻擊)
# 遞迴層[2] - /wiki/%E5%9E%83%E5%9C%BE%E9%9B%BB%E9%83%B5 (垃圾郵件)
# 遞迴層[2] - /wiki/%E6%96%87%E4%BB%B6%E6%89%A9%E5%B1%95%E5%90%8D (副檔名)
# 遞迴層[2] - /wiki/DOS (DOS)
# 遞迴層[2] - /wiki/FAT (FAT)
# 遞迴層[2] - /wiki/8.3 (3個字母)
# 遞迴層[2] - /wiki/Microsoft_Windows (Microsoft Windows)
# 遞迴層[2] - /wiki/Cookie (Cookie)
# 遞迴層[2] - /wiki/%E6%B3%A8%E5%86%8C%E8%A1%A8 (登錄檔)
# 遞迴層[2] - /wiki/EXE%E6%A0%BC%E5%BC%8F (EXE檔案)
# 遞迴層[2] - /wiki/%E6%89%80%E8%A6%8B%E5%8D%B3%E6%89%80%E5%BE%97 (所見即所得)
# 遞迴層[2] - /wiki/%E6%96%87%E5%AD%97%E5%A4%84%E7%90%86%E5%99%A8 (文書處理器)
# 遞迴層[2] - /wiki/WYSIWYM (WYSIWYM)
# 遞迴層[1] - /wiki/%E5%9C%96%E7%89%87 (圖片)
# 遞迴層[2] - /wiki/%E7%85%A7%E7%9B%B8%E6%9C%BA (照相機)
# 遞迴層[2] - /wiki/%E9%95%9C%E5%AD%90 (鏡子)
# 遞迴層[2] - /wiki/%E6%9C%9B%E8%BF%9C%E9%95%9C (望遠鏡)
# 遞迴層[2] - /wiki/%E6%98%BE%E5%BE%AE%E9%95%9C (顯微鏡)
# 遞迴層[2] - /wiki/%E6%95%B0%E5%AD%97%E5%9B%BE%E5%83%8F (數位影像)
# 遞迴層[2] - /wiki/%E5%9B%BE%E5%83%8F%E5%88%86%E6%9E%90 (圖像分析)
# 遞迴層[2] - /wiki/%E5%9B%BE%E5%83%8F%E5%A4%84%E7%90%86 (圖像處理)
# 遞迴層[2] - /wiki/%E5%9C%96%E7%89%87 (圖片)
# 遞迴層[2] - /wiki/%E7%85%A7%E7%89%87 (相片)
# 遞迴層[2] - /wiki/%E5%BD%B1%E7%89%87 (影片)
# 遞迴層[1] - /wiki/%E5%BD%B1%E7%89%87 (影片)
# 遞迴層[1] - /wiki/%E8%81%B2%E9%9F%B3 (聲音)
# 遞迴層[2] - /wiki/%E5%A3%B0%E6%B3%A2 (聲波)
# 遞迴層[2] - /wiki/%E4%BB%8B%E8%B4%A8 (介質)
# 遞迴層[2] - /wiki/%E7%A9%BA%E6%B0%A3 (空氣)
# 遞迴層[2] - /wiki/%E5%9B%BA%E9%AB%94 (固體)
# 遞迴層[2] - /wiki/%E6%B6%B2%E9%AB%94 (液體)
# 遞迴層[2] - /wiki/%E5%90%AC%E8%A7%89 (聽覺)
# 遞迴層[2] - /wiki/%E5%99%A8%E5%AE%98 (器官)
# 遞迴層[2] - /wiki/%E6%B3%A2%E5%8B%95 (波動)
# 遞迴層[2] - /wiki/%E8%B5%AB%E5%85%B9 (Hz)
# 遞迴層[2] - /wiki/%E5%88%86%E8%B2%9D (分貝)
# 遞迴層[2] - /wiki/%E5%A3%B0%E5%AD%A6 (聲學)
# 遞迴層[2] - /wiki/%E5%9B%BA%E4%BD%93 (固體)
# 遞迴層[2] - /wiki/%E6%B6%B2%E4%BD%93 (液體)
# 遞迴層[2] - /wiki/%E9%9F%B3%E9%9F%BF%E5%B7%A5%E7%A8%8B (音響工程)
# 遞迴層[2] - /wiki/%E8%81%B2%E9%9F%B3%E4%BF%A1%E8%99%9F%E8%99%95%E7%90%86 (聲音信號處理)
# 遞迴層[2] - /wiki/%E5%BB%BA%E7%AD%91%E5%A3%B0%E5%AD%A6 (建築聲學)
# 遞迴層[2] - /wiki/%E5%BF%83%E7%90%86%E5%A3%B0%E5%AD%A6 (心理聲學)
# 遞迴層[2] - /wiki/%E8%AA%AA%E8%A9%B1 (說話)
# 遞迴層[2] - /wiki/%E8%B6%85%E9%9F%B3%E6%B3%A2 (超音波)
# 遞迴層[2] - /wiki/%E6%8C%AF%E5%8B%95 (振動)
# 遞迴層[2] - /wiki/%E4%B9%90%E5%99%A8 (樂器)
# 遞迴層[2] - /wiki/%E9%A2%91%E7%8E%87 (頻率)
# 遞迴層[2] - /wiki/%E5%BC%BA%E5%BA%A6 (強度)
# 遞迴層[2] - /wiki/%E6%AD%A3%E5%BC%A6%E6%B3%A2 (正弦波)
# 遞迴層[2] - /wiki/%E5%82%85%E7%AB%8B%E5%8F%B6%E5%8F%98%E6%8D%A2 (傅立葉變換)
# 遞迴層[2] - /wiki/%E8%B6%85%E5%A3%B0%E6%B3%A2 (超音波)
# 遞迴層[2] - /wiki/%E6%AC%A1%E5%A3%B0%E6%B3%A2 (次聲波)
# 遞迴層[2] - /wiki/%E9%A0%BB%E7%8E%87 (頻率)
# 遞迴層[2] - /wiki/%E6%B3%A2%E9%95%B7 (波長)
# 遞迴層[2] - /wiki/%E5%8F%8D%E5%B0%84 (反射)
# 遞迴層[2] - /wiki/%E6%8A%98%E5%B0%84 (折射)
# 遞迴層[2] - /wiki/%E5%B9%B2%E6%B6%89 (干涉)
# 遞迴層[2] - /wiki/%E7%B9%9E%E5%B0%84 (繞射)
# 遞迴層[2] - /wiki/%E6%95%A3%E5%B0%84 (散射)
# 遞迴層[2] - /wiki/%E6%AD%A3%E5%BC%A6%E6%9B%B2%E7%B7%9A (正弦)
# 遞迴層[2] - /wiki/%E5%B9%B3%E9%9D%A2%E6%B3%A2 (平面波)
# 遞迴層[2] - /wiki/%E6%A0%87%E5%87%86%E7%8A%B6%E5%86%B5 (標準狀況)
# 遞迴層[2] - /wiki/%E9%80%9F%E5%BA%A6 (速度)
# 遞迴層[2] - /wiki/%E5%90%91%E9%87%8F (向量)
# 遞迴層[2] - /wiki/%E6%B3%A2%E7%9F%A2 (波向量)
# 遞迴層[2] - /wiki/%E6%A8%AA%E6%B3%A2 (橫波)
# 遞迴層[2] - /wiki/%E5%89%AA%E6%87%89%E5%8A%9B (剪應力)
# 遞迴層[2] - /wiki/%E5%81%8F%E6%8C%AF (偏振)
# 遞迴層[2] - /wiki/%E5%A3%B0%E9%80%9F (聲速)
# 遞迴層[2] - /wiki/%E8%BF%9E%E7%BB%AD%E4%BB%8B%E8%B4%A8%E5%8A%9B%E5%AD%A6 (連續介質力學)
# 遞迴層[2] - /wiki/%E7%BB%8F%E5%85%B8%E5%8A%9B%E5%AD%A6 (古典力學)
# 遞迴層[2] - /wiki/%E4%B8%8D%E5%8F%AF%E5%A3%93%E7%B8%AE%E7%8E%87 (不可壓縮率)
# 遞迴層[2] - /wiki/%E5%AF%86%E5%BA%A6 (密度)
# 遞迴層[2] - /wiki/%E7%B6%93%E5%85%B8%E5%8A%9B%E5%AD%B8 (古典力學)
# 遞迴層[2] - /wiki/%E7%B5%95%E7%86%B1 (絕熱)
# 遞迴層[2] - /wiki/%E7%90%86%E6%83%B3%E6%B0%94%E4%BD%93 (理想氣體)
# 遞迴層[2] - /wiki/%E7%94%9F%E7%90%86%E5%AD%B8 (生理學)
# 遞迴層[2] - /wiki/%E5%BF%83%E7%90%86%E5%AD%B8 (心理學)
# 遞迴層[2] - /wiki/%E7%89%A9%E7%A8%AE (物種)
# 遞迴層[2] - /wiki/%E5%B0%8E%E8%88%AA (導航)
# 遞迴層[2] - /wiki/%E6%8D%95%E9%A3%9F (捕食)
# 遞迴層[2] - /wiki/%E8%9B%99 (蛙)
# 遞迴層[2] - /wiki/%E9%B3%A5 (鳥)
# 遞迴層[2] - /wiki/%E5%93%BA%E4%B9%B3%E5%8B%95%E7%89%A9 (哺乳動物)
# 遞迴層[2] - /wiki/%E8%9A%8A%E9%9F%B3 (蚊音)
# 遞迴層[2] - /wiki/%E5%8E%8B%E5%BC%BA (壓力)
# 遞迴層[2] - /wiki/%E5%9D%87%E6%96%B9%E6%A0%B9 (均方根)
# 遞迴層[2] - /wiki/%E5%B8%95%E6%96%AF%E5%8D%A1 (Pa)
# 遞迴層[2] - /wiki/%E5%93%8D%E5%BA%94%E7%8E%87 (響應率)
# 遞迴層[2] - /wiki/%E5%9B%BD%E9%99%85%E7%94%B5%E5%B7%A5%E5%A7%94%E5%91%98%E4%BC%9A (國際電工委員會)
# 遞迴層[2] - /wiki/%E8%B5%AB%E8%8C%B2 (赫茲)
# 遞迴層[2] - /wiki/%E5%B7%A5%E4%B8%9A (工業)
# 遞迴層[2] - /wiki/%E5%86%9B%E4%BA%8B (軍事)
# 遞迴層[2] - /wiki/%E9%86%AB%E7%99%82 (醫療)
# 遞迴層[2] - /wiki/%E6%BD%9C%E8%89%87 (潛艇)
# 遞迴層[2] - /wiki/%E5%A3%B0%E5%91%90 (聲吶)
# 遞迴層[2] - /wiki/%E8%83%86%E7%BB%93%E7%9F%B3 (膽結石)
# 遞迴層[2] - /wiki/%E7%81%AB%E5%B1%B1%E7%88%86%E7%99%BC (火山爆發)
# 遞迴層[2] - /wiki/%E9%BE%99%E5%8D%B7%E9%A3%8E (龍捲風)
# 遞迴層[2] - /wiki/%E9%9B%B7%E6%9A%B4 (雷暴)
# 遞迴層[2] - /wiki/%E5%8F%B0%E9%A3%8E (颱風)
# 遞迴層[2] - /wiki/%E6%A0%B8%E8%AF%95%E9%AA%8C (核試驗)
# 遞迴層[2] - /wiki/%E7%81%AB%E7%AE%AD (火箭)
# 遞迴層[2] - /wiki/%E5%A3%B0%E5%8E%8B (聲壓)
# 遞迴層[2] - /wiki/%E9%AB%98%E8%A1%80%E5%8E%8B (高血壓)
# 遞迴層[2] - /wiki/%E7%9D%A1%E7%9C%A0 (睡眠)
# 遞迴層[2] - /wiki/%E5%9B%9E%E9%9F%B3 (回音)
# 遞迴層[1] - /wiki/%E5%A4%9A%E5%AA%92%E9%AB%94 (多媒體)
# 遞迴層[2] - /wiki/%E5%AA%92%E4%BD%93 (媒體)
# 遞迴層[2] - /wiki/%E6%96%87%E5%AD%97 (文字)
# 遞迴層[2] - /wiki/%E5%9C%96%E7%89%87 (圖片)
# 遞迴層[2] - /wiki/%E7%85%A7%E7%89%87 (照片)
# 遞迴層[2] - /wiki/%E5%A3%B0%E9%9F%B3 (聲音)
# 遞迴層[2] - /wiki/%E5%8A%A8%E7%94%BB (動畫)
# 遞迴層[2] - /wiki/%E5%BD%B1%E7%89%87 (影片)
# 遞迴層[2] - /wiki/%E7%A8%8B%E5%BA%8F (程序)
# 遞迴層[2] - /wiki/%E4%BA%92%E5%8B%95 (互動)
# 遞迴層[2] - /wiki/TCP (TCP)
# 遞迴層[2] - /wiki/UDP (UDP)
# 遞迴層[2] - /wiki/HTML (HTML)
# 遞迴層[2] - /wiki/XML (XML)
# 遞迴層[2] - /wiki/VRML (VRML)
# 遞迴層[2] - /wiki/%E5%B9%BF%E5%91%8A (廣告)
# 遞迴層[2] - /wiki/%E8%89%BA%E6%9C%AF (藝術)
# 遞迴層[2] - /wiki/%E6%95%99%E8%82%B2 (教育)
# 遞迴層[2] - /wiki/%E5%A8%B1%E4%B9%90 (娛樂)
# 遞迴層[2] - /wiki/%E4%B8%8B%E8%BD%BD (下載)
# 遞迴層[2] - /wiki/%E8%A7%86%E8%A7%89 (視覺)
# 遞迴層[2] - /wiki/%E5%90%AC%E8%A7%89 (聽覺)
# 遞迴層[2] - /wiki/%E8%A7%A6%E8%A7%89 (觸覺)
# 遞迴層[2] - /wiki/%E5%8F%8D%E9%A6%88 (反饋)
# 遞迴層[2] - /wiki/%E5%A4%A7%E7%9C%BE%E5%82%B3%E5%AA%92 (大眾傳媒)
# 遞迴層[1] - /wiki/%E7%B6%B2%E9%9A%9B%E7%B6%B2%E8%B7%AF (網際網路)
# 遞迴層[2] - /wiki/20%E4%B8%96%E7%B4%80 (20世紀)
# 遞迴層[2] - /wiki/%E7%94%B5%E8%84%91%E7%BD%91%E7%BB%9C (電腦網路)
# 遞迴層[2] - /wiki/%E7%B6%B2%E8%B7%AF (網路)
# 遞迴層[2] - /wiki/%E7%BD%91%E7%BB%9C%E5%8D%8F%E8%AE%AE (網路協定)
# 遞迴層[2] - /wiki/%E5%AD%B8%E8%A1%93%E7%95%8C (學術界)
# 遞迴層[2] - /wiki/%E7%94%B5%E5%AD%90%E6%8A%80%E6%9C%AF (電子)
# 遞迴層[2] - /wiki/%E7%84%A1%E7%B7%9A (無線)
# 遞迴層[2] - /wiki/%E5%85%89%E7%BA%96%E7%B6%B2%E8%B7%AF (光纖網路技術)
# 遞迴層[2] - /wiki/%E8%B6%85%E6%96%87%E6%9C%AC (超文字)
# 遞迴層[2] - /wiki/%E8%90%AC%E7%B6%AD%E7%B6%B2 (全球資訊網)
# 遞迴層[2] - /wiki/%E9%9B%BB%E5%AD%90%E9%83%B5%E4%BB%B6 (電子郵件)
# 遞迴層[2] - /wiki/%E7%B6%B2%E9%9A%9B%E5%8D%94%E8%AD%B0%E9%80%9A%E8%A9%B1%E6%8A%80%E8%A1%93 (通話)
# 遞迴層[2] - /wiki/%E6%AA%94%E6%A1%88%E5%88%86%E4%BA%AB (檔案分享)
# 遞迴層[2] - /wiki/TCP/IP (TCP/IP)
# 遞迴層[2] - /wiki/%E5%88%86%E6%95%A3%E7%BD%91%E7%BB%9C (分散網路)
# 遞迴層[2] - /wiki/%E6%8E%92%E9%98%9F%E8%AE%BA (排隊論)
# 遞迴層[2] - /wiki/%E5%B0%81%E5%8C%85%E4%BA%A4%E6%8F%9B (封包交換)
# 遞迴層[2] - /wiki/%E7%BE%8E%E5%9B%BD%E5%9B%BD%E9%98%B2%E9%83%A8 (美國國防部)
# 遞迴層[2] - /wiki/%E5%9C%8B%E9%98%B2%E9%AB%98%E7%AD%89%E7%A0%94%E7%A9%B6%E8%A8%88%E5%8A%83%E7%BD%B2 (高等研究計劃署)
# 遞迴層[2] - /wiki/%E5%86%B7%E6%88%98 (冷戰)
# 遞迴層[2] - /wiki/ARPA%E7%BD%91 (ARPA網)
# 遞迴層[2] - /wiki/%E8%8B%B1%E5%9B%BD (英國)
# 遞迴層[2] - /wiki/%E6%8C%AA%E5%A8%81 (挪威)
# 遞迴層[2] - /wiki/%E8%AE%A1%E7%AE%97%E6%9C%BA (電腦)
# 遞迴層[2] - /wiki/%E7%BD%97%E4%BC%AF%E7%89%B9%C2%B7%E5%8D%A1%E6%81%A9 (羅伯特·卡恩)
# 遞迴層[2] - /wiki/%E6%96%87%E9%A0%93%C2%B7%E7%91%9F%E5%A4%AB (文頓·瑟夫)
# 遞迴層[2] - /wiki/TCP/IP%E5%8D%8F%E8%AE%AE (TCP/IP協定)
# 遞迴層[2] - /wiki/%E5%9B%BE%E7%81%B5%E5%A5%96 (圖靈獎)
# 遞迴層[2] - /wiki/%E7%BD%91%E7%BB%9C%E6%8E%A7%E5%88%B6%E5%8D%8F%E8%AE%AE (NCP)
# 遞迴層[2] - /wiki/%E7%BE%8E%E5%9B%BD%E5%9B%BD%E5%AE%B6%E7%A7%91%E5%AD%A6%E5%9F%BA%E9%87%91%E4%BC%9A (美國國家科學基金會)
# 遞迴層[2] - /wiki/Usenet (Usenet)
# 遞迴層[2] - /wiki/Bitnet (Bitnet)
# 遞迴層[2] - /wiki/X.25 (X.25)
# 遞迴層[2] - /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E (提姆·柏內茲-李)
# 遞迴層[2] - /wiki/%E7%91%9E%E5%A3%AB (瑞士)
# 遞迴層[2] - /wiki/%E6%AD%90%E6%B4%B2%E6%A0%B8%E5%AD%90%E7%A0%94%E7%A9%B6%E7%B5%84%E7%B9%94 (歐洲核子研究組織)
# 遞迴層[2] - /wiki/HTML (HTML)
# 遞迴層[2] - /wiki/HTTP (HTTP)
# 遞迴層[2] - /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 (web)
# 遞迴層[2] - /wiki/FidoNet (FidoNet)
# 遞迴層[2] - /wiki/ARPANET (ARPA網)
# 遞迴層[2] - /wiki/%E7%BE%8E%E8%81%94%E7%A4%BE (美聯社)
# 遞迴層[2] - /wiki/%E7%BA%BD%E7%BA%A6%E6%97%B6%E6%8A%A5 (紐約時報)
# 遞迴層[2] - /wiki/%E7%B6%B2%E9%9A%9B%E7%B6%B2%E8%B7%AF%E5%8D%94%E5%AE%9A (網際網路協定)
# 遞迴層[2] - /wiki/IPv4 (IPv4)
# 遞迴層[2] - /wiki/IP%E5%9C%B0%E5%9D%80 (IP位址)
# 遞迴層[2] - /wiki/IPv6 (IPv6)
# 遞迴層[2] - /wiki/%E7%94%A8%E6%88%B7%E6%95%B0%E6%8D%AE%E6%8A%A5%E5%8D%8F%E8%AE%AE (UDP)
# 遞迴層[2] - /wiki/%E4%BC%A0%E8%BE%93%E6%8E%A7%E5%88%B6%E5%8D%8F%E8%AE%AE (TCP協定)
# 遞迴層[2] - /wiki/UDP (UDP)
# 遞迴層[2] - /wiki/%E6%96%87%E4%BB%B6%E4%BC%A0%E8%BE%93%E5%8D%8F%E8%AE%AE (FTP)
# 遞迴層[2] - /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E4%BC%A0%E8%BE%93%E5%8D%8F%E8%AE%AE (HTTP)
# 遞迴層[2] - /wiki/%E5%9E%83%E5%9C%BE%E9%82%AE%E4%BB%B6 (垃圾郵件)
# 遞迴層[2] - /wiki/%E8%A0%95%E8%99%AB%E7%97%85%E6%AF%92 (蠕蟲病毒)
# 遞迴層[2] - /wiki/%E6%83%A1%E6%84%8F%E8%BB%9F%E9%AB%94 (惡意軟體)
# 遞迴層[2] - /wiki/%E9%9B%BB%E8%85%A6%E7%97%85%E6%AF%92 (電腦病毒)
# 遞迴層[2] - /wiki/%E9%9B%BB%E8%85%A6%E8%A0%95%E8%9F%B2 (電腦蠕蟲)
# 遞迴層[2] - /wiki/%E9%98%BB%E6%96%B7%E6%9C%8D%E5%8B%99%E6%94%BB%E6%93%8A (阻斷服務攻擊)
# 遞迴層[2] - /wiki/%E5%8B%92%E7%B4%A2%E8%BB%9F%E9%AB%94 (勒索軟體)
# 遞迴層[2] - /wiki/%E6%AE%AD%E5%B1%8D%E7%B6%B2%E7%B5%A1 (殭屍網路)
# 遞迴層[2] - /wiki/%E9%96%93%E8%AB%9C%E8%BB%9F%E4%BB%B6 (間諜軟體)
# 遞迴層[2] - /wiki/%E7%94%B5%E8%84%91%E7%8A%AF%E7%BD%AA (網路犯罪)
# 遞迴層[2] - /wiki/%E8%85%BE%E8%AE%AFQQ (騰訊QQ)
# 遞迴層[2] - /wiki/Skype (Skype)
# 遞迴層[2] - /wiki/%E7%A1%AC%E4%BB%B6 (硬體)
# 遞迴層[2] - /wiki/%E9%98%B2%E7%81%AB%E5%A2%99 (防火牆)
# 遞迴層[2] - /wiki/%E4%B8%AD%E5%8D%8E%E4%BA%BA%E6%B0%91%E5%85%B1%E5%92%8C%E5%9B%BD (中華人民共和國)
# 遞迴層[2] - /wiki/%E6%B2%99%E7%89%B9%E9%98%BF%E6%8B%89%E4%BC%AF (沙烏地阿拉伯)
# 遞迴層[2] - /wiki/%E6%94%BF%E6%B2%BB (政治)
# 遞迴層[2] - /wiki/%E5%AE%97%E6%95%99 (宗教)
# 遞迴層[2] - /wiki/%E4%BF%A1%E6%81%AF%E6%8A%80%E6%9C%AF (資訊科技)
# 遞迴層[2] - /wiki/%E6%9C%9D%E9%B2%9C (朝鮮)
# 遞迴層[2] - /wiki/%E9%98%B2%E7%81%AB%E9%95%BF%E5%9F%8E (防火長城)
# 遞迴層[2] - /wiki/%E7%BE%8E%E5%9C%8B%E5%9C%8B%E5%AE%B6%E5%AE%89%E5%85%A8%E5%B1%80 (美國國家安全域)
# 遞迴層[2] - /wiki/%E4%B8%AD%E6%83%85%E5%B1%80 (中情局)
# 遞迴層[2] - /wiki/%E7%88%B1%E5%BE%B7%E5%8D%8E%C2%B7%E6%96%AF%E8%AF%BA%E7%99%BB (史諾登)
# 遞迴層[2] - /wiki/%E8%A1%9B%E5%A0%B1 (衛報)
# 遞迴層[2] - /wiki/%E8%8F%AF%E7%9B%9B%E9%A0%93%E9%83%B5%E5%A0%B1 (華盛頓郵報)
# 遞迴層[2] - /wiki/%E7%B6%93%E6%BF%9F%E5%90%88%E4%BD%9C%E7%99%BC%E5%B1%95%E7%B5%84%E7%B9%94 (經濟合作發展組織)
# 遞迴層[2] - /wiki/%E5%86%B0%E5%B3%B6 (冰島)
# 遞迴層[2] - /wiki/%E9%9F%A9%E5%9B%BD (韓國)
# 遞迴層[2] - /wiki/%E8%8D%B7%E8%98%AD (荷蘭)
# 遞迴層[2] - /wiki/%E4%B8%B9%E9%BA%A5 (丹麥)
# 遞迴層[2] - /wiki/%E7%BE%8E%E5%9C%8B (美國)
# 遞迴層[2] - /wiki/%E4%B8%AD%E5%9B%BD%E4%BA%92%E8%81%94%E7%BD%91%E7%BB%9C%E4%BF%A1%E6%81%AF%E4%B8%AD%E5%BF%83 (中國互聯網絡信息中心)
# 遞迴層[2] - /wiki/%E7%BD%91%E6%B0%91 (網友)
# 遞迴層[1] - /wiki/ENQUIRE (ENQUIRE)
# 遞迴層[2] - /wiki/%E6%AD%90%E6%B4%B2%E6%A0%B8%E5%AD%90%E7%A0%94%E7%A9%B6%E4%B8%AD%E5%BF%83 (歐洲核子研究中心)
# 遞迴層[2] - /wiki/%E6%8F%90%E5%A7%86%C2%B7%E6%9F%8F%E5%85%A7%E8%8C%B2-%E6%9D%8E (提姆·柏內茲-李)
# 遞迴層[2] - /wiki/%E8%BB%9F%E9%AB%94 (軟體)
# 遞迴層[2] - /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 (全球資訊網)
# 遞迴層[2] - /wiki/%E8%B6%85%E6%96%87%E5%AD%97 (超文字)
# 遞迴層[2] - /wiki/%E8%AA%9E%E7%BE%A9%E7%B6%B2 (語義網)
# 遞迴層[2] - /wiki/%E7%A1%AC%E9%AB%94 (硬體)
# 遞迴層[2] - /wiki/%E9%9B%BB%E5%AD%90%E9%83%B5%E4%BB%B6 (電子郵件)
# 遞迴層[2] - /wiki/OpenVMS (VAX / VMS Notes)
# 遞迴層[2] - /wiki/Usenet (Usenet)
# 遞迴層[1] - /wiki/%E6%95%B0%E6%8D%AE%E5%BA%93 (資料庫)
# 遞迴層[2] - /wiki/%E6%A1%A3%E6%A1%88%E6%9F%9C (檔案櫃)
# 遞迴層[2] - /wiki/%E6%AA%94%E6%A1%88 (檔案)
# 遞迴層[2] - /wiki/%E5%85%B1%E4%BA%AB (共享)
# 遞迴層[2] - /wiki/%E6%95%B0%E6%8D%AE%E5%86%97%E4%BD%99 (冗餘度)
# 遞迴層[2] - /wiki/%E9%9B%86%E5%90%88 (集合)
# 遞迴層[2] - /wiki/Tablespace (Tablespace)
# 遞迴層[2] - /wiki/%E6%95%B0%E6%8D%AE%E5%BA%93%E7%AE%A1%E7%90%86%E7%B3%BB%E7%BB%9F (資料庫管理系統)
# 遞迴層[2] - /wiki/%E8%B3%87%E6%96%99%E5%BA%AB (資料庫)
# 遞迴層[2] - /wiki/%E8%BB%9F%E9%AB%94 (軟體)
# 遞迴層[2] - /wiki/%E9%97%9C%E8%81%AF%E6%A8%A1%E5%9E%8B (關聯式)
# 遞迴層[2] - /wiki/XML (XML)
# 遞迴層[2] - /wiki/SQL (SQL)
# 遞迴層[2] - /wiki/%E9%96%8B%E6%94%BE%E5%BC%8F%E8%B3%87%E6%96%99%E5%BA%AB%E9%80%A3%E6%8E%A5 (開放式資料庫連接)
# 遞迴層[2] - /wiki/%E7%A9%BA%E5%80%BC (空值)
# 遞迴層[2] - /wiki/ACID (ACID)
# 遞迴層[1] - /wiki/%E8%AF%AD%E4%B9%89%E7%BD%91 (語意網)
# 遞迴層[2] - /wiki/%E8%8B%B1%E8%AF%AD (英語)
# 遞迴層[2] - /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91%E8%81%94%E7%9B%9F (全球資訊網協會)
# 遞迴層[2] - /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E (提姆·柏內茲-李)
# 遞迴層[2] - /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 (全球資訊網)
# 遞迴層[2] - /wiki/HTML (HTML)
# 遞迴層[2] - /wiki/%E8%AE%A1%E7%AE%97%E6%9C%BA (電腦)
# 遞迴層[2] - /wiki/%E5%85%83%E6%95%B0%E6%8D%AE (元資料)
# 遞迴層[2] - /wiki/%E7%BD%AE%E6%A0%87%E8%AF%AD%E8%A8%80 (標示語言)
# 遞迴層[2] - /wiki/XML (text-and-markup)
# 遞迴層[2] - /wiki/%E7%9F%A5%E8%AF%86%E8%A1%A8%E7%8E%B0 (知識表現)
# 遞迴層[2] - /wiki/%E8%AF%AD%E4%B9%89%E7%BD%91%E7%BB%9C_(%E8%AE%A1%E7%AE%97%E6%9C%BA%E7%A7%91%E5%AD%A6) (語意網絡)
# 遞迴層[2] - /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 (全球資訊網)
# 遞迴層[2] - /wiki/%E8%90%AC%E7%B6%AD%E7%B6%B2 (全球資訊網)
# 遞迴層[2] - /wiki/%E5%8F%AF%E7%B8%AE%E6%94%BE%E5%90%91%E9%87%8F%E5%9C%96%E5%BD%A2 (SVG)
# 遞迴層[2] - /wiki/Web_2.0 (Web 2.0)
# 遞迴層[1] - /wiki/%E7%BD%97%E4%BC%AF%E7%89%B9%C2%B7%E5%8D%A1%E9%87%8C%E5%A5%A5 (羅伯特·卡里奧)
# 遞迴層[2] - /wiki/Help:%E6%B3%95%E8%AA%9E%E5%9C%8B%E9%9A%9B%E9%9F%B3%E6%A8%99 ([kɛˈjo])
# 遞迴層[2] - /wiki/%E6%AF%94%E5%88%A9%E6%97%B6 (比利時)
# 遞迴層[2] - /wiki/%E4%BF%A1%E6%81%AF%E5%AD%A6 (資訊工程師)
# 遞迴層[2] - /wiki/%E8%AE%A1%E7%AE%97%E6%9C%BA%E7%A7%91%E5%AD%A6%E5%AE%B6 (電腦科學家)
# 遞迴層[2] - /wiki/CERN (CERN)
# 遞迴層[2] - /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E (提姆·柏內茲-李)
# 遞迴層[2] - /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 (全球資訊網)
# 遞迴層[2] - /wiki/%E5%AE%89%E7%89%B9%E5%8D%AB%E6%99%AE (安特衛普)
# 遞迴層[2] - /wiki/%E8%8D%B7%E8%98%AD%E8%AA%9E (荷蘭語)
# 遞迴層[2] - /wiki/%E6%A0%B9%E7%89%B9%E5%A4%A7%E5%AD%A6 (根特大學)
# 遞迴層[2] - /wiki/%E5%AF%86%E6%AD%87%E6%A0%B9%E5%A4%A7%E5%AD%A6 (密西根大學)
# 遞迴層[2] - /wiki/Fortran (Fortran)
# 遞迴層[2] - /wiki/%E6%AD%90%E6%B4%B2%E6%A0%B8%E5%AD%90%E7%A0%94%E7%A9%B6%E7%B5%84%E7%B9%94 (歐洲核子研究組織)
# 遞迴層[2] - /wiki/%E8%B6%85%E6%96%87%E6%9C%AC (超文字)
# 遞迴層[2] - /wiki/%E5%BC%97%E5%8A%B3%E6%81%A9%E9%9C%8D%E5%A4%AB%E5%8D%8F%E4%BC%9A (弗勞恩霍夫協會)
# 遞迴層[2] - /wiki/%E6%AC%A7%E7%9B%9F%E5%A7%94%E5%91%98%E4%BC%9A (歐盟執委會)
# 遞迴層[2] - /wiki/%E5%85%AC%E6%9C%89%E9%A2%86%E5%9F%9F (公有領域)
# 遞迴層[2] - /wiki/W3C (W3C)
# 遞迴層[2] - /wiki/%E6%97%A0%E7%A5%9E%E8%AE%BA (無神論)
# 遞迴層[1] - /wiki/NeXT (NeXT)
# 遞迴層[2] - /wiki/%E8%8B%B1%E8%AA%9E (英語)
# 遞迴層[2] - /wiki/%E7%BE%8E%E5%9C%8B (美國)
# 遞迴層[2] - /wiki/%E5%8A%A0%E5%88%A9%E7%A6%8F%E5%B0%BC%E4%BA%9A%E5%B7%9E (加利福尼亞州)
# 遞迴層[2] - /wiki/%E7%B4%85%E6%9C%A8%E5%9F%8E (紅木城)
# 遞迴層[2] - /wiki/%E5%B7%A5%E4%BD%9C%E7%AB%99 (工作站)
# 遞迴層[2] - /wiki/%E8%98%8B%E6%9E%9C%E5%85%AC%E5%8F%B8 (蘋果公司)
# 遞迴層[2] - /wiki/%E8%98%8B%E6%9E%9C%E9%9B%BB%E8%85%A6 (蘋果電腦)
# 遞迴層[2] - /wiki/%E5%8F%B2%E8%92%82%E5%A4%AB%C2%B7%E8%B3%88%E4%BC%AF%E6%96%AF (史蒂夫·賈伯斯)
# 遞迴層[2] - /wiki/NeXT_Computer (NeXT Computer)
# 遞迴層[2] - /wiki/%E7%89%A9%E4%BB%B6%E5%B0%8E%E5%90%91 (物件導向)
# 遞迴層[2] - /wiki/%E4%BD%9C%E6%A5%AD%E7%B3%BB%E7%B5%B1 (作業系統)
# 遞迴層[2] - /wiki/NEXTSTEP (NEXTSTEP)
# 遞迴層[2] - /wiki/API (API)
# 遞迴層[2] - /wiki/OPENSTEP (OPENSTEP)
# 遞迴層[2] - /wiki/%E5%8B%95%E6%85%8B%E7%B6%B2%E9%A0%81 (動態網頁)
# 遞迴層[2] - /wiki/%E7%BD%91%E7%AB%99 (網站)
# 遞迴層[2] - /wiki/%E7%BA%A6%E7%BF%B0%C2%B7%E6%96%AF%E5%8D%A1%E5%88%A9 (史考利)
# 遞迴層[2] - /wiki/%E4%BF%9D%E7%BD%97%C2%B7%E5%85%B0%E5%BE%B7 (保羅·蘭德)
# 遞迴層[2] - /wiki/%E8%AE%A9-%E8%B7%AF%E6%98%93%C2%B7%E5%8A%A0%E8%A5%BF (讓-路易·加西)
# 遞迴層[2] - /wiki/Unix (Unix)
# 遞迴層[2] - /wiki/%E9%A3%8E%E6%8A%95 (風投)
# 遞迴層[2] - /wiki/%E7%BD%97%E6%96%AF%C2%B7%E4%BD%A9%E7%BD%97 (羅斯·佩羅)
# 遞迴層[2] - /wiki/%E5%8A%A0%E5%B7%9E (加州)
# 遞迴層[2] - /wiki/%E6%97%A5%E6%9C%AC (日本)
# 遞迴層[2] - /wiki/%E4%BD%B3%E8%83%BD (佳能)
# 遞迴層[2] - /wiki/%E7%A3%81%E7%A2%9F%E6%A9%9F (磁碟機)
# 遞迴層[2] - /wiki/%E5%85%89%E7%A2%9F%E6%A9%9F (光碟機)
# 遞迴層[2] - /wiki/Sun (Sun)
# 遞迴層[2] - /wiki/Copland_%E6%93%8D%E4%BD%9C%E7%B3%BB%E7%BB%9F (Copland)
# 遞迴層[2] - /wiki/BeOS (BeOS)
# 遞迴層[2] - /wiki/Mac_OS_X (Mac OS X)
# 遞迴層[2] - /wiki/Mac_OS_X_Server (Mac OS X Server)
# 遞迴層[2] - /wiki/Xcode (Xcode)
# 遞迴層[1] - /wiki/%E8%81%96%E8%AA%95%E7%AF%80 (聖誕節)
# 遞迴層[2] - /wiki/%E5%9F%BA%E7%9D%A3%E6%95%99 (基督教)
# 遞迴層[2] - /wiki/%E8%81%96%E7%B6%93 (聖經)
# 遞迴層[2] - /wiki/%E8%80%B6%E7%A8%A3 (耶穌)
# 遞迴層[2] - /wiki/%E8%80%B6%E7%A8%A3%E9%99%8D%E7%94%9F (降生)
# 遞迴層[2] - /wiki/%E8%8A%82%E6%97%A5 (節日)
# 遞迴層[2] - /wiki/%E6%95%99%E6%9C%83%E5%B9%B4%E6%9B%86 (禮儀年曆)
# 遞迴層[2] - /wiki/%E7%BE%85%E9%A6%AC%E5%A4%A9%E4%B8%BB%E6%95%99%E8%81%96%E4%BA%BA%E6%9B%86 (節日)
# 遞迴層[2] - /wiki/%E5%9F%BA%E7%9D%A3%E6%95%99%E6%B4%BE%E7%B3%BB (教派)
# 遞迴層[2] - /wiki/%E5%B0%87%E8%87%A8%E6%9C%9F (將臨期)
# 遞迴層[2] - /wiki/%E8%81%96%E8%AA%95%E5%A4%9C (聖誕夜)
# 遞迴層[2] - /wiki/%E5%9C%8B%E5%AE%B6 (國家)
# 遞迴層[2] - /wiki/%E8%A5%BF%E6%96%B9%E4%B8%96%E7%95%8C (西方國家)
# 遞迴層[2] - /wiki/%E5%9F%BA%E7%9D%A3%E6%95%99%E6%96%87%E5%8C%96 (基督教文化)
# 遞迴層[2] - /wiki/%E5%85%AC%E5%85%B1%E5%81%87%E6%97%A5 (公共假日)
# 遞迴層[2] - /wiki/%E6%B0%91%E4%BF%97 (民俗)
# 遞迴層[2] - /wiki/%E5%85%83%E6%97%A6 (元旦)
# 遞迴層[2] - /wiki/%E5%AD%A6%E6%9C%AF (學術)
# 遞迴層[2] - /wiki/%E5%9C%A3%E6%AF%8D%E9%A2%86%E6%8A%A5 (聖母領報)
# 遞迴層[2] - /wiki/%E5%9F%BA%E7%9D%A3%E6%95%99%E5%8E%86%E5%8F%B2 (發展初期)
# 遞迴層[2] - /wiki/%E5%86%9C%E7%A5%9E%E8%8A%82 (農神節)
# 遞迴層[2] - /wiki/%E5%8F%A4%E7%BE%85%E9%A6%AC (古羅馬)
# 遞迴層[2] - /wiki/%E5%86%AC%E8%87%B3 (冬至)
# 遞迴層[2] - /wiki/%E6%97%A5%E7%85%A7 (日照)
# 遞迴層[2] - /wiki/%E8%A5%BF%E6%96%B9%E5%9F%BA%E7%9D%A3%E6%95%99 (西方教會)
# 遞迴層[2] - /wiki/4%E4%B8%96%E7%B4%80 (4世紀)
# 遞迴層[2] - /wiki/%E6%AD%A3%E6%95%99%E6%9C%83 (正教會)
# 遞迴層[2] - /wiki/%E5%84%92%E7%95%A5%E6%9B%86 (儒略曆)
# 遞迴層[2] - /wiki/%E5%95%86%E6%A5%AD (商業)
# 遞迴層[2] - /wiki/%E8%BF%91%E4%BB%A3 (近代)
# 遞迴層[2] - /wiki/%E6%9D%B1%E4%BA%9E (東亞)
# 遞迴層[2] - /wiki/%E6%95%99%E6%9C%83 (教會)
# 遞迴層[2] - /wiki/%E6%B6%88%E8%B2%BB (消費)
# 遞迴層[2] - /wiki/%E8%B3%BC%E7%89%A9 (購物)
# 遞迴層[2] - /wiki/%E5%9F%BA%E7%9D%A3 (基督)
# 遞迴層[2] - /wiki/%E5%BD%8C%E6%92%92 (彌撒)
# 遞迴層[2] - /wiki/Xmas (Xmas)
# 遞迴層[2] - /wiki/X (X)
# 遞迴層[2] - /wiki/%E5%B8%8C%E8%85%8A (希臘)
# 遞迴層[2] - /wiki/%CE%A7 (Χ)
# 遞迴層[2] - /wiki/%E5%B8%8C%E8%87%98%E8%AA%9E (希臘語)
# 遞迴層[2] - /wiki/%E8%A5%BF%E7%8F%AD%E7%89%99%E8%AA%9E (西班牙語)
# 遞迴層[2] - /wiki/%E8%91%A1%E8%90%84%E7%89%99%E8%AA%9E (葡萄牙語)
# 遞迴層[2] - /wiki/%E6%B3%A2%E8%98%AD%E8%AA%9E (波蘭語)
# 遞迴層[2] - /wiki/%E6%B3%95%E8%AA%9E (法語)
# 遞迴層[2] - /wiki/%E6%84%8F%E5%A4%A7%E5%88%A9%E8%AA%9E (義大利語)
# 遞迴層[2] - /wiki/%E5%8A%A0%E6%B3%B0%E7%BE%85%E5%B0%BC%E4%BA%9E%E8%AA%9E (加泰隆尼亞語)
# 遞迴層[2] - /wiki/%E5%BE%B7%E8%AA%9E (德語)
# 遞迴層[2] - /wiki/%E5%A4%A7%E4%B8%AD%E8%8F%AF%E5%9C%B0%E5%8D%80 (大中華地區)
# 遞迴層[2] - /wiki/%E8%8F%AF%E5%8D%97 (華南)
# 遞迴層[2] - /wiki/%E8%8F%AF%E4%BA%BA (華人)
# 遞迴層[2] - /wiki/%E6%B8%AF%E6%BE%B3 (港澳)
# 遞迴層[2] - /wiki/%E8%87%BA%E7%81%A3 (臺灣)
# 遞迴層[2] - /wiki/%E8%A1%8C%E6%86%B2%E7%B4%80%E5%BF%B5%E6%97%A5 (行憲紀念日)
# 遞迴層[2] - /wiki/%E4%B8%AD%E5%9C%8B%E5%A4%A7%E9%99%B8 (中國大陸)
# 遞迴層[2] - /wiki/%E6%94%B9%E9%9D%A9%E9%96%8B%E6%94%BE (改革開放)
# 遞迴層[2] - /wiki/%E6%AD%90%E7%BE%8E (歐美)
# 遞迴層[2] - /wiki/%E4%B8%AD%E5%9C%8B%E6%B0%91%E9%96%93%E4%BF%A1%E4%BB%B0 (中國民間信仰)
# 遞迴層[2] - /wiki/%E8%A1%8C%E6%94%BF%E9%99%A2%E6%96%B0%E8%81%9E%E5%B1%80 (行政院新聞局)
# 遞迴層[2] - /wiki/%E5%AE%8B%E6%A5%9A%E7%91%9C (宋楚瑜)
# 遞迴層[2] - /wiki/%E8%80%B6%E7%A8%A3%E8%AF%9E%E7%94%9F (耶穌的降生)
# 遞迴層[2] - /wiki/%E5%9F%BA%E7%9D%A3%E6%95%99%E6%95%99%E6%B4%BE (基督教各教派)
# 遞迴層[2] - /wiki/%E5%A4%A9%E4%B8%BB%E6%95%99 (天主教)
# 遞迴層[2] - /wiki/%E5%9F%BA%E7%9D%A3%E6%96%B0%E6%95%99 (基督新教)
# 遞迴層[2] - /wiki/%E7%A7%91%E6%99%AE%E7%89%B9%E6%95%99%E4%BC%9A (科普特)
# 遞迴層[2] - /wiki/%E8%80%B6%E8%B7%AF%E6%92%92%E5%86%B7 (耶路撒冷)
# 遞迴層[2] - /wiki/%E7%99%BD%E4%BF%84%E7%BD%97%E6%96%AF (白俄羅斯)
# 遞迴層[2] - /wiki/%E5%9F%83%E5%A1%9E%E4%BF%84%E6%AF%94%E4%BA%9A (衣索比亞)
# 遞迴層[2] - /wiki/%E4%BF%84%E7%BD%97%E6%96%AF (俄羅斯)
# 遞迴層[2] - /wiki/%E9%A9%AC%E5%85%B6%E9%A1%BF (馬其頓)
# 遞迴層[2] - /wiki/%E5%A1%9E%E5%B0%94%E7%BB%B4%E4%BA%9A (塞爾維亞)
# 遞迴層[2] - /wiki/%E6%A0%BC%E9%B2%81%E5%90%89%E4%BA%9A (喬治亞)
# 遞迴層[2] - /wiki/%E6%9D%B1%E6%AD%A3%E6%95%99 (東正教)
# 遞迴層[2] - /wiki/%E5%85%AC%E5%8E%86 (格里高利曆)
# 遞迴層[2] - /wiki/%E8%A5%BF%E6%AC%A7 (西歐)
# 遞迴層[2] - /wiki/%E5%BE%A9%E6%B4%BB%E7%AF%80 (復活節)
# 遞迴層[2] - /wiki/%E4%B9%8C%E5%85%8B%E5%85%B0 (烏克蘭)
# 遞迴層[2] - /wiki/%E4%BA%9A%E7%BE%8E%E5%B0%BC%E4%BA%9A (亞美尼亞)
# 遞迴層[2] - /wiki/%E4%BA%9A%E7%BE%8E%E5%B0%BC%E4%BA%9A%E6%95%99%E4%BC%9A (亞美尼亞教會)
# 遞迴層[2] - /wiki/%E9%A1%AF%E7%8F%BE%E6%97%A5 (主顯節)
# 遞迴層[2] - /wiki/%E5%9C%A3%E8%AF%9E%E6%A0%91 (聖誕樹)
# 遞迴層[2] - /wiki/%E5%86%AC%E9%9D%92 (冬青)
# 遞迴層[2] - /wiki/%E6%A7%B2%E5%AF%84%E7%94%9F (槲寄生)
# 遞迴層[2] - /wiki/%E7%A4%BC%E7%89%A9 (禮物)
# 遞迴層[2] - /wiki/%E5%BC%82%E6%95%99 (異教)
# 遞迴層[2] - /wiki/%E6%95%99%E5%AE%97 (教宗)
# 遞迴層[2] - /wiki/%E9%A1%8D%E6%88%91%E7%95%A5%E4%B8%80%E4%B8%96 (額我略一世)
# 遞迴層[2] - /wiki/%E5%A5%A5%E5%88%A9%E5%BC%97%C2%B7%E5%85%8B%E4%BC%A6%E5%A8%81%E5%B0%94 (克倫威爾)
# 遞迴層[2] - /wiki/%E4%BF%84%E5%9B%BD%E9%9D%A9%E5%91%BD (俄國革命)
# 遞迴層[2] - /wiki/%E8%8B%8F%E8%81%94 (蘇聯)
# 遞迴層[2] - /wiki/%E5%9F%BA%E7%9D%A3%E6%95%99%E6%B4%BE (基督教派)
# 遞迴層[2] - /wiki/%E5%9F%BA%E7%9D%A3%E6%95%99%E5%9F%BA%E8%A6%81%E4%B8%BB%E4%B9%89 (基要派)
# 遞迴層[2] - /wiki/%E6%B8%85%E6%95%99%E5%BE%92 (清教徒)
# 遞迴層[2] - /wiki/%E6%96%B0%E8%88%88%E5%AE%97%E6%95%99 (新興宗教)
# 遞迴層[2] - /wiki/%E8%80%B6%E5%92%8C%E8%8F%AF%E8%A6%8B%E8%AD%89%E4%BA%BA (耶和華見證人)
# 遞迴層[2] - /wiki/%E5%8C%97%E6%AC%A7 (北歐)
# 遞迴層[2] - /wiki/%E5%9C%A3%E8%AF%9E%E8%80%81%E4%BA%BA (聖誕老人)
# 遞迴層[2] - /wiki/%E5%82%B3%E8%AA%AA (傳說)
# 遞迴層[2] - /wiki/%E5%9C%A3%E5%B0%BC%E5%8F%A4%E6%8B%89 (聖尼古拉斯)
# 遞迴層[2] - /wiki/4%E4%B8%96%E7%BA%AA (4世紀)
# 遞迴層[2] - /wiki/%E5%AE%89%E9%82%A3%E6%89%98%E5%88%A9%E4%BA%9E (小亞細亞)
# 遞迴層[2] - /wiki/%E4%B8%BB%E6%95%99 (主教)
# 遞迴層[2] - /wiki/%E9%A9%AF%E9%B9%BF (馴鹿)
# 遞迴層[2] - /wiki/%E9%9B%AA%E6%A9%87 (雪橇)
# 遞迴層[2] - /wiki/%E6%B3%95%E8%AF%AD (法語)
# 遞迴層[2] - /wiki/%E5%8F%AF%E5%8F%A3%E5%8F%AF%E4%B9%90 (可口可樂)
# 遞迴層[2] - /wiki/1930%E5%B9%B4%E4%BB%A3 (1930年代)
# 遞迴層[2] - /wiki/%E4%BE%8F%E5%84%92_(%E9%BE%99%E4%B8%8E%E5%9C%B0%E4%B8%8B%E5%9F%8E) (侏儒)
# 遞迴層[2] - /wiki/12%E6%9C%885%E6%97%A5 (12月5日)
# 遞迴層[2] - /wiki/%E8%80%B6%E5%92%8C%E5%8D%8E (耶和華)
# 遞迴層[2] - /wiki/%E8%A5%BF%E7%8F%AD%E7%89%99 (西班牙)
# 遞迴層[2] - /wiki/1%E6%9C%886%E6%97%A5 (1月6日)
# 遞迴層[2] - /wiki/%E7%A5%9E%E7%88%B6 (神父)
# 遞迴層[2] - /wiki/%E7%AE%97%E5%91%BD (算命)
# 遞迴層[2] - /wiki/%E7%89%A7%E5%B8%88 (牧師)
# 遞迴層[2] - /wiki/%E8%81%96%E8%AA%95%E5%8D%A1 (聖誕卡)
# 遞迴層[2] - /wiki/%E6%9D%89 (杉)
# 遞迴層[2] - /wiki/%E6%9F%8F (柏)
# 遞迴層[2] - /wiki/%E8%81%96%E8%AA%95%E7%87%88 (聖誕燈)
# 遞迴層[2] - /wiki/%E5%B8%B8%E7%BB%BF%E6%A4%8D%E7%89%A9 (常綠植物)
# 遞迴層[2] - /wiki/%E9%9B%AA%E4%BA%BA (雪人)
# 遞迴層[2] - /wiki/%E7%8C%A9%E7%8C%A9%E6%9C%A8 (猩猩木)
# 遞迴層[2] - /wiki/%E6%9C%B1%E9%A1%B6%E7%BA%A2 (孤挺花)
# 遞迴層[2] - /wiki/%E8%80%B6%E7%A8%A3%E9%99%8D%E7%94%9F%E5%9C%BA%E6%99%AF (耶穌降生場景)
# 遞迴層[2] - /wiki/%E7%BE%8E%E5%9B%BD (美國)
# 遞迴層[2] - /wiki/%E5%AE%97%E6%95%99%E8%87%AA%E7%94%B1 (宗教自由)
# 遞迴層[2] - /wiki/%E8%81%96%E8%AA%95%E5%A4%A7%E9%A4%90 (聖誕大餐)
# 遞迴層[2] - /wiki/%E4%B8%9C%E6%AC%A7 (東歐)
# 遞迴層[2] - /wiki/%E7%A6%81%E9%A3%9F (禁食)
# 遞迴層[2] - /wiki/%E8%80%B6%E7%A9%8C (耶穌)
# 遞迴層[2] - /wiki/%E7%8A%B9%E5%A4%AA%E6%95%99 (猶太教)
# 遞迴層[2] - /wiki/%E5%85%89%E6%98%8E%E8%8A%82 (光明節)
# 遞迴層[2] - /wiki/%E4%BC%8A%E6%96%AF%E5%85%B0%E6%95%99 (伊斯蘭教)
# 遞迴層[2] - /wiki/%E5%85%88%E7%9F%A5 (先知)
# 遞迴層[2] - /wiki/%E7%91%9E%E5%85%B8 (瑞典)
# 遞迴層[2] - /wiki/%E5%8D%8E%E7%89%B9%E8%BF%AA%E5%A3%AB%E5%B0%BC%E5%85%AC%E5%8F%B8 (迪士尼)
# 遞迴層[2] - /wiki/%E6%8C%AA%E5%A8%81 (挪威)
# 遞迴層[2] - /wiki/%E8%8A%82%E7%A4%BC%E6%97%A5 (節禮日)
# 遞迴層[2] - /wiki/%E8%8A%AC%E5%85%B0 (芬蘭)
# 遞迴層[2] - /wiki/%E6%84%8F%E5%A4%A7%E5%88%A9 (義大利)
# 遞迴層[2] - /wiki/%E5%8F%A4%E7%BD%97%E9%A9%AC (古羅馬)
# 遞迴層[2] - /wiki/%E4%BB%AA%E5%BC%8F (宗教儀式)
# 遞迴層[2] - /wiki/%E8%88%B9%E8%88%B6 (船)
# 遞迴層[2] - /wiki/%E6%9D%B1%E6%AD%90 (東歐)
# 遞迴層[2] - /wiki/%E6%96%AF%E6%8B%89%E5%A4%AB%E4%BA%BA (斯拉夫)
# 遞迴層[2] - /wiki/%E9%9B%AA%E5%A7%91%E5%A8%98 (雪姑娘)
# 遞迴層[2] - /wiki/%E4%B8%89%E5%A5%97%E8%BB%8A (三套車)
# 遞迴層[2] - /wiki/%E6%8D%B7%E5%85%8B (捷克)
# 遞迴層[2] - /wiki/%E9%9B%B2%E6%9D%89 (雲杉)
# 遞迴層[2] - /wiki/%E6%9D%BE%E7%A7%91 (松樹)
# 遞迴層[2] - /wiki/%E8%8B%B9%E6%9E%9C (蘋果)
# 遞迴層[2] - /wiki/%E9%9E%8B (鞋)
# 遞迴層[2] - /wiki/%E5%87%BA%E5%AB%81 (出嫁)
# 遞迴層[2] - /wiki/%E9%93%85 (鉛)
# 遞迴層[2] - /wiki/%E6%B3%A2%E5%85%B0 (波蘭)
# 遞迴層[2] - /wiki/%E6%96%AF%E6%B4%9B%E4%BC%90%E5%85%8B (斯洛伐克)
# 遞迴層[2] - /wiki/%E5%B8%83%E6%8B%89%E8%BF%AA%E6%96%AF%E6%8B%89%E5%8F%91 (布拉迪斯拉發)
# 遞迴層[2] - /wiki/%E8%98%87%E8%81%AF%E8%A7%A3%E9%AB%94 (蘇聯解體)
# 遞迴層[2] - /wiki/%E9%96%80%E5%BE%92 (門徒)
# 遞迴層[2] - /wiki/%E8%81%96%E8%AA%95%E6%A8%B9 (聖誕樹)
# 遞迴層[2] - /wiki/%E5%BD%BC%E5%BE%97%E5%A4%A7%E5%B8%9D (彼得大帝)
# 遞迴層[2] - /wiki/18%E4%B8%96%E7%B4%80 (18世紀)
# 遞迴層[2] - /wiki/%E8%8B%B1%E5%9B%BD (英國)
# 遞迴層[2] - /wiki/%E5%9C%A3%E8%AF%9E%E6%8B%89%E7%82%AE (聖誕拉炮)
# 遞迴層[2] - /wiki/%E5%8A%8D%E6%A9%8B (劍橋)
# 遞迴層[2] - /wiki/%E5%A5%A5%E6%96%AF%E9%99%86 (奧斯陸)
# 遞迴層[2] - /wiki/%E7%AC%AC%E4%BA%8C%E6%AC%A1%E4%B8%96%E7%95%8C%E5%A4%A7%E6%88%98 (二戰)
# 遞迴層[2] - /wiki/%E7%89%B9%E6%8B%89%E6%B3%95%E5%8A%A0%E5%BB%A3%E5%A0%B4 (特拉法加廣場)
# 遞迴層[2] - /wiki/%E9%B8%BD%E5%AD%90%E5%B9%BF%E5%9C%BA (鴿子廣場)
# 遞迴層[2] - /wiki/%E5%BE%B7%E5%9B%BD (德國)
# 遞迴層[2] - /wiki/%E8%8D%B7%E5%85%B0 (荷蘭)
# 遞迴層[2] - /wiki/%E8%81%96%E5%B0%BC%E5%8F%A4%E6%8B%89%E7%AF%80 (聖尼古拉節)
# 遞迴層[2] - /wiki/%E9%BB%91%E5%BD%BC%E5%BE%97 (黑彼得)
# 遞迴層[2] - /wiki/%E5%A5%A5%E5%9C%B0%E5%88%A9 (奧地利)
# 遞迴層[2] - /wiki/%E7%91%9E%E5%A3%AB (瑞士)
# 遞迴層[2] - /wiki/%E5%8F%AF%E5%85%A7%E5%B8%8C%E7%89%B9%C2%B7%E9%AD%AF%E6%99%AE%E9%9B%B7%E5%B8%8C%E7%89%B9 (可內希特·魯普雷希特)
# 遞迴層[2] - /wiki/%E5%9D%8E%E5%8D%9C%E6%96%AF (坎卜斯)
# 遞迴層[2] - /wiki/%E4%B8%AD%E5%9C%8B (中國)
# 遞迴層[2] - /wiki/%E8%BE%B2%E6%9B%86%E6%96%B0%E5%B9%B4 (農曆新年)
# 遞迴層[2] - /wiki/%E6%89%8B%E5%B7%A5%E8%89%BA%E5%93%81 (手工藝品)
# 遞迴層[2] - /wiki/%E6%8B%9C%E5%B9%B4 (拜年)
# 遞迴層[2] - /wiki/%E5%AE%B6%E7%A6%BD (家禽)
# 遞迴層[2] - /wiki/%E5%BE%B7%E7%B4%AF%E6%96%AF%E9%A1%BF (德勒斯登)
# 遞迴層[2] - /wiki/%E4%B8%AD%E5%9B%BD%E5%88%B6%E9%80%A0 (中國製造)
# 遞迴層[2] - /wiki/%E5%9C%9F%E8%80%B3%E5%85%B6 (土耳其)
# 遞迴層[2] - /wiki/%E4%BA%9A%E6%B4%B2 (亞洲)
# 遞迴層[2] - /wiki/%E5%8A%A0%E6%8B%BF%E5%A4%A7 (加拿大)
# 遞迴層[2] - /wiki/%E9%AD%81%E5%8C%97%E5%85%8B%E7%9C%81 (魁北克省)
# 遞迴層[2] - /wiki/%E6%B3%95%E5%9B%BD (法國)
# 遞迴層[2] - /wiki/%E7%BA%BD%E7%BA%A6%E5%B8%82 (紐約)
# 遞迴層[2] - /wiki/%E6%B4%9B%E5%85%8B%E8%8F%B2%E5%8B%92%E4%B8%AD%E5%BF%83 (洛克菲勒中心)
# 遞迴層[2] - /wiki/%E5%8D%8E%E7%9B%9B%E9%A1%BF%E5%93%A5%E4%BC%A6%E6%AF%94%E4%BA%9A%E7%89%B9%E5%8C%BA (華盛頓)
# 遞迴層[2] - /wiki/%E7%99%BD%E5%AE%AB (白宮)
# 遞迴層[2] - /wiki/%E8%8B%B1%E8%81%94%E9%82%A6 (大英國協)
# 遞迴層[2] - /wiki/%E5%8C%97%E7%BE%8E%E7%A9%BA%E9%98%B2%E5%8F%B8%E4%BB%A4%E9%83%A8 (北美防空聯合司令部)
# 遞迴層[2] - /wiki/%E6%8B%89%E4%B8%81%E7%BE%8E%E6%B4%B2 (拉丁美洲)
# 遞迴層[2] - /wiki/%E7%BE%8E%E6%B4%B2%E5%9C%9F%E8%91%97 (美洲土著)
# 遞迴層[2] - /wiki/%E5%93%A5%E4%BC%A6%E6%AF%94%E4%BA%9A (哥倫比亞)
# 遞迴層[2] - /wiki/%E6%99%BA%E5%88%A9 (智利)
# 遞迴層[2] - /wiki/%E5%B7%B4%E8%A5%BF (巴西)
# 遞迴層[2] - /wiki/%E5%A4%8F%E5%AD%A3 (夏季)
# 遞迴層[2] - /wiki/%E9%98%BF%E6%A0%B9%E5%BB%B7 (阿根廷)
# 遞迴層[2] - /wiki/%E7%A7%98%E9%B2%81 (秘魯)
# 遞迴層[2] - /wiki/%E5%A2%A8%E8%A5%BF%E5%93%A5 (墨西哥)
# 遞迴層[2] - /wiki/%E4%BC%A0%E6%95%99%E5%A3%AB (傳教士)
# 遞迴層[2] - /wiki/%E4%BA%9E%E6%B4%B2 (亞洲)
# 遞迴層[2] - /wiki/%E9%A6%99%E6%B8%AF (香港)
# 遞迴層[2] - /wiki/%E8%8B%B1%E5%B1%AC%E9%A6%99%E6%B8%AF (殖民地時代)
# 遞迴層[2] - /wiki/%E8%8B%B1%E5%9C%8B (英國)
# 遞迴層[2] - /wiki/%E8%A5%BF%E6%96%B9%E6%96%87%E5%8C%96 (西方文化)
# 遞迴層[2] - /wiki/%E7%AF%80%E7%A6%AE%E6%97%A5 (節禮日)
# 遞迴層[2] - /wiki/%E9%A6%99%E6%B8%AF%E7%AF%80%E6%97%A5%E8%88%87%E5%85%AC%E7%9C%BE%E5%81%87%E6%9C%9F (香港節日與公眾假期)
# 遞迴層[2] - /wiki/1970%E5%B9%B4%E4%BB%A3%E9%A6%99%E6%B8%AF (1970年代)
# 遞迴層[2] - /wiki/%E6%94%BE%E5%81%87 (放假)
# 遞迴層[2] - /wiki/%E6%97%85%E9%81%8A (旅遊)
# 遞迴層[2] - /wiki/%E6%B6%88%E9%81%A3 (消遣)
# 遞迴層[2] - /wiki/%E6%8B%8D%E6%8B%96 (拍拖)
# 遞迴層[2] - /wiki/%E5%95%86%E5%A0%B4 (商場)
# 遞迴層[2] - /wiki/%E8%90%AC%E8%81%96%E5%A4%9C (萬聖夜)
# 遞迴層[2] - /wiki/%E8%90%AC%E8%81%96%E7%AF%80 (萬聖節)
# 遞迴層[2] - /wiki/%E7%87%88%E9%A3%BE (燈飾)
# 遞迴層[2] - /wiki/%E7%B6%AD%E5%A4%9A%E5%88%A9%E4%BA%9E%E6%B8%AF (維多利亞港)
# 遞迴層[2] - /wiki/%E5%B0%96%E6%B2%99%E5%92%80 (尖沙咀)
# 遞迴層[2] - /wiki/%E4%B8%AD%E7%92%B0 (中環)
# 遞迴層[2] - /wiki/%E7%9A%87%E5%90%8E%E5%83%8F%E5%BB%A3%E5%A0%B4 (皇后像廣場)
# 遞迴層[2] - /wiki/%E6%B4%BE%E5%B0%8D (派對)
# 遞迴層[2] - /wiki/%E8%81%96%E8%AA%95%E7%A6%AE%E7%89%A9 (聖誕禮物)
# 遞迴層[2] - /wiki/%E9%A6%99%E6%B8%AF%E8%82%A1%E5%B8%82 (股市)
# 遞迴層[2] - /wiki/%E5%B9%B3%E5%AE%89%E5%A4%9C (平安夜)
# 遞迴層[2] - /wiki/%E9%8A%85%E9%91%BC%E7%81%A3 (銅鑼灣)
# 遞迴層[2] - /wiki/%E8%98%AD%E6%A1%82%E5%9D%8A (蘭桂坊)
# 遞迴層[2] - /wiki/%E9%A6%99%E6%B8%AF%E5%A4%A7%E5%B0%88%E9%99%A2%E6%A0%A1 (大專院校)
# 遞迴層[2] - /wiki/%E5%85%83%E6%97%A6%E6%97%A5 (元旦日)
# 遞迴層[2] - /wiki/%E6%9A%91%E5%81%87 (暑假)
# 遞迴層[2] - /wiki/%E6%83%85%E4%BE%B6 (情侶)
# 遞迴層[2] - /wiki/%E6%83%85%E4%BA%BA%E7%AF%80 (情人節)
# 遞迴層[2] - /wiki/%E8%81%96%E8%AA%95%E8%80%81%E4%BA%BA (聖誕老人)
# 遞迴層[2] - /wiki/%E9%A6%99%E6%B8%AF%E9%83%B5%E6%94%BF (郵政署)
# 遞迴層[2] - /wiki/%E6%BE%B3%E9%96%80 (澳門)
# 遞迴層[2] - /wiki/%E8%91%A1%E8%90%84%E7%89%99 (葡萄牙)
# 遞迴層[2] - /wiki/%E6%BE%B3%E9%96%80%E5%85%AC%E7%9C%BE%E5%81%87%E6%9C%9F (澳門的公眾假期)
# 遞迴層[2] - /wiki/%E6%BE%B3%E9%96%80%E5%8D%9A%E5%BD%A9%E6%A5%AD (博彩業)
# 遞迴層[2] - /wiki/%E6%9C%8D%E5%8B%99%E6%A5%AD (服務業)
# 遞迴層[2] - /wiki/%E9%9B%B6%E5%94%AE (零售業)
# 遞迴層[2] - /wiki/%E6%BE%B3%E9%96%80%E5%9B%9E%E6%AD%B8 (澳門回歸紀念日)
# 遞迴層[2] - /wiki/%E6%AD%90%E9%99%B8 (歐陸)
# 遞迴層[2] - /wiki/%E8%AD%B0%E4%BA%8B%E4%BA%AD%E5%89%8D%E5%9C%B0 (議事亭前地)
# 遞迴層[2] - /wiki/%E5%A4%A7%E4%B8%89%E5%B7%B4%E7%89%8C%E5%9D%8A (大三巴牌坊)
# 遞迴層[2] - /wiki/%E6%96%B0%E5%8F%A3%E5%B2%B8%E6%96%B0%E5%A1%AB%E6%B5%B7%E5%8D%80 (皇朝區)
# 遞迴層[2] - /wiki/%E5%A1%94%E7%9F%B3%E5%BB%A3%E5%A0%B4 (塔石廣場)
# 遞迴層[2] - /wiki/%E5%8D%97%E7%81%A3%E6%B9%96%E5%BB%A3%E5%A0%B4 (南灣湖廣場)
# 遞迴層[2] - /wiki/%E6%BE%B3%E9%96%80%E6%BC%81%E4%BA%BA%E7%A2%BC%E9%A0%AD (漁人碼頭)
# 遞迴層[2] - /wiki/%E4%B8%BB%E6%95%99%E5%BA%A7%E5%A0%82 (主教座堂)
# 遞迴層[2] - /wiki/%E7%A6%AE%E7%89%A9 (禮物)
# 遞迴層[2] - /wiki/%E8%B3%80%E5%8D%A1 (賀卡)
# 遞迴層[2] - /wiki/%E8%87%BA%E7%81%A3%E7%AF%80%E6%97%A5 (中華民國國定假日)
# 遞迴層[2] - /wiki/%E4%B8%AD%E8%8F%AF%E6%B0%91%E5%9C%8B%E6%86%B2%E6%B3%95 (中華民國憲法)
# 遞迴層[2] - /wiki/%E4%BA%94%E5%A4%A9%E5%B7%A5%E4%BD%9C%E5%88%B6 (週休二日)
# 遞迴層[2] - /wiki/%E8%A1%8C%E6%94%BF%E9%99%A2 (行政院)
# 遞迴層[2] - /wiki/%E4%B8%AD%E8%8F%AF%E6%B0%91%E5%9C%8B%E7%B8%BD%E7%B5%B1 (總統)
# 遞迴層[2] - /wiki/%E9%99%B3%E6%B0%B4%E6%89%81 (陳水扁)
# 遞迴層[2] - /wiki/%E6%A2%B5%E8%92%82%E5%B2%A1 (梵蒂岡)
# 遞迴層[2] - /wiki/%E8%8B%A5%E6%9C%9B-%E9%A1%9E%E6%96%AF%C2%B7%E6%89%98%E6%9C%97 (陶然)
# 遞迴層[2] - /wiki/%E6%A8%9E%E6%A9%9F (樞機主教)
# 遞迴層[2] - /wiki/%E4%B8%AD%E8%8F%AF%E6%B0%91%E5%9C%8B%EF%BC%8D%E8%81%96%E5%BA%A7%E9%97%9C%E4%BF%82 (臺梵邦交)
# 遞迴層[2] - /wiki/%E4%BD%9B%E8%AA%95 (佛誕)
# 遞迴層[2] - /wiki/%E4%B8%AD%E5%9B%BD%E5%A4%A7%E9%99%86 (中國大陸)
# 遞迴層[2] - /wiki/%E4%B8%AD%E5%8D%8E%E4%BA%BA%E6%B0%91%E5%85%B1%E5%92%8C%E5%9B%BD%E8%8A%82%E6%97%A5%E4%B8%8E%E5%85%AC%E4%BC%97%E5%81%87%E6%9C%9F (法定假日)
# 遞迴層[2] - /wiki/%E6%94%B9%E9%9D%A9%E5%BC%80%E6%94%BE (改革開放)
# 遞迴層[2] - /wiki/%E5%95%86%E5%9C%88 (商圈)
# 遞迴層[2] - /wiki/%E8%98%8B%E6%9E%9C (蘋果)
# 遞迴層[2] - /wiki/%E5%A4%8F%E5%A8%83 (夏娃)
# 遞迴層[2] - /wiki/%E7%A6%81%E6%9E%9C (禁果)
# 遞迴層[2] - /wiki/%E6%B9%96%E5%8D%97%E7%9C%81 (湖南)
# 遞迴層[2] - /wiki/%E8%A1%A1%E9%98%B3%E5%B8%82 (衡陽市)
# 遞迴層[2] - /wiki/%E5%8D%97%E5%8D%8E%E5%A4%A7%E5%AD%A6_(%E6%B9%96%E5%8D%97) (南華大學)
# 遞迴層[2] - /wiki/%E9%87%8D%E5%BA%86%E5%B8%82 (重慶)
# 遞迴層[2] - /wiki/%E5%8D%97%E4%BA%AC%E5%B8%82 (南京市)
# 遞迴層[2] - /wiki/%E8%A7%A3%E6%94%BE%E7%A2%91 (解放碑)
# 遞迴層[2] - /wiki/%E6%97%A5%E6%9C%AC (日本)
# 遞迴層[2] - /wiki/%E7%A5%9E%E9%81%93 (神道教)
# 遞迴層[2] - /wiki/%E6%97%A5%E6%9C%AC%E4%BD%9B%E6%95%99 (佛教)
# 遞迴層[2] - /wiki/%E6%97%A5%E6%9C%AC%E7%AF%80%E6%97%A5 (國定假日)
# 遞迴層[2] - /wiki/%E5%AF%92%E5%81%87 (冬休)
# 遞迴層[2] - /wiki/%E5%A4%A9%E7%9A%87 (天皇)
# 遞迴層[2] - /wiki/%E6%98%8E%E4%BB%81 (明仁)
# 遞迴層[2] - /wiki/%E7%94%9F%E6%97%A5 (生日)
# 遞迴層[2] - /wiki/%E5%A4%A9%E7%9A%87%E8%AA%95%E7%94%9F%E6%97%A5 (天皇誕生日)
# 遞迴層[2] - /wiki/%E6%97%A5%E6%9C%AC%E5%9C%8B%E6%86%B2%E6%B3%95 (日本國憲法)
# 遞迴層[2] - /wiki/%E6%94%BF%E6%95%99%E5%88%86%E9%9B%A2 (政教分離)
# 遞迴層[2] - /wiki/%E6%97%A5%E6%9C%AC%E6%B3%95%E5%BE%8B (日本法律)
# 遞迴層[2] - /wiki/%E8%82%AF%E5%BE%B7%E5%9F%BA (肯德基)
# 遞迴層[2] - /wiki/%E7%82%B8%E9%9B%9E (炸雞)
# 遞迴層[2] - /wiki/%E6%84%9B%E6%83%85 (愛情)
# 遞迴層[2] - /wiki/%E6%97%85%E9%A4%A8 (旅館)
# 遞迴層[2] - /wiki/%E6%95%99%E5%A0%82 (教堂)
# 遞迴層[2] - /wiki/%E5%8D%B0%E5%BA%A6 (印度)
# 遞迴層[2] - /wiki/%E5%8D%B0%E5%9C%B0%E8%AA%9E (印地語)
# 遞迴層[2] - /wiki/%E8%8F%B2%E5%BE%8B%E8%B3%93 (菲律賓)
# 遞迴層[2] - /wiki/%E4%BC%8A%E4%B8%B9%E5%A5%B6%E9%85%AA (伊丹奶酪)
# 遞迴層[2] - /wiki/%E9%9F%A9%E5%9B%BD (韓國)
# 遞迴層[2] - /wiki/%E9%A9%AC%E6%9D%A5%E8%A5%BF%E4%BA%9A (馬來西亞)
# 遞迴層[2] - /wiki/%E6%96%B0%E5%8A%A0%E5%9D%A1 (新加坡)
# 遞迴層[2] - /wiki/%E4%B8%9C%E5%B8%9D%E6%B1%B6 (東帝汶)
# 遞迴層[2] - /wiki/%E6%BE%B3%E5%A4%A7%E5%88%A9%E4%BA%9A (澳大利亞)
# 遞迴層[2] - /wiki/%E6%96%B0%E8%A5%BF%E5%85%B0 (紐西蘭)
# 遞迴層[2] - /wiki/%E5%86%AC%E5%AD%A3 (冬季)
# 遞迴層[2] - /wiki/%E8%8D%B7%E9%87%8C%E6%B4%BB (好萊塢)
# 遞迴層[2] - /wiki/%E6%B9%AF%C2%B7%E6%BC%A2%E6%96%AF (湯·漢斯)
# 遞迴層[2] - /wiki/%E6%AF%94%E5%B0%94%C2%B7%E7%9B%96%E8%8C%A8 (蓋茨)
# 遞迴層[2] - /wiki/%E6%BE%B3%E6%96%B0%E5%86%9B%E5%9B%A2%E6%97%A5 (澳新軍團日)
# 遞迴層[2] - /wiki/%E7%A5%9E%E8%A9%B1%E6%95%85%E4%BA%8B (神話故事)
# 遞迴層[2] - /wiki/%E5%A5%87%E8%BF%B9 (奇蹟)
# 遞迴層[2] - /wiki/%E5%BD%BC%E5%BE%97%C2%B7%E4%BC%8A%E9%87%8C%E5%A5%87%C2%B7%E6%9F%B4%E7%A7%91%E5%A4%AB%E6%96%AF%E5%9F%BA (柴可夫斯基)
# 遞迴層[2] - /wiki/%E8%83%A1%E6%A1%83%E5%A4%B9%E5%AD%90 (胡桃鉗)
# 遞迴層[2] - /wiki/%E6%9F%A5%E5%B0%94%E6%96%AF%C2%B7%E7%8B%84%E6%9B%B4%E6%96%AF (查爾斯·狄更斯)
# 遞迴層[2] - /wiki/%E5%B0%8F%E6%B0%A3%E8%B2%A1%E7%A5%9E (小氣財神)
# 遞迴層[2] - /wiki/%E6%96%AF%E5%A0%AA%E7%9A%84%E7%BA%B3%E7%BB%B4%E4%BA%9A (斯堪地那維亞)
# 遞迴層[2] - /wiki/%E6%BC%A2%E6%96%AF%C2%B7%E5%85%8B%E9%87%8C%E6%96%AF%E8%92%82%E5%AE%89%C2%B7%E5%AE%89%E5%BE%92%E7%94%9F (安徒生)
# 遞迴層[2] - /wiki/%E9%85%97%E9%85%92 (酗酒)
# 遞迴層[2] - /wiki/%E7%94%B5%E5%BD%B1 (電影)
# 遞迴層[2] - /wiki/%E7%94%B5%E8%A7%86 (電視)
# 遞迴層[2] - /wiki/%E9%A3%8E%E4%BA%91%E4%BA%BA%E7%89%A9 (風雲人物)
# 遞迴層[2] - /wiki/%E6%9F%A5%E7%90%86%C2%B7%E5%B8%83%E6%9C%97%E7%9A%84%E8%81%96%E8%AA%95%E7%AF%80 (查理·布朗的聖誕節)
# 遞迴層[2] - /wiki/%E6%9F%A5%E7%90%86%C2%B7%E5%B8%83%E6%9C%97 (查理·布朗)
# 遞迴層[2] - /wiki/%E5%B9%B3%E5%AE%89%E5%A4%9C_(%E6%AD%8C%E6%9B%B2) (平安夜)
# 遞迴層[2] - /wiki/%E6%A0%BC%E5%A5%A5%E5%B0%94%E6%A0%BC%C2%B7%E5%BC%97%E9%87%8C%E5%BE%B7%E9%87%8C%E5%B8%8C%C2%B7%E4%BA%A8%E5%BE%B7%E5%B0%94 (亨德爾)
# 遞迴層[2] - /wiki/%E5%BC%A5%E8%B5%9B%E4%BA%9A_(%E4%BA%A8%E5%BE%B7%E5%B0%94) (彌賽亞)
# 遞迴層[2] - /wiki/%E8%83%A1%E6%A1%83%E9%89%97 (胡桃鉗)
# 遞迴層[2] - /wiki/%E7%BA%A6%E7%BF%B0%C2%B7%E5%A1%9E%E5%B7%B4%E6%96%AF%E8%92%82%E5%AE%89%C2%B7%E5%B7%B4%E8%B5%AB (約翰·塞巴斯蒂安·巴赫)
# 遞迴層[2] - /wiki/%E6%86%82%E9%AC%B1%E7%97%87 (憂鬱症)
# 遞迴層[2] - /wiki/%E8%87%AA%E6%9D%80 (自殺)
# 遞迴層[2] - /wiki/%E8%B0%8B%E6%9D%80 (謀殺)
# 遞迴層[2] - /wiki/%E9%85%92%E7%B2%BE (酒精)
# 遞迴層[2] - /wiki/%E6%84%9F%E6%81%A9%E8%8A%82 (感恩節)
# 遞迴層[2] - /wiki/%E7%A6%8F%E9%9F%B3%E6%B4%BE (福音派)
# 遞迴層[2] - /wiki/%E5%9F%BA%E7%9D%A3%E5%BE%92 (基督徒)
# 遞迴層[2] - /wiki/%E7%A5%A8%E6%88%BF (票房)
# 遞迴層[2] - /wiki/%E5%A5%A5%E6%96%AF%E5%8D%A1%E9%87%91%E5%83%8F%E5%A5%96 (奧斯卡獎)
# 遞迴層[1] - /wiki/WorldWideWeb (WorldWideWeb)
# 遞迴層[2] - /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 (全球資訊網)
# 遞迴層[2] - /wiki/%E7%B6%B2%E9%A0%81%E7%80%8F%E8%A6%BD%E5%99%A8 (網頁瀏覽器)
# 遞迴層[2] - /wiki/%E6%89%80%E8%A6%8B%E5%8D%B3%E6%89%80%E5%BE%97 (所見即所得)
# 遞迴層[2] - /wiki/HTML%E7%B7%A8%E8%BC%AF%E5%99%A8 (網頁編輯器)
# 遞迴層[2] - /wiki/%E6%8F%90%E5%A7%86%C2%B7%E6%9F%8F%E5%85%A7%E8%8C%B2-%E6%9D%8E (提姆·柏內茲-李)
# 遞迴層[1] - /wiki/%E7%B6%B2%E9%A0%81%E4%BC%BA%E6%9C%8D%E5%99%A8 (網頁伺服器)
# 遞迴層[2] - /wiki/HTTP (HTTP)
# 遞迴層[2] - /wiki/HTML (HTML)
# 遞迴層[2] - /wiki/URL (URL)
# 遞迴層[2] - /wiki/Apache (Apache)
# 遞迴層[2] - /wiki/IIS (IIS)
# 遞迴層[2] - /wiki/Nginx (Nginx)
# 遞迴層[1] - /wiki/%E6%96%B0%E9%97%BB%E7%BB%84 (新聞群組)
# 遞迴層[2] - /wiki/Usenet (Usenet)
# 遞迴層[2] - /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 (全球資訊網)
# 遞迴層[2] - /wiki/%E8%AE%BA%E5%9D%9B (論壇)
# 遞迴層[2] - /wiki/NNTP (NNTP)
# 遞迴層[2] - /wiki/Fort%C3%A9_Agent (Forté Agent)
# 遞迴層[2] - /wiki/Opera (Opera)
# 遞迴層[2] - /wiki/Outlook_Express (Outlook Express)
# 遞迴層[2] - /wiki/Windows_Mail (Windows Mail)
# 遞迴層[2] - /wiki/Netscape (Netscape)
# 遞迴層[2] - /wiki/Mozilla (Mozilla)
# 遞迴層[2] - /wiki/Mozilla_Thunderbird (Mozilla Thunderbird)
# 遞迴層[2] - /wiki/Emacs (Emacs)
# 遞迴層[2] - /wiki/INN (INN)
# 遞迴層[2] - /wiki/Wikipedia:%E4%B8%8D%E8%A6%81%E6%A8%A1%E6%A3%B1%E4%B8%A4%E5%8F%AF ([何時？])
# 遞迴層[2] - /wiki/%E6%9C%8D%E5%8A%A1%E5%99%A8 (伺服器)
# 遞迴層[2] - /wiki/WWW (WWW)
# 遞迴層[2] - /wiki/BBS (BBS)
# 遞迴層[2] - /wiki/%E5%AE%A2%E6%88%B7%E7%AB%AF (客戶端)
# 遞迴層[2] - /wiki/%E6%96%B0%E5%B8%86%E6%96%B0%E9%97%BB%E7%BB%84 (新帆新聞群組)
# 遞迴層[2] - /wiki/Google_Groups (Google Groups)
# 遞迴層[2] - /wiki/Alt.chinese.text (ACT)
# 遞迴層[2] - /wiki/Wikipedia:%E5%A4%B1%E6%95%88%E9%93%BE%E6%8E%A5 (永久失效連結)
# 遞迴層[2] - /wiki/Google (Google)
# 遞迴層[2] - /wiki/Google#Google网上论坛（新闻组） (Google Groups)
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-50-5bcc6df82908> in <module>
#       2 max_recursive_depth = 2
#       3
# ----> 4 WikiArticle(root_keyword_link, input_keyword, 0)
#
# <ipython-input-49-302e31d22a57> in WikiArticle(key_word_link, key_word, recursive)
#      86
#      87             for k, v in external_link_dict.items():
# ---> 88                 WikiArticle(k, v, recursive)  # 再次呼叫同樣的函數，執行同樣的流程
#      89
#
# <ipython-input-49-302e31d22a57> in WikiArticle(key_word_link, key_word, recursive)
#      86
#      87             for k, v in external_link_dict.items():
# ---> 88                 WikiArticle(k, v, recursive)  # 再次呼叫同樣的函數，執行同樣的流程
#      89
#
# <ipython-input-49-302e31d22a57> in WikiArticle(key_word_link, key_word, recursive)
#      24
#      25         url = 'https://zh.wikipedia.org' + key_word_link  # 組合關鍵字查詢URL
# ---> 26         resp = requests.get(url, headers=headers)
#      27         resp.encoding = 'utf-8'
#      28
#
# D:\miniconda\envs\jupyter\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# D:\miniconda\envs\jupyter\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# D:\miniconda\envs\jupyter\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# D:\miniconda\envs\jupyter\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# D:\miniconda\envs\jupyter\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# D:\miniconda\envs\jupyter\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# D:\miniconda\envs\jupyter\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     352             conn.request_chunked(method, url, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#     356         # Reset the timeout for the recv() on the socket
#
# D:\miniconda\envs\jupyter\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1250                 encode_chunked=False):
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#    1254     def _send_request(self, method, url, body, headers, encode_chunked):
#
# D:\miniconda\envs\jupyter\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1291
#    1292         for hdr, value in headers.items():
# -> 1293             self.putheader(hdr, value)
#    1294         if isinstance(body, str):
#    1295             # RFC 2616 Section 3.7.1 says that text default has a
#
# D:\miniconda\envs\jupyter\lib\http\client.py in putheader(self, header, *values)
#    1223         for i, one_value in enumerate(values):
#    1224             if hasattr(one_value, 'encode'):
# -> 1225                 values[i] = one_value.encode('latin-1')
#    1226             elif isinstance(one_value, int):
#    1227                 values[i] = str(one_value).encode('ascii')
#
# UnicodeEncodeError: 'latin-1' codec can't encode characters in position 25-33: ordinal not in range(256)
