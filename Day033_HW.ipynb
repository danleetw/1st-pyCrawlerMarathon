# %% [markdown]
# # 反爬：登入授權模擬
#
# * 了解「登入權限機制」的反爬蟲機制
# * 「登入權限機制」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）

# %%
'''
Your Code
'''
import requests
from bs4 import BeautifulSoup


cookies = {'user_session': 'W7VpAgLcUouEd-m9Ql46l1O2_bFFRxT_DK4tG030OEtFUXT_'}

rs = requests.session()
payload={
    'login':'xxxxxx',
    'password': 'xxxxxx',
    'authenticity_token':'mmEHnqN/UGhfIbDFYWBCf6guwbFTTTjPvujgEQEQx+iM2FbFbEQ1YTVYFQD1t5hSBDMqNkdughnCqfoYPMbTvg=='
}

res = requests.get('https://github.com/session',cookies=cookies)
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# GitHub
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to content
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Search
#
#
#         All GitHub
#
# ↵
#
#
#       Jump to
#       ↵
#
#
#
#
#
#
# No suggested jump to results
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Search
#
#
#         All GitHub
#
# ↵
#
#
#       Jump to
#       ↵
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Search
#
#
#         All GitHub
#
# ↵
#
#
#       Jump to
#       ↵
#
#
#
#
#
#
#
#
#
#
#
#
#
#       Dashboard
#
#
#     Pull requests
#
#
#     Issues
#
#
#
#         Marketplace
#
#
#
#     Explore
#
#
#
#       susan8213
#
#
#
#
#         Sign out
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   New repository
#
#
#     Import repository
#
#
#   New gist
#
#
#     New organization
#
#
#     New project
#
#
#
#
#
#
#
#
#
#
#
#
# Signed in as susan8213
#
#
#
#
#
#
#
#
#
#
#
#
#
# Set status
#
#
#
#
#
#
#
# ...
