# %% [markdown]
# # YAHOO電影爬蟲練習
# ## 練習爬取電影放映資訊。必須逐步獲取電影的代號、放映地區、放映日期後，再送出查詢給伺服器。

# %%
import requests
import re
from bs4 import BeautifulSoup

# %% [markdown]
# ### 先搜尋全部的電影代號(ID)資訊

# %%
# 查看目前上映那些電影，並擷取出其ID資訊
url = 'https://movies.yahoo.com.tw/'
resp = requests.get(url)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
html = soup.find("select", attrs={'name':'movie_id'})
movie_item = html.find_all("option", attrs={'data-name':re.compile('.*')})

for p in movie_item:
    print("Movie: %s, ID: %s" % (p["data-name"], p["value"]))
# Out:
# Movie: 復仇母親, ID: 10392
# Movie: 風暴過後, ID: 10387
# Movie: 南方車站的聚會, ID: 10380
# Movie: 祭旗, ID: 10373
# Movie: 唯你是愛, ID: 10370
# Movie: 屍控療法, ID: 10367
# Movie: 黑熊來了, ID: 10357
# Movie: 唐人街探案2, ID: 10353
# Movie: 黑計畫, ID: 10351
# Movie: HUMAN LOST人間失格, ID: 10348
# Movie: 假面騎士劇場版ZI-O Over Quartzer, ID: 10331
# Movie: 巴黎小情聖, ID: 10329
# Movie: 每個月來訪一次的月經醬, ID: 10324
# Movie: 8級警戒, ID: 10323
# Movie: 為你存在的每一天, ID: 10297
# Movie: 黑色聖誕節, ID: 10291
# Movie: 熱氣球飛行家, ID: 10257
# Movie: 大說謊家, ID: 10122
# Movie: 特約經紀公司, ID: 10364
# Movie: 一屍到底番外篇：好萊塢大作戰！, ID: 10352
# Movie: 花生醬獵鷹的願望, ID: 10340
# Movie: 女孩要革命, ID: 10339
# Movie: 我的靈魂是愛做的, ID: 10336
# Movie: 絕世情歌, ID: 10328
# Movie: 人間失格：太宰治與他的3個女人, ID: 10287
# Movie: 抓狂博物館, ID: 10279
# Movie: 呆萌特務, ID: 10264
# Movie: 去年聖誕節, ID: 10256
# Movie: 野蠻遊戲：全面晉級, ID: 10134
# Movie: 夕霧花園, ID: 10327
# Movie: 懸案密碼前傳：瓶中信, ID: 10254
# Movie: 布魯克林孤兒, ID: 10224
# Movie: 暴走曼哈頓, ID: 10044
# Movie: 鋒迴路轉, ID: 10258
# Movie: 賽道狂人, ID: 10097
# Movie: 麂皮：永不滿足, ID: 10358
# Movie: 82年生的金智英, ID: 10298
# Movie: BanG Dream！ FILM LIVE, ID: 10271
# Movie: 冰雪奇緣2, ID: 9597
# Movie: 萬萬沒想到, ID: 10281
# Movie: 山田孝之的痛苦與榮耀, ID: 10301
# Movie: 決戰中途島, ID: 10130
# Movie: 安眠醫生, ID: 10098
# Movie: 魔鬼終結者：黑暗宿命, ID: 10067
# Movie: 陽光普照, ID: 10240
# Movie: 狙擊獵殺：救援行動, ID: 10284
# Movie: 雙子殺手, ID: 10017
# Movie: 盲人律師, ID: 10267
# Movie: 黑魔女2, ID: 10262
# Movie: 電影版 壞傢伙們, ID: 10249
# Movie: 藍波：最後一滴血, ID: 10205
# Movie: 屍樂園：髒比雙拼, ID: 10176
# Movie: 弒婚遊戲, ID: 10171
# Movie: 108悍將, ID: 10238
# Movie: 小丑, ID: 9949
# Movie: 校外打怪教學, ID: 10200
# Movie: 信用詐欺師JP, ID: 10190
# Movie: 無間行動, ID: 10155
# Movie: 星際救援, ID: 10227
# Movie: 返校, ID: 10109
# Movie: 唐頓莊園, ID: 10064
# Movie: 舞孃騙很大, ID: 10199
# Movie: 花椒之味, ID: 10158
# Movie: 好小男孩, ID: 9894
# Movie: 牠 第二章, ID: 10042
# Movie: 極限逃生, ID: 10174
# Movie: 你願意嫁給我老公嗎？, ID: 10141
# Movie: 下半場, ID: 9807
# Movie: 全面攻佔3：天使救援, ID: 10082
# Movie: 普羅米亞, ID: 10119
# Movie: 朵拉與失落的黃金城, ID: 9920
# Movie: 獅子王, ID: 9116
# Movie: 玩具總動員4, ID: 9924
# Movie: 毀滅者, ID: 9405
# Movie: 庫爾斯克號：深海救援, ID: 9134
# Movie: 厄夜追緝令, ID: 9589
# Movie: 苦兒流浪記, ID: 9538
# Movie: 活個精彩, ID: 9394
# Movie: 限時好友, ID: 9578
# Movie: 祝你忌日快樂, ID: 9568
# Movie: 艾莉塔：戰鬥天使, ID: 8553
# Movie: 馴龍高手3, ID: 8350
# Movie: 幸福綠皮書, ID: 9150
# Movie: 貝士浮生錄, ID: 6906
# Movie: 一首搖滾上月球, ID: 4887
# Movie: 錢不夠用2, ID: 3026

# %% [markdown]
# ### 指定你有興趣的電影其ID，然後查詢其放映地區資訊。

# %%
# 參考前一個步驟中擷取到的ID資訊，並指定ID
movie_id = 10256

# %%
url = 'https://movies.yahoo.com.tw/api/v1/areas_by_movie_theater'
payload = {'movie_id':str(movie_id)}

# 模擬一個header
headers = {
    'authority': 'movies.yahoo.com.tw',
    'method': 'GET',
    'path': '/api/v1/areas_by_movie_theater?movie_id=' + str(movie_id),
    'scheme': 'https',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'rxx=9s3x2fws06.1g16irnc&v=1; _ga=GA1.3.2056742944.1551651301; GUC=AQEBAQFczFpdm0IfmwSB&s=AQAAACoo4N5D&g=XMsVBw; BX=4hkdk1decm57t&b=3&s=mr; _ga=GA1.4.2056742944.1551651301; nexagesuid=82843256dd234e8e91aa73f2062f8218; browsed_movie=; avi=eyJpdiI6Im1NeWFJRlVRWDR1endEcGRGUGJUbVE9PSIsInZhbHVlIjoickRpU3JuUytmcGl6cjF5OW0rNU9iZz09IiwibWFjIjoiY2VmY2NkNzZmM2NhNjY5YzlkOTcyNjE5OGEyMzU0NWYxOTdmMDRkMDY3OWNmMmZjOTMxYjc5MjI5N2Q5NGE5MiJ9; cmp=t=1559391030&j=0; _gid=GA1.4.779543841.1559391031; XSRF-TOKEN=%3D; m_s=; _gat=1; nexagesd=10',
    'dnt': '1',
    'mv-authorization': '21835b082e15b91a69b3851eec7b31b82ce82afb',
    'referer': 'https://movies.yahoo.com.tw/',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}
    
resp = requests.get(url, params=payload, headers=headers)
#print(resp.json())  # 若有需要，列印出json原始碼

# 這裡回傳的格式是JSON格式的資料，要解析JSON擷取資料
for p in resp.json():
    print('放映地區: {0}, 代號(area_id): {1}'.format(p['title'], p['area_id']))
# Out:
# 放映地區: 台北市, 代號(area_id): 28
# 放映地區: 新北市, 代號(area_id): 8
# 放映地區: 桃園, 代號(area_id): 16
# 放映地區: 新竹, 代號(area_id): 20
# 放映地區: 苗栗, 代號(area_id): 15
# 放映地區: 台中, 代號(area_id): 2
# 放映地區: 彰化, 代號(area_id): 22
# 放映地區: 雲林, 代號(area_id): 19
# 放映地區: 嘉義, 代號(area_id): 21
# 放映地區: 台南, 代號(area_id): 10
# 放映地區: 高雄, 代號(area_id): 17
# 放映地區: 基隆, 代號(area_id): 18
# 放映地區: 花蓮, 代號(area_id): 12
# 放映地區: 金門, 代號(area_id): 24
# 放映地區: 澎湖, 代號(area_id): 23

# %% [markdown]
# ### 指定你想要觀看的放映地區，查詢有上映電影的場次日期

# %%
# 指定放映地區
area_id = 8

# %%
# 向網站發送請求
url = 'https://movies.yahoo.com.tw/movietime_result.html'
payload = {'movie_id':str(movie_id), 'area_id':str(area_id)}
resp = requests.get(url, params=payload)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
movie_date = soup.find_all("label", attrs={'for':re.compile("date_[\d]")})

# 列印播放日期
for date in movie_date:
    print("%s %s" % (date.p.string, date.h3.string))
# Out:
# 十二月 16
# 十二月 17
# 十二月 18
# 十二月 19
# 十二月 20

# %% [markdown]
# ### 最後指定觀看的日期，查詢並列印出放映的電影院、放映類型(數位、3D、IMAX 3D...)、放映時間等資訊。

# %%
# 選定要觀看的日期
date = "2019-12-16"

# %%
# 向網站發送請求，獲取上映的電影院及時間資訊
url = "https://movies.yahoo.com.tw/ajax/pc/get_schedule_by_movie"
payload = {'movie_id':str(movie_id),
           'date':date,
           'area_id':str(area_id),
           'theater_id':'',
           'datetime':'',
           'movie_type_id':''}

resp = requests.get(url, params=payload)
print(resp.json()['view'])  # 若有需要，列印出json原始碼

soup = BeautifulSoup(resp.json()['view'], 'lxml')
html = soup.find_all("ul", attrs={'data-theater_name':re.compile(".*")})
# Out:
# <div class="pc-movie-schedule-form">
#     <div class="area_timebox">
#    <div class="area_title">新北市</div>
#       <ul id="theater_id_56" class="area_time _c jq_area_time" data-theater_name="鴻金寶麻吉影城" data-theater_url="http://machicinema.wordpress.com/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=56" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=56">鴻金寶麻吉影城</a>
#            <span>02-22070222</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                    <input type="radio" name="schedule_list" id="72590943" class="gabtn"
#                         value="2019-12-16 13:05:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="13:05"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72590943" class="">13:05</label>
#                                                                     <input type="radio" name="schedule_list" id="72590944" class="gabtn"
#                         value="2019-12-16 18:05:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="18:05"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72590944" class="">18:05</label>
#                                                                     <input type="radio" name="schedule_list" id="72590945" class="gabtn"
#                         value="2019-12-16 23:40:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="23:40"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72590945" class="select">23:40</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_57" class="area_time _c jq_area_time" data-theater_name="三重天台戲院" data-theater_url="http://www.t-movies.com.tw/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=57" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=57">三重天台戲院</a>
#            <span>02-29787700</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                    <input type="radio" name="schedule_list" id="72590969" class="gabtn"
#                         value="2019-12-16 10:10:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="10:10"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72590969" class="">10:10</label>
#                                                                     <input type="radio" name="schedule_list" id="72590970" class="gabtn"
#                         value="2019-12-16 14:05:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="14:05"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72590970" class="">14:05</label>
#                                                                     <input type="radio" name="schedule_list" id="72590971" class="gabtn"
#                         value="2019-12-16 18:15:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="18:15"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72590971" class="">18:15</label>
#                                                                     <input type="radio" name="schedule_list" id="72590972" class="gabtn"
#                         value="2019-12-16 20:10:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="20:10"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72590972" class="select">20:10</label>
#                                                                     <input type="radio" name="schedule_list" id="72590973" class="gabtn"
#                         value="2019-12-16 22:05:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="22:05"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72590973" class="select">22:05</label>
#                                                                     <input type="radio" name="schedule_list" id="72590974" class="gabtn"
#                         value="2019-12-17 00:00:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.17"
#                         data-movie_time="00:00"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72590974" class="select">00:00</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_59" class="area_time _c jq_area_time" data-theater_name="國賓影城(中和環球購物中心)" data-theater_url="http://www.ambassador.com.tw/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=59" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=59">國賓影城(中和環球購物中心)</a>
#            <span>02-22268088</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                    <input type="radio" name="schedule_list" id="72592335" class="gabtn"
#                         value="2019-12-16 13:15:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="13:15"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72592335" class="">13:15</label>
#                                                                     <input type="radio" name="schedule_list" id="72592336" class="gabtn"
#                         value="2019-12-16 17:35:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="17:35"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72592336" class="">17:35</label>
#                                                                     <input type="radio" name="schedule_list" id="72592337" class="gabtn"
#                         value="2019-12-16 22:00:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="22:00"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72592337" class="select">22:00</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_128" class="area_time _c jq_area_time" data-theater_name="板橋大遠百威秀影城" data-theater_url="http://www.vscinemas.com.tw/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=128" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=128">板橋大遠百威秀影城</a>
#            <span>02-77386608</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                                    <input type="radio" name="schedule_list" id="72570558" class="gabtn"
#                         value="2019-12-16 21:35:00"  data-movie="570a9b68a41046efabd02ce4827fe5ff"
#                         data-cinema="737ece862a0111e18e86000bdb90dba4" data-session="1258a854e8744c8d821fb090ba570468"
#                         data-date="1576425600" data-time="1576503300"
#                         data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="21:35"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-ezding="ezding"
#                         />
#                     <label for="72570558" class="select">21:35</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_154" class="area_time _c jq_area_time" data-theater_name="板橋秀泰影城" data-theater_url="http://www.showtimes.com.tw/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=154" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=154">板橋秀泰影城</a>
#            <span>02-22720639</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                    <input type="radio" name="schedule_list" id="72592656" class="gabtn"
#                         value="2019-12-16 10:30:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="10:30"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72592656" class="">10:30</label>
#                                                                     <input type="radio" name="schedule_list" id="72592657" class="gabtn"
#                         value="2019-12-16 12:30:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="12:30"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72592657" class="">12:30</label>
#                                                                     <input type="radio" name="schedule_list" id="72592658" class="gabtn"
#                         value="2019-12-16 18:30:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="18:30"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72592658" class="">18:30</label>
#                                                                     <input type="radio" name="schedule_list" id="72592659" class="gabtn"
#                         value="2019-12-16 20:30:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="20:30"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72592659" class="select">20:30</label>
#                                                                     <input type="radio" name="schedule_list" id="72592660" class="gabtn"
#                         value="2019-12-16 22:30:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="22:30"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72592660" class="select">22:30</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_180" class="area_time _c jq_area_time" data-theater_name="國賓影城(林口昕境廣場)" data-theater_url="http://www.ambassador.com.tw/aboutus_a9.html" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=180" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=180">國賓影城(林口昕境廣場)</a>
#            <span>02-26080011</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                    <input type="radio" name="schedule_list" id="72592881" class="gabtn"
#                         value="2019-12-16 13:00:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="13:00"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72592881" class="">13:00</label>
#                                                                     <input type="radio" name="schedule_list" id="72592882" class="gabtn"
#                         value="2019-12-16 15:00:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="15:00"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72592882" class="">15:00</label>
#                                                                     <input type="radio" name="schedule_list" id="72592883" class="gabtn"
#                         value="2019-12-16 17:30:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="17:30"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72592883" class="">17:30</label>
#                                                                     <input type="radio" name="schedule_list" id="72592884" class="gabtn"
#                         value="2019-12-16 19:30:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="19:30"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72592884" class="select">19:30</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_185" class="area_time _c jq_area_time" data-theater_name="國賓影城(新莊晶冠廣場)" data-theater_url="http://www.ambassador.com.tw/showtime_list.html?theaterid=3301d822-b385-4aa8-a9eb-aa59d58e95c9" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=185" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=185">國賓影城(新莊晶冠廣場)</a>
#            <span>(02)8521-6517</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                    <input type="radio" name="schedule_list" id="72593016" class="gabtn"
#                         value="2019-12-16 11:10:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="11:10"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72593016" class="">11:10</label>
#                                                                     <input type="radio" name="schedule_list" id="72593017" class="gabtn"
#                         value="2019-12-16 13:45:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="13:45"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72593017" class="">13:45</label>
#                                                                     <input type="radio" name="schedule_list" id="72593018" class="gabtn"
#                         value="2019-12-16 16:50:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="16:50"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72593018" class="">16:50</label>
#                                                                     <input type="radio" name="schedule_list" id="72593019" class="gabtn"
#                         value="2019-12-16 20:30:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="20:30"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72593019" class="select">20:30</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_193" class="area_time _c jq_area_time" data-theater_name="林口MITSUI OUTLET PARK威秀影城" data-theater_url="http://www.vscinemas.com.tw/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=193" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=193">林口MITSUI OUTLET PARK威秀影城</a>
#            <span>02-26068099</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                                    <input type="radio" name="schedule_list" id="72566089" class="gabtn"
#                         value="2019-12-16 21:45:00"  data-movie="41b112a5c0a0429f8c4a63d7478da189"
#                         data-cinema="73544d843cd311e69bb83d0f96c001c2" data-session="f03f460cf394415ba0274824a2872ffc"
#                         data-date="1576425600" data-time="1576503900"
#                         data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="21:45"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-ezding="ezding"
#                         />
#                     <label for="72566089" class="select">21:45</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_214" class="area_time _c jq_area_time" data-theater_name="樹林秀泰影城" data-theater_url="https://www.showtimes.com.tw/events?corpId=54" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=214" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=214">樹林秀泰影城</a>
#            <span>02-26868769</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                    <input type="radio" name="schedule_list" id="72593413" class="gabtn"
#                         value="2019-12-16 11:30:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="11:30"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72593413" class="">11:30</label>
#                                                                     <input type="radio" name="schedule_list" id="72593414" class="gabtn"
#                         value="2019-12-16 15:40:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="15:40"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72593414" class="">15:40</label>
#                                                                     <input type="radio" name="schedule_list" id="72593415" class="gabtn"
#                         value="2019-12-16 19:50:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="19:50"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72593415" class="select">19:50</label>
#                                                                     <input type="radio" name="schedule_list" id="72593416" class="gabtn"
#                         value="2019-12-16 21:50:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="21:50"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72593416" class="select">21:50</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_237" class="area_time _c jq_area_time" data-theater_name="美麗新淡海影城" data-theater_url="https://www.miranewcinemas.com/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=237" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=237">美麗新淡海影城</a>
#            <span>02-7705-0899</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                    <input type="radio" name="schedule_list" id="72593647" class="gabtn"
#                         value="2019-12-16 13:45:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="13:45"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72593647" class="">13:45</label>
#                                                                     <input type="radio" name="schedule_list" id="72593648" class="gabtn"
#                         value="2019-12-16 17:55:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="17:55"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72593648" class="">17:55</label>
#                                                                     <input type="radio" name="schedule_list" id="72593649" class="gabtn"
#                         value="2019-12-16 20:00:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="20:00"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72593649" class="select">20:00</label>
#                                                                     <input type="radio" name="schedule_list" id="72593650" class="gabtn"
#                         value="2019-12-16 22:00:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="22:00"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72593650" class="select">22:00</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_247" class="area_time _c jq_area_time" data-theater_name="喜樂時代影城永和店" data-theater_url="https://goo.gl/H6eWKV" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=247" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=247">喜樂時代影城永和店</a>
#            <span>(02)8231-6685</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                    <input type="radio" name="schedule_list" id="72593743" class="gabtn"
#                         value="2019-12-16 10:00:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="10:00"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72593743" class="">10:00</label>
#                                                                     <input type="radio" name="schedule_list" id="72593744" class="gabtn"
#                         value="2019-12-16 13:50:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="13:50"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72593744" class="">13:50</label>
#                                                                     <input type="radio" name="schedule_list" id="72593745" class="gabtn"
#                         value="2019-12-16 17:35:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="17:35"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72593745" class="">17:35</label>
#                                                                     <input type="radio" name="schedule_list" id="72593746" class="gabtn"
#                         value="2019-12-16 21:20:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="21:20"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72593746" class="select">21:20</label>
#                                                                     <input type="radio" name="schedule_list" id="72593747" class="gabtn"
#                         value="2019-12-16 23:20:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="23:20"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72593747" class="select">23:20</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_251" class="area_time _c jq_area_time" data-theater_name="國賓影城(淡水禮萊廣場)" data-theater_url="http://www.ambassador.com.tw/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=251" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=251">國賓影城(淡水禮萊廣場)</a>
#            <span>02-2626-0707</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                    <input type="radio" name="schedule_list" id="72593813" class="gabtn"
#                         value="2019-12-16 13:30:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="13:30"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72593813" class="">13:30</label>
#                                                                     <input type="radio" name="schedule_list" id="72593814" class="gabtn"
#                         value="2019-12-16 15:55:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="15:55"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72593814" class="">15:55</label>
#                                                                     <input type="radio" name="schedule_list" id="72593815" class="gabtn"
#                         value="2019-12-16 20:10:00" data-movie_type="數位"
#                         data-movie_title="去年聖誕節"
#                         data-movie_date="12.16"
#                         data-movie_time="20:10"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-news="news"
#                         />
#                     <label for="72593815" class="select">20:10</label>
#                                                </div>
#            </li>
#           </ul>
#    </div>
#
#     <div class="booking_modal jq_booking_modal">
#     <div class="booking_modal_backdrop"></div>
#     <!-- 時報訂票 ＆ 有官網訂票 新增 class => no_seats -->
#     <div class="booking_modal_content jq_booking_modal_content">
#         <form method="get" action="https://movies.yahoo.com.tw/ticket/ezding_ticket" target="_blank" id="form_schedule">
#                 <div class="ezding_ticket_value">
#             <input type="hidden" name="movie_id" value="">
#             <input type="hidden" name="cinema_id" value="">
#             <input type="hidden" name="session_id" value="">
#             <input type="hidden" name="date" value="">
#             <input type="hidden" name="time" value="">
#             <input type="hidden" name="campaign_code" value="yahoopc">
#         </div>
#         <ul class="top_infos">
#             <li>
#                 <p>片名</p>
#                 <h3 id="top_infos_movie"></h3>
#             </li>
#             <li>
#                 <p>影城</p>
#                 <h3 id="top_infos_theater"></h3>
#             </li>
#             <li>
#                 <p>日期</p>
#                 <h3 id="top_infos_date"></h3>
#             </li>
#             <li>
#                 <p>版本</p>
#                 <h3 id="top_infos_movie_type"></h3>
#             </li>
#             <li>
#                 <p>時間</p>
#                 <h3 id="top_infos_time"></h3>
#             </li>
#         </ul>
#
#         <div class="booking_seats">
#             <a href="#" class="theater_schedules gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_全部電影場次', '']">全部電影場次</a>
#             <a href="#" class="theater_url gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_官網訂票', '']" target="_blank">官網訂票</a>
#             <p id="no_theater_url" class="no_theater_url">無提供官網訂票</p>
#
#             <p id="booking_number" class="booking_number">人數</p>
#             <div class="booking_seat_group jq_booking_seat_group">
#                                     <input type="radio" name="tickets" id="seat_1" value="1" />
#                     <label for="seat_1">1</label>
#                                     <input type="radio" name="tickets" id="seat_2" value="2"  checked />
#                     <label for="seat_2">2</label>
#                                     <input type="radio" name="tickets" id="seat_3" value="3" />
#                     <label for="seat_3">3</label>
#                                     <input type="radio" name="tickets" id="seat_4" value="4" />
#                     <label for="seat_4">4</label>
#                                     <input type="radio" name="tickets" id="seat_5" value="5" />
#                     <label for="seat_5">5</label>
#                                     <input type="radio" name="tickets" id="seat_6" value="6" />
#                     <label for="seat_6">6</label>
#                             </div>
#             <button type="submit" class="action_btn action_booking_btn jq_booking_btn gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_選位', '']">選位</button>
#             <a href="#" class="action_btn action_link jq_booking_link gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_時報戲院_官網選位', '']" target="_blank">官網訂票</a>
#             <button type="button" class="action_btn close jq_close_booking_btn">關閉</button>
#         </div>
#         </form>
#
#         <!-- 無官網訂票區塊 -->
#         <div class="no_theater_section">
#             <p>無提供官網訂票</p>
#             <button type="button" class="action_btn close jq_close_booking_btn">關閉</button>
#         </div>
#     </div>
# </div></div>

# %%
'''

  試著從上一步驟回傳的電影院資料中，擷取電影院名稱、影片放映類型以及時間表
  
  Your code here.

'''
soup
# Out:
# <html><body><div class="pc-movie-schedule-form">
# <div class="area_timebox">
# <div class="area_title">新北市</div>
# <ul class="area_time _c jq_area_time" data-theater_name="鴻金寶麻吉影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=56" data-theater_url="http://machicinema.wordpress.com/" id="theater_id_56">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=56">鴻金寶麻吉影城</a>
# <span>02-22070222</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="13:05" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72590943" name="schedule_list" type="radio" value="2019-12-16 13:05:00"/>
# <label class="" for="72590943">13:05</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="18:05" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72590944" name="schedule_list" type="radio" value="2019-12-16 18:05:00"/>
# <label class="" for="72590944">18:05</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="23:40" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72590945" name="schedule_list" type="radio" value="2019-12-16 23:40:00"/>
# <label class="select" for="72590945">23:40</label>
# </div>
# </li>
# </ul>
# <ul class="area_time _c jq_area_time" data-theater_name="三重天台戲院" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=57" data-theater_url="http://www.t-movies.com.tw/" id="theater_id_57">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=57">三重天台戲院</a>
# <span>02-29787700</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="10:10" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72590969" name="schedule_list" type="radio" value="2019-12-16 10:10:00"/>
# <label class="" for="72590969">10:10</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="14:05" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72590970" name="schedule_list" type="radio" value="2019-12-16 14:05:00"/>
# <label class="" for="72590970">14:05</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="18:15" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72590971" name="schedule_list" type="radio" value="2019-12-16 18:15:00"/>
# <label class="" for="72590971">18:15</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="20:10" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72590972" name="schedule_list" type="radio" value="2019-12-16 20:10:00"/>
# <label class="select" for="72590972">20:10</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="22:05" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72590973" name="schedule_list" type="radio" value="2019-12-16 22:05:00"/>
# <label class="select" for="72590973">22:05</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.17" data-movie_time="00:00" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72590974" name="schedule_list" type="radio" value="2019-12-17 00:00:00"/>
# <label class="select" for="72590974">00:00</label>
# </div>
# </li>
# </ul>
# <ul class="area_time _c jq_area_time" data-theater_name="國賓影城(中和環球購物中心)" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=59" data-theater_url="http://www.ambassador.com.tw/" id="theater_id_59">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=59">國賓影城(中和環球購物中心)</a>
# <span>02-22268088</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="13:15" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72592335" name="schedule_list" type="radio" value="2019-12-16 13:15:00"/>
# <label class="" for="72592335">13:15</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="17:35" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72592336" name="schedule_list" type="radio" value="2019-12-16 17:35:00"/>
# <label class="" for="72592336">17:35</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="22:00" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72592337" name="schedule_list" type="radio" value="2019-12-16 22:00:00"/>
# <label class="select" for="72592337">22:00</label>
# </div>
# </li>
# </ul>
# <ul class="area_time _c jq_area_time" data-theater_name="板橋大遠百威秀影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=128" data-theater_url="http://www.vscinemas.com.tw/" id="theater_id_128">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=128">板橋大遠百威秀影城</a>
# <span>02-77386608</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-cinema="737ece862a0111e18e86000bdb90dba4" data-date="1576425600" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie="570a9b68a41046efabd02ce4827fe5ff" data-movie_date="12.16" data-movie_time="21:35" data-movie_title="去年聖誕節" data-movie_type="數位" data-session="1258a854e8744c8d821fb090ba570468" data-time="1576503300" id="72570558" name="schedule_list" type="radio" value="2019-12-16 21:35:00"/>
# <label class="select" for="72570558">21:35</label>
# </div>
# </li>
# </ul>
# <ul class="area_time _c jq_area_time" data-theater_name="板橋秀泰影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=154" data-theater_url="http://www.showtimes.com.tw/" id="theater_id_154">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=154">板橋秀泰影城</a>
# <span>02-22720639</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="10:30" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72592656" name="schedule_list" type="radio" value="2019-12-16 10:30:00"/>
# <label class="" for="72592656">10:30</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="12:30" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72592657" name="schedule_list" type="radio" value="2019-12-16 12:30:00"/>
# <label class="" for="72592657">12:30</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="18:30" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72592658" name="schedule_list" type="radio" value="2019-12-16 18:30:00"/>
# <label class="" for="72592658">18:30</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="20:30" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72592659" name="schedule_list" type="radio" value="2019-12-16 20:30:00"/>
# <label class="select" for="72592659">20:30</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="22:30" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72592660" name="schedule_list" type="radio" value="2019-12-16 22:30:00"/>
# <label class="select" for="72592660">22:30</label>
# </div>
# </li>
# </ul>
# <ul class="area_time _c jq_area_time" data-theater_name="國賓影城(林口昕境廣場)" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=180" data-theater_url="http://www.ambassador.com.tw/aboutus_a9.html" id="theater_id_180">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=180">國賓影城(林口昕境廣場)</a>
# <span>02-26080011</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="13:00" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72592881" name="schedule_list" type="radio" value="2019-12-16 13:00:00"/>
# <label class="" for="72592881">13:00</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="15:00" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72592882" name="schedule_list" type="radio" value="2019-12-16 15:00:00"/>
# <label class="" for="72592882">15:00</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="17:30" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72592883" name="schedule_list" type="radio" value="2019-12-16 17:30:00"/>
# <label class="" for="72592883">17:30</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="19:30" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72592884" name="schedule_list" type="radio" value="2019-12-16 19:30:00"/>
# <label class="select" for="72592884">19:30</label>
# </div>
# </li>
# </ul>
# <ul class="area_time _c jq_area_time" data-theater_name="國賓影城(新莊晶冠廣場)" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=185" data-theater_url="http://www.ambassador.com.tw/showtime_list.html?theaterid=3301d822-b385-4aa8-a9eb-aa59d58e95c9" id="theater_id_185">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=185">國賓影城(新莊晶冠廣場)</a>
# <span>(02)8521-6517</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="11:10" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72593016" name="schedule_list" type="radio" value="2019-12-16 11:10:00"/>
# <label class="" for="72593016">11:10</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="13:45" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72593017" name="schedule_list" type="radio" value="2019-12-16 13:45:00"/>
# <label class="" for="72593017">13:45</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="16:50" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72593018" name="schedule_list" type="radio" value="2019-12-16 16:50:00"/>
# <label class="" for="72593018">16:50</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="20:30" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72593019" name="schedule_list" type="radio" value="2019-12-16 20:30:00"/>
# <label class="select" for="72593019">20:30</label>
# </div>
# </li>
# </ul>
# <ul class="area_time _c jq_area_time" data-theater_name="林口MITSUI OUTLET PARK威秀影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=193" data-theater_url="http://www.vscinemas.com.tw/" id="theater_id_193">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=193">林口MITSUI OUTLET PARK威秀影城</a>
# <span>02-26068099</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-cinema="73544d843cd311e69bb83d0f96c001c2" data-date="1576425600" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie="41b112a5c0a0429f8c4a63d7478da189" data-movie_date="12.16" data-movie_time="21:45" data-movie_title="去年聖誕節" data-movie_type="數位" data-session="f03f460cf394415ba0274824a2872ffc" data-time="1576503900" id="72566089" name="schedule_list" type="radio" value="2019-12-16 21:45:00"/>
# <label class="select" for="72566089">21:45</label>
# </div>
# </li>
# </ul>
# <ul class="area_time _c jq_area_time" data-theater_name="樹林秀泰影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=214" data-theater_url="https://www.showtimes.com.tw/events?corpId=54" id="theater_id_214">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=214">樹林秀泰影城</a>
# <span>02-26868769</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="11:30" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72593413" name="schedule_list" type="radio" value="2019-12-16 11:30:00"/>
# <label class="" for="72593413">11:30</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="15:40" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72593414" name="schedule_list" type="radio" value="2019-12-16 15:40:00"/>
# <label class="" for="72593414">15:40</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="19:50" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72593415" name="schedule_list" type="radio" value="2019-12-16 19:50:00"/>
# <label class="select" for="72593415">19:50</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="21:50" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72593416" name="schedule_list" type="radio" value="2019-12-16 21:50:00"/>
# <label class="select" for="72593416">21:50</label>
# </div>
# </li>
# </ul>
# <ul class="area_time _c jq_area_time" data-theater_name="美麗新淡海影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=237" data-theater_url="https://www.miranewcinemas.com/" id="theater_id_237">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=237">美麗新淡海影城</a>
# <span>02-7705-0899</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="13:45" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72593647" name="schedule_list" type="radio" value="2019-12-16 13:45:00"/>
# <label class="" for="72593647">13:45</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="17:55" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72593648" name="schedule_list" type="radio" value="2019-12-16 17:55:00"/>
# <label class="" for="72593648">17:55</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="20:00" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72593649" name="schedule_list" type="radio" value="2019-12-16 20:00:00"/>
# <label class="select" for="72593649">20:00</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="22:00" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72593650" name="schedule_list" type="radio" value="2019-12-16 22:00:00"/>
# <label class="select" for="72593650">22:00</label>
# </div>
# </li>
# </ul>
# <ul class="area_time _c jq_area_time" data-theater_name="喜樂時代影城永和店" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=247" data-theater_url="https://goo.gl/H6eWKV" id="theater_id_247">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=247">喜樂時代影城永和店</a>
# <span>(02)8231-6685</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="10:00" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72593743" name="schedule_list" type="radio" value="2019-12-16 10:00:00"/>
# <label class="" for="72593743">10:00</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="13:50" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72593744" name="schedule_list" type="radio" value="2019-12-16 13:50:00"/>
# <label class="" for="72593744">13:50</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="17:35" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72593745" name="schedule_list" type="radio" value="2019-12-16 17:35:00"/>
# <label class="" for="72593745">17:35</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="21:20" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72593746" name="schedule_list" type="radio" value="2019-12-16 21:20:00"/>
# <label class="select" for="72593746">21:20</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="23:20" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72593747" name="schedule_list" type="radio" value="2019-12-16 23:20:00"/>
# <label class="select" for="72593747">23:20</label>
# </div>
# </li>
# </ul>
# <ul class="area_time _c jq_area_time" data-theater_name="國賓影城(淡水禮萊廣場)" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=251" data-theater_url="http://www.ambassador.com.tw/" id="theater_id_251">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=251">國賓影城(淡水禮萊廣場)</a>
# <span>02-2626-0707</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="13:30" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72593813" name="schedule_list" type="radio" value="2019-12-16 13:30:00"/>
# <label class="" for="72593813">13:30</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="15:55" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72593814" name="schedule_list" type="radio" value="2019-12-16 15:55:00"/>
# <label class="" for="72593814">15:55</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '去年聖誕節']" data-movie_date="12.16" data-movie_time="20:10" data-movie_title="去年聖誕節" data-movie_type="數位" data-news="news" id="72593815" name="schedule_list" type="radio" value="2019-12-16 20:10:00"/>
# <label class="select" for="72593815">20:10</label>
# </div>
# </li>
# </ul>
# </div>
# <div class="booking_modal jq_booking_modal">
# <div class="booking_modal_backdrop"></div>
# <!-- 時報訂票 ＆ 有官網訂票 新增 class => no_seats -->
# <div class="booking_modal_content jq_booking_modal_content">
# <form action="https://movies.yahoo.com.tw/ticket/ezding_ticket" id="form_schedule" method="get" target="_blank">
# <div class="ezding_ticket_value">
# <input name="movie_id" type="hidden" value=""/>
# <input name="cinema_id" type="hidden" value=""/>
# <input name="session_id" type="hidden" value=""/>
# <input name="date" type="hidden" value=""/>
# <input name="time" type="hidden" value=""/>
# <input name="campaign_code" type="hidden" value="yahoopc"/>
# </div>
# <ul class="top_infos">
# <li>
# <p>片名</p>
# <h3 id="top_infos_movie"></h3>
# </li>
# <li>
# <p>影城</p>
# <h3 id="top_infos_theater"></h3>
# </li>
# <li>
# <p>日期</p>
# <h3 id="top_infos_date"></h3>
# </li>
# <li>
# <p>版本</p>
# <h3 id="top_infos_movie_type"></h3>
# </li>
# <li>
# <p>時間</p>
# <h3 id="top_infos_time"></h3>
# </li>
# </ul>
# <div class="booking_seats">
# <a class="theater_schedules gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_全部電影場次', '']" href="#">全部電影場次</a>
# <a class="theater_url gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_官網訂票', '']" href="#" target="_blank">官網訂票</a>
# <p class="no_theater_url" id="no_theater_url">無提供官網訂票</p>
# <p class="booking_number" id="booking_number">人數</p>
# <div class="booking_seat_group jq_booking_seat_group">
# <input id="seat_1" name="tickets" type="radio" value="1"/>
# <label for="seat_1">1</label>
# <input checked="" id="seat_2" name="tickets" type="radio" value="2"/>
# <label for="seat_2">2</label>
# <input id="seat_3" name="tickets" type="radio" value="3"/>
# <label for="seat_3">3</label>
# <input id="seat_4" name="tickets" type="radio" value="4"/>
# <label for="seat_4">4</label>
# <input id="seat_5" name="tickets" type="radio" value="5"/>
# <label for="seat_5">5</label>
# <input id="seat_6" name="tickets" type="radio" value="6"/>
# <label for="seat_6">6</label>
# </div>
# <button class="action_btn action_booking_btn jq_booking_btn gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_選位', '']" type="submit">選位</button>
# <a class="action_btn action_link jq_booking_link gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_時報戲院_官網選位', '']" href="#" target="_blank">官網訂票</a>
# <button class="action_btn close jq_close_booking_btn" type="button">關閉</button>
# </div>
# </form>
# <!-- 無官網訂票區塊 -->
# <div class="no_theater_section">
# <p>無提供官網訂票</p>
# <button class="action_btn close jq_close_booking_btn" type="button">關閉</button>
# </div>
# </div>
# </div></div></body></html>

# %%
#theaters=html.find_all("ul",attrs={"class":"area_time _c jq_area_time"})
theaters=soup.find_all("ul",attrs={"class":"area_time _c jq_area_time"})

# %%
for theater in theaters:
    print(theater["data-theater_name"])
    for tt in theater.find_all("input"):
        print(tt["data-movie_date"],tt["data-movie_time"])
        #print(theater.find("li").a.string)
    #print(" ",theater.input["data-movie_date"],theater.input["data-movie_time"])
    
    
    #print(theater.input)
    #print()
# Out:
# 鴻金寶麻吉影城
# 12.16 13:05
# 12.16 18:05
# 12.16 23:40
# 三重天台戲院
# 12.16 10:10
# 12.16 14:05
# 12.16 18:15
# 12.16 20:10
# 12.16 22:05
# 12.17 00:00
# 國賓影城(中和環球購物中心)
# 12.16 13:15
# 12.16 17:35
# 12.16 22:00
# 板橋大遠百威秀影城
# 12.16 21:35
# 板橋秀泰影城
# 12.16 10:30
# 12.16 12:30
# 12.16 18:30
# 12.16 20:30
# 12.16 22:30
# 國賓影城(林口昕境廣場)
# 12.16 13:00
# 12.16 15:00
# 12.16 17:30
# 12.16 19:30
# 國賓影城(新莊晶冠廣場)
# 12.16 11:10
# 12.16 13:45
# 12.16 16:50
# 12.16 20:30
# 林口MITSUI OUTLET PARK威秀影城
# 12.16 21:45
# 樹林秀泰影城
# 12.16 11:30
# 12.16 15:40
# 12.16 19:50
# 12.16 21:50
# 美麗新淡海影城
# 12.16 13:45
# 12.16 17:55
# 12.16 20:00
# 12.16 22:00
# 喜樂時代影城永和店
# 12.16 10:00
# 12.16 13:50
# 12.16 17:35
# 12.16 21:20
# 12.16 23:20
# 國賓影城(淡水禮萊廣場)
# 12.16 13:30
# 12.16 15:55
# 12.16 20:10
