# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 利用 urllib 套件的 urlretrieve 方法下載檔案
# * 了解 Python File I/O 讀檔、寫檔的用法
# * 能用運用資源管理器 With Statement 優化寫法

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？

'''
Your Code
'''
import requests
import json
r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
response = r.text

response
# Out:
# '[{"id":232599218,"title":"我家的貓每天睡覺前一定會做的事","excerpt":"Aniki每天只要注意到我進房間床上躺著時，一定會咬著牠的逗貓棒來找我🤣🤣🤣，不陪牠玩就會坐在那等著我拿起逗貓棒跟牠玩爲止。———————我是分隔線——————，看到大家都跟我也一樣被融化了，覺","anonymousSchool":false,"anonymousDepartment":false,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2019-11-30T06:52:29.882Z","updatedAt":"2019-12-01T12:19:34.437Z","commentCount":132,"likeCount":4444,"withNickname":true,"tags":[],"topics":["貓","領養代替購買","寵物"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","gender":"F","school":"正妹與大叔","department":"sky740311","replyTitle":null,"mediaMeta":[{"id":"1c8941e8-68bc-476d-81dd-6e7dbcdf545e","url":"https://i.imgur.com/jT6dhqRl.jpg","normalizedUrl":"https://i.imgur.com/jT6dhqRl.jpg","thumbnail":"https://i.imgur.com/jT6dhqRl.jpg","type":"image/thumbnail","tags":["ANNOTATED"],"createdAt":"2019-11-30T06:52:29.882Z","updatedAt":"2019-12-01T12:19:34.437Z"},{"id":"1c8941e8-68bc-476d-81dd-6e7dbcdf545e","url":"https://i.imgur.com/jT6dhqR.j
# ...

# %%
ret_data=json.loads(response)

# %%
#for i in j:
#    print(i.keys())
print(ret_data[0].keys())
# Out:
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'gender', 'school', 'department', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])

# %%
print("共:",len(ret_data),"筆資料")
print("每一筆資料包含以下欄位:",ret_data[0].keys())

#for i in j:
#    for k in j[0].keys():
#        print(k,i[k])
#    print()
# Out:
# 共: 30 筆資料
# 每一筆資料包含以下欄位: dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'gender', 'school', 'department', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」

'''
Your Code
'''
for data in ret_data:
    print("標題:",data['title'])
    print("貼文時間:",data['createdAt'])
    print("留言人數:",data['commentCount'])
    print("按讚人數:",data['likeCount'])
    print()
# Out:
# 標題: 我家的貓每天睡覺前一定會做的事
# 貼文時間: 2019-11-30T06:52:29.882Z
# 留言人數: 132
# 按讚人數: 4444
#
# 標題: 被擠床原來是一件幸福的事
# 貼文時間: 2019-11-30T04:15:42.699Z
# 留言人數: 23
# 按讚人數: 1709
#
# 標題: #哈士奇 滿一歲啦 文長 滿滿的二哈
# 貼文時間: 2019-11-30T16:30:51.154Z
# 留言人數: 25
# 按讚人數: 933
#
# 標題: 媽 晚餐好了沒
# 貼文時間: 2019-11-30T10:42:58.582Z
# 留言人數: 5
# 按讚人數: 667
#
# 標題: 有貓快拜！！
# 貼文時間: 2019-11-30T03:07:22.599Z
# 留言人數: 4
# 按讚人數: 446
#
# 標題: 有人要吸兔嗎？
# 貼文時間: 2019-11-30T04:58:10.195Z
# 留言人數: 40
# 按讚人數: 318
#
# 標題: 你到底是貓還是狗？
# 貼文時間: 2019-11-30T14:32:06.500Z
# 留言人數: 10
# 按讚人數: 77
#
# 標題: 原來柴犬可以那麽可愛🐕
# 貼文時間: 2019-11-30T17:17:51.628Z
# 留言人數: 2
# 按讚人數: 76
#
# 標題: 好像買太小了...
# 貼文時間: 2019-12-01T08:27:28.504Z
# 留言人數: 5
# 按讚人數: 61
#
# 標題: 我養的是工讀生？🤔
# 貼文時間: 2019-12-01T02:07:09.729Z
# 留言人數: 6
# 按讚人數: 56
#
# 標題: 白圍巾白手套橘貓❤️
# 貼文時間: 2019-11-30T07:44:14.420Z
# 留言人數: 6
# 按讚人數: 55
#
# 標題: 四個月的布偶屁貓
# 貼文時間: 2019-11-30T11:24:26.047Z
# 留言人數: 2
# 按讚人數: 45
#
# 標題: 從沒想過山竹可以這麼可口ฅ
# 貼文時間: 2019-11-30T10:24:08.529Z
# 留言人數: 6
# 按讚人數: 35
#
# 標題: #柴 #影片 到底有多討厭洗澡
# ...

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

'''
Your Code
'''
new_list_comment=[]
new_list_like=[]
for data in ret_data:
    #comment_cnt = data['commentCount']
    new_list_comment.append(data['commentCount'])
    new_list_like.append(data['likeCount'])
    #print(type(comment_cnt))
    ##like_cnt = data['likeCount']
    ##new_list.append(int_price)
print("平均留言人數:",sum(new_list_comment)/len(new_list_comment))
print("平均按讚人數:",sum(new_list_ㄌㄞlike)/len(new_list_comment))
# Out:
# 平均留言人數: 9.966666666666667
